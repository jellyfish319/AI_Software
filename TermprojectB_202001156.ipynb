# %% [markdown]
# ## 셀 순서대로 실행해주시면 됩니다.
#
# gdown이 동작하지 않으실 경우 링크에서 파일들을 받으신 뒤 코랩에 압축해제해주시면 되겠습니다.

# %% [markdown]
# https://drive.google.com/file/d/14At7O0pOuc5djlMTf-Z_BUE-tgAlDIx8/view?usp=drive_link

# %%
FILE_ID = '14At7O0pOuc5djlMTf-Z_BUE-tgAlDIx8'

# !pip install -q gdown
# !pip install torch transformers peft datasets[audio] librosa soundfile scikit-learn pandas tqdm
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 43.4 MB/s eta 0:00:00
# ...

# %%
import gdown
url = f'https://drive.google.com/uc?id={FILE_ID}'
gdown.download(url, quiet=False)

# !unzip -q {"B.zip"}
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1XAdP0M1PfnN5qo7js5lj7XbQKmUHVsMg
# From (redirected): https://drive.google.com/uc?id=1XAdP0M1PfnN5qo7js5lj7XbQKmUHVsMg&confirm=t&uuid=e671af1e-9edd-4a7b-8f79-c3d33e28c26f
# To: /content/Submission.zip
# 100%|██████████| 6.03G/6.03G [01:19<00:00, 75.4MB/s]
# Downloading...
# From (original): https://drive.google.com/uc?id=1XAdP0M1PfnN5qo7js5lj7XbQKmUHVsMg
# From (redirected): https://drive.google.com/uc?id=1XAdP0M1PfnN5qo7js5lj7XbQKmUHVsMg&confirm=t&uuid=89e7ae5e-4110-4b70-b9f4-e2b6105b88ce
# To: /content/B.zip
# 100%|██████████| 6.03G/6.03G [01:18<00:00, 77.2MB/s]

# %%
print("\n" + "="*50)
print(" [Mode 1] UrbanSound8K")
print("="*50)

# !python evaluate.py --mode urban
# Out:
# ...
#  [Mode 1] UrbanSound8K
# ...
# 2025-12-15 11:30:18.278590: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1765798218.298464    5752 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1765798218.304633    5752 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1765798218.319704    5752 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %% [markdown]
# ## ./test/custom 폴더에 테스트 데이터셋을 넣어주세요.
# ## 테스트 데이터셋 아래에는 "air_conditioner", "car_horn", "children_playing", "dog_bark", "drilling","engine_idling", "gun_shot", "jackhammer", "siren", "street_music" 폴더에 클래스에 맞는 음원들을 넣어주세요.

# %%
# !python evaluate.py --mode custom
