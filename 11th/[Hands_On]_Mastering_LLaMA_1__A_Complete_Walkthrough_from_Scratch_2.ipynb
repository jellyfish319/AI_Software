# %% [markdown]
# # [Hands-On] Mastering LLaMA 1: A Complete Walkthrough from Scratch
#
# - Author: Sangkeun Jung (hugmanskj@gmail.com)
#
# > Educational Purpose
#
# **Copyright**: All rights reserved
#
# ---
#
# ### Overview
#
# This hands-on tutorial is designed for those who want to fully understand and master the LLaMA 1 architecture by building it from scratch. We'll break down every component of the model, covering the theory and practical implementation details, to provide a comprehensive guide from the very basics to the final construction.
#
# Throughout this walkthrough, you will:
# - Dive deep into the foundational concepts behind LLaMA 1, such as multi-head attention, feed-forward networks, and the SwiGLU activation function.
# - Implement advanced techniques like Rotary Position Embedding (RoPE) and RMSNorm, which optimize performance and efficiency in large models.
# - Explore LLaMA's key improvements over traditional transformer models, including how it achieves better scalability and efficiency.
# - Verify the correctness of your custom implementation by comparing it to Hugging Face’s official LLaMA 1 model at a high-precision level.
#
# By the end of this tutorial, you'll have a complete understanding of LLaMA 1’s architecture and how to implement it from scratch, making it a powerful resource for both learners and professionals looking to deepen their knowledge of large-scale language models.
#
# ---

# %% [markdown]
# We begin by implementing essential utility functions, such as data loading, model initialization, and training helper functions. These components will be reused across different experimental setups for consistency and efficiency.

# %%
## Importing Libraries

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import numpy as np
import time
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## Hyperparameters and Configuration

# %%
# Modified hyperparameters
SEQUENCE_LENGTH = 64

EMBEDDING_DIM = 256
HIDDEN_DIM = 256

BATCH_SIZE = 512
EPOCHS = 1
LEARNING_RATE = 0.001
PRINT_EVERY = 1000
VALIDATION_SPLIT = 0.1

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %% [markdown]
# ## Data Preparation
#
# We are using the TinyShakespeare dataset, a small character-level text corpus consisting of a subset of Shakespeare's plays. It's often used for testing sequence models, as it includes a rich set of vocabulary and provides a challenging task for next-character prediction.

# %%
## Utility Functions

def load_data(filename):
    with open(filename, 'r', encoding='utf-8') as f:
        return f.read()

def create_char_mappings(text):
    chars = sorted(list(set(text)))
    char_to_idx = {ch: i for i, ch in enumerate(chars)}
    idx_to_char = {i: ch for i, ch in enumerate(chars)}
    return chars, char_to_idx, idx_to_char

# %% [markdown]
# ## Dataset

# %%
# !wget --no-check-certificate 'https://drive.google.com/uc?export=download&id=19zosLuU0z4MxIMKbGVYEGlg52QyfbTIy' -O input.txt
# Out:
# --2025-11-16 11:14:58--  https://drive.google.com/uc?export=download&id=19zosLuU0z4MxIMKbGVYEGlg52QyfbTIy
# Resolving drive.google.com (drive.google.com)... 74.125.137.139, 74.125.137.113, 74.125.137.101, ...
# Connecting to drive.google.com (drive.google.com)|74.125.137.139|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://drive.usercontent.google.com/download?id=19zosLuU0z4MxIMKbGVYEGlg52QyfbTIy&export=download [following]
# --2025-11-16 11:14:58--  https://drive.usercontent.google.com/download?id=19zosLuU0z4MxIMKbGVYEGlg52QyfbTIy&export=download
# Resolving drive.usercontent.google.com (drive.usercontent.google.com)... 142.251.2.132, 2607:f8b0:4023:c0d::84
# Connecting to drive.usercontent.google.com (drive.usercontent.google.com)|142.251.2.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1115394 (1.1M) [application/octet-stream]
# Saving to: ‘input.txt’
#
# input.txt           100%[===================>]   1.06M  --.-KB/s    in 0.1s
#
# 2025-11-16 11:14:59 (8.47 MB/s) - ‘input.txt’ saved [1115394/1115394]

# %%
class CharDataset(Dataset):
    def __init__(self, text, seq_length, char_to_idx):
        self.text = text
        self.seq_length = seq_length
        self.char_to_idx = char_to_idx

    def __len__(self):
        return len(self.text) - self.seq_length

    def __getitem__(self, idx):
        x = [self.char_to_idx[ch] for ch in self.text[idx:idx+self.seq_length]]
        y = [self.char_to_idx[ch] for ch in self.text[idx+1:idx+self.seq_length+1]]
        return torch.tensor(x), torch.tensor(y)

# %% [markdown]
# In autoregressive modeling, each input sequence predicts the next token. For this dataset, the input is a sequence of characters from the text, and the target is the same sequence shifted by one character. This technique allows the model to learn sequential dependencies within the text.

# %%
def prepare_data(text, seq_length, batch_size, val_split):
    chars, char_to_idx, idx_to_char = create_char_mappings(text)

    # Split data into train and validation
    val_size = int(len(text) * val_split)
    train_text, val_text = text[:-val_size], text[-val_size:]

    train_dataset = CharDataset(train_text, seq_length, char_to_idx)
    val_dataset = CharDataset(val_text, seq_length, char_to_idx)

    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

    return train_loader, val_loader, chars, char_to_idx, idx_to_char

# %%
# Load the data
text = load_data('input.txt')
train_loader, val_loader, chars, char_to_idx, idx_to_char = prepare_data(text, SEQUENCE_LENGTH, BATCH_SIZE, VALIDATION_SPLIT)
vocab_size = len(chars)

print(f"Total characters: {len(text)}")
print(f"Vocabulary size: {vocab_size}")
print(f"Train dataset size: {len(train_loader.dataset)}")
print(f"Validation dataset size: {len(val_loader.dataset)}")
# Out:
# Total characters: 1115394
# Vocabulary size: 65
# Train dataset size: 1003791
# Validation dataset size: 111475

# %% [markdown]
# ## Data Visualization

# %%
# Function to convert index sequence to character sequence
def indices_to_text(indices, idx_to_char):
    return ''.join([idx_to_char[idx.item()] for idx in indices])

# Get a batch of data
dataiter = iter(train_loader)
batch_x, batch_y = next(dataiter)

print(f"Input shape: {batch_x.shape}")
print(f"Target shape: {batch_y.shape}")

# Print a few samples from the batch
num_samples = 3
for i in range(num_samples):
    print(f"Sample {i+1}: ------------------------------" )
    print("Input sequence :", indices_to_text(batch_x[i], idx_to_char).replace('\n',''))
    print("Target sequence:", indices_to_text(batch_y[i], idx_to_char).replace('\n',''))
    print()
# Out:
# Input shape: torch.Size([512, 64])
# Target shape: torch.Size([512, 64])
# Sample 1: ------------------------------
# Input sequence : t true;That Mowbray hath received eight thousand noblesIn name
# Target sequence:  true;That Mowbray hath received eight thousand noblesIn name
#
# Sample 2: ------------------------------
# Input sequence :  succeeding ages have re-edified.PRINCE EDWARD:Is it upon rec
# Target sequence: succeeding ages have re-edified.PRINCE EDWARD:Is it upon reco
#
# Sample 3: ------------------------------
# Input sequence :  have time to breathe be well assuredHer faction will be full a
# Target sequence: have time to breathe be well assuredHer faction will be full as

# %% [markdown]
# ## Training Function

# %%
def train(model, dataloader, criterion, optimizer, device, epoch, step, log_interval=10):
    model.train()
    losses = []

    for batch, (x, y) in enumerate(dataloader):
        x, y = x.to(device), y.to(device)
        optimizer.zero_grad()
        output, _ = model(x)
        loss = criterion(output.view(-1, output.size(-1)), y.view(-1))
        loss.backward()
        optimizer.step()

        step += 1
        losses.append((step, epoch, loss.item()))

        if (batch + 1) % log_interval == 0:
            print(f'Epoch {epoch}, Step {step}, Batch {batch+1}/{len(dataloader)}, Loss: {loss.item():.4f}')

    return losses, step

# %%
def validate(model, dataloader, criterion, device, epoch, step):
    model.eval()
    losses = []

    with torch.no_grad():
        for x, y in dataloader:
            x, y = x.to(device), y.to(device)
            output, _ = model(x)
            loss = criterion(output.view(-1, output.size(-1)), y.view(-1))
            losses.append((step, epoch, loss.item()))

    return losses

# %% [markdown]
# ## Generation Function

# %%
def generate(model, char_to_idx, idx_to_char, start_char, max_length, device):
    model.eval()
    hidden = None
    current_char = start_char
    generated_text = current_char

    for _ in range(max_length):
        x = torch.tensor([[char_to_idx[current_char]]]).to(device)
        output, hidden = model(x, hidden)
        probs = torch.softmax(output[0, -1], dim=0)
        next_char_idx = torch.multinomial(probs, 1).item()
        current_char = idx_to_char[next_char_idx]
        generated_text += current_char

    return generated_text

# %%
def train_model(model, train_loader, val_loader, criterion, optimizer, device, epochs, log_interval=10):
    all_train_losses = []
    all_val_losses = []
    step = 0

    for epoch in range(1, epochs + 1):
        print(f"Epoch {epoch}/{epochs}")
        epoch_start_time = time.time()

        # Training phase
        epoch_train_losses, step = train(model, train_loader, criterion, optimizer, device, epoch, step, log_interval)
        all_train_losses.extend(epoch_train_losses)

        # Validation phase
        epoch_val_losses = validate(model, val_loader, criterion, device, epoch, step)
        all_val_losses.extend(epoch_val_losses)

        epoch_time = time.time() - epoch_start_time
        print(f'Epoch {epoch}/{epochs}, '
              f'Train Loss: {epoch_train_losses[-1][2]:.4f}, '
              f'Val Loss: {epoch_val_losses[-1][2]:.4f}, '
              f'Epoch Time: {epoch_time:.2f}s')

    # Create DataFrames after all epochs
    train_losses_df = pd.DataFrame(all_train_losses, columns=['step', 'epoch', 'loss_value'])
    val_losses_df = pd.DataFrame(all_val_losses, columns=['step', 'epoch', 'loss_value'])

    return model, train_losses_df, val_losses_df

# %%
def generate_text(model, char_to_idx, idx_to_char, start_text, device, max_length=500):
    model.eval()
    current_text = start_text
    hidden = None

    with torch.no_grad():
        for _ in range(max_length):
            x = torch.tensor([[char_to_idx[ch] for ch in current_text[-SEQUENCE_LENGTH:]]]).to(device)
            output, hidden = model(x, hidden)
            probs = torch.softmax(output[0, -1], dim=0)
            next_char_idx = torch.multinomial(probs, 1).item()
            next_char = idx_to_char[next_char_idx]
            current_text += next_char

    return current_text

# %%
# Utiltiy functions

# Dictionary to store the losses from different models/configurations
loss_comparison_dict = {}

# Function to add and store losses from different models
def add_loss_to_comparison(model_name, train_losses_df, val_losses_df):
    """
    Adds training and validation losses from a model to the comparison dictionary.

    Args:
    - model_name (str): A name to identify the model (e.g., 'LSTM', 'LSTM with RMSNorm')
    - train_losses_df (DataFrame): DataFrame containing the training losses.
    - val_losses_df (DataFrame): DataFrame containing the validation losses.
    """
    loss_comparison_dict[model_name] = {
        'train': train_losses_df,
        'val': val_losses_df
    }

# %%
# Function to plot loss curves
def plot_loss(train_losses_df, val_losses_df):
    plt.figure(figsize=(10, 5))

    # Plot training losses
    for epoch in train_losses_df['epoch'].unique():
        epoch_train_losses = train_losses_df[train_losses_df['epoch'] == epoch]
        plt.plot(epoch_train_losses['step'], epoch_train_losses['loss_value'],
                 color='blue', alpha=0.3)

    # scatter training loss at the end of each epoch
    last_train_losses = train_losses_df.groupby('epoch').last().reset_index()
    plt.scatter(last_train_losses['step'], last_train_losses['loss_value'],
                color='blue')

    # Plot and scatter validation loss at the end of each epoch
    last_val_losses = val_losses_df.groupby('epoch').last().reset_index()
    plt.plot(last_val_losses['step'], last_val_losses['loss_value'],
             color='orange', label='Validation Loss')
    plt.scatter(last_val_losses['step'], last_val_losses['loss_value'],
                color='orange')

    plt.xlabel('Steps')
    plt.ylabel('Loss')
    plt.title('Training and Validation Loss')
    plt.legend()
    plt.grid(True)
    plt.show()

# Function to print final loss values
def print_final_losses(train_losses_df, val_losses_df):
    print("Final Training Loss:", train_losses_df.groupby('epoch')['loss_value'].last().iloc[-1])
    print("Final Validation Loss:", val_losses_df.groupby('epoch')['loss_value'].last().iloc[-1])

# %%
# Function to plot loss curves for multiple models stored in loss_comparison_dict
def plot_loss_comparisons():
    """
    Plots the training and validation loss curves for multiple models added to the loss comparison dictionary.
    """
    plt.figure(figsize=(10, 5))

    # Get the last model in the dictionary
    last_model_name = list(loss_comparison_dict.keys())[-1]

    # Loop through each model in the loss dictionary
    for model_name, losses in loss_comparison_dict.items():
        train_losses_df = losses['train']
        val_losses_df = losses['val']

        # Plot training losses for each model
        plt.plot(train_losses_df['step'], train_losses_df['loss_value'],
                 label=f'{model_name}', linestyle='-', alpha=0.7)

        # scatter training loss at the end of each epoch
        last_train_losses = train_losses_df.groupby('epoch').last().reset_index()

        # Scatter normal points for all models
        plt.scatter(last_train_losses['step'], last_train_losses['loss_value'], marker='o', s=50)

        # If this is the last model, highlight the last point with a star (no label in legend)
        if model_name == last_model_name:
            final_step = train_losses_df['step'].iloc[-1]
            final_loss = train_losses_df['loss_value'].iloc[-1]
            plt.scatter(final_step, final_loss, marker='*', s=100, color='red', zorder=5)  # Reduced size to s=100

    plt.xlabel('Steps')
    plt.ylabel('Loss')
    plt.title('Training Loss Comparison')
    plt.legend()  # Legend will only show colors, no final star
    plt.grid(True)
    plt.show()

# %% [markdown]
# We have prepared the data and utility functions, let’s implement a simple LSTM-based decoder as a baseline.
#
# This is a foundational model that we’ll use to compare with more advanced architectures like LLaMA. The LSTM decoder will serve as a reference point in terms of performance and complexity.
#
# If you're already familiar with LSTM models, you can skip this section and proceed directly to LLaMA-specific techniques.

# %% [markdown]
# ## LSTM based Decoder

# %%
class LSTMDecoder(nn.Module):
    def __init__(self, vocab_size, embedding_dim, hidden_dim):
        super(LSTMDecoder, self).__init__()
        self.embedding = nn.Embedding(vocab_size, embedding_dim)
        self.lstm = nn.LSTM(embedding_dim, hidden_dim, batch_first=True)
        self.fc = nn.Linear(hidden_dim, vocab_size)

    def forward(self, x, hidden=None):
        embed = self.embedding(x)
        output, hidden = self.lstm(embed, hidden)
        output = self.fc(output)
        return output, hidden

# %%
### Model Initialization
model = LSTMDecoder(vocab_size, EMBEDDING_DIM, HIDDEN_DIM).to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=LEARNING_RATE)

# %%
## Training Loop
trained_model, train_losses_df, val_losses_df = train_model(model, train_loader, val_loader, criterion, optimizer, device, EPOCHS)
# Out:
# Epoch 1/1
# Epoch 1, Step 10, Batch 10/1961, Loss: 3.2413
# Epoch 1, Step 20, Batch 20/1961, Loss: 2.8643
# Epoch 1, Step 30, Batch 30/1961, Loss: 2.6330
# Epoch 1, Step 40, Batch 40/1961, Loss: 2.5102
# Epoch 1, Step 50, Batch 50/1961, Loss: 2.3773
# Epoch 1, Step 60, Batch 60/1961, Loss: 2.3088
# Epoch 1, Step 70, Batch 70/1961, Loss: 2.2483
# Epoch 1, Step 80, Batch 80/1961, Loss: 2.1826
# Epoch 1, Step 90, Batch 90/1961, Loss: 2.1247
# Epoch 1, Step 100, Batch 100/1961, Loss: 2.0778
# Epoch 1, Step 110, Batch 110/1961, Loss: 2.0443
# Epoch 1, Step 120, Batch 120/1961, Loss: 2.0084
# Epoch 1, Step 130, Batch 130/1961, Loss: 1.9727
# Epoch 1, Step 140, Batch 140/1961, Loss: 1.9642
# Epoch 1, Step 150, Batch 150/1961, Loss: 1.9231
# Epoch 1, Step 160, Batch 160/1961, Loss: 1.8897
# Epoch 1, Step 170, Batch 170/1961, Loss: 1.8747
# Epoch 1, Step 180, Batch 180/1961, Loss: 1.8385
# Epoch 1, Step 190, Batch 190/1961, Loss: 1.8323
# Epoch 1, Step 200, Batch 200/1961, Loss: 1.7919
# Epoch 1, Step 210, Batch 210/1961, Loss: 1.7855
# Epoch 1, Step 220, Batch 220/1961, Loss: 1.7651
# Epoch 1, Step 230, Batch 230/1961, Loss: 1.7772
# Epoch 1, Step 240, Batch 240/1961, Loss: 1.7331
# Epoch 1, Step 250, Batch 250/1961, Loss: 1.7237
# Epoch 1, Step 260, Batch 260/1961, Loss: 1.7054
# Epoch 1, Step 270, Batch 270/1961, Loss: 1.7001
# Epoch 1, Step 280, Batch 280/1961, Loss: 1.6914
# Epoch 1, Step 290, Batch 290/1961, Loss: 1.6902
# Epoch 1, Step 300, Batch 300/1961, Loss: 1.6673
# Epoch 1, Step 310, Batch 310/1961, Loss: 1.6668
# Epoch 1, Step 320, Batch 320/1961, Loss: 1.6472
# Epoch 1, Step 330, Batch 330/1961, Loss: 1.6316
# Epoch 1, Step 340, Batch 340/1961, Loss: 1.6334
# Epoch 1, Step 350, Batch 350/1961, Loss: 1.6307
# Epoch 1, Step 360, Batch 360/1961, Loss: 1.6013
# Epoch 1, Step 370, Batch 370/1961, Loss: 1.6163
# Epoch 1, Step 380, Batch 380/1961, Loss: 1.6174
# Epoch 1, Step 390, Batch 390/1961, Loss: 1.5967
# Epoch 1, Step 400, Batch 400/1961, Loss: 1.5861
# Epoch 1, Step 410, Batch 410/1961, Loss: 1.5811
# Epoch 1, Step 420, Batch 420/1961, Loss: 1.5777
# Epoch 1, Step 430, Batch 430/1961, Loss: 1.5842
# Epoch 1, Step 440, Batch 440/1961, Loss: 1.5864
# Epoch 1, Step 450, Batch 450/1961, Loss: 1.5572
# Epoch 1, Step 460, Batch 460/1961, Loss: 1.5401
# Epoch 1, Step 470, Batch 470/1961, Loss: 1.5314
# Epoch 1, Step 480, Batch 480/1961, Loss: 1.5403
# Epoch 1, Step 490, Batch 490/1961, Loss: 1.5400
# Epoch 1, Step 500, Batch 500/1961, Loss: 1.5419
# Epoch 1, Step 510, Batch 510/1961, Loss: 1.5264
# Epoch 1, Step 520, Batch 520/1961, Loss: 1.5206
# Epoch 1, Step 530, Batch 530/1961, Loss: 1.5166
# Epoch 1, Step 540, Batch 540/1961, Loss: 1.5025
# Epoch 1, Step 550, Batch 550/1961, Loss: 1.5160
# Epoch 1, Step 560, Batch 560/1961, Loss: 1.4998
# Epoch 1, Step 570, Batch 570/1961, Loss: 1.5006
# Epoch 1, Step 580, Batch 580/1961, Loss: 1.5027
# Epoch 1, Step 590, Batch 590/1961, Loss: 1.5015
# Epoch 1, Step 600, Batch 600/1961, Loss: 1.4782
# Epoch 1, Step 610, Batch 610/1961, Loss: 1.4872
# Epoch 1, Step 620, Batch 620/1961, Loss: 1.4859
# Epoch 1, Step 630, Batch 630/1961, Loss: 1.4689
# Epoch 1, Step 640, Batch 640/1961, Loss: 1.4678
# Epoch 1, Step 650, Batch 650/1961, Loss: 1.4535
# Epoch 1, Step 660, Batch 660/1961, Loss: 1.4778
# Epoch 1, Step 670, Batch 670/1961, Loss: 1.4622
# Epoch 1, Step 680, Batch 680/1961, Loss: 1.4432
# Epoch 1, Step 690, Batch 690/1961, Loss: 1.4687
# Epoch 1, Step 700, Batch 700/1961, Loss: 1.4624
# Epoch 1, Step 710, Batch 710/1961, Loss: 1.4516
# Epoch 1, Step 720, Batch 720/1961, Loss: 1.4430
# Epoch 1, Step 730, Batch 730/1961, Loss: 1.4401
# Epoch 1, Step 740, Batch 740/1961, Loss: 1.4455
# Epoch 1, Step 750, Batch 750/1961, Loss: 1.4577
# Epoch 1, Step 760, Batch 760/1961, Loss: 1.4558
# Epoch 1, Step 770, Batch 770/1961, Loss: 1.4467
# Epoch 1, Step 780, Batch 780/1961, Loss: 1.4426
# Epoch 1, Step 790, Batch 790/1961, Loss: 1.4275
# Epoch 1, Step 800, Batch 800/1961, Loss: 1.4148
# Epoch 1, Step 810, Batch 810/1961, Loss: 1.4197
# Epoch 1, Step 820, Batch 820/1961, Loss: 1.4306
# Epoch 1, Step 830, Batch 830/1961, Loss: 1.4193
# Epoch 1, Step 840, Batch 840/1961, Loss: 1.4186
# Epoch 1, Step 850, Batch 850/1961, Loss: 1.4352
# Epoch 1, Step 860, Batch 860/1961, Loss: 1.4223
# Epoch 1, Step 870, Batch 870/1961, Loss: 1.4187
# Epoch 1, Step 880, Batch 880/1961, Loss: 1.4106
# Epoch 1, Step 890, Batch 890/1961, Loss: 1.4295
# Epoch 1, Step 900, Batch 900/1961, Loss: 1.4046
# Epoch 1, Step 910, Batch 910/1961, Loss: 1.4082
# Epoch 1, Step 920, Batch 920/1961, Loss: 1.4033
# Epoch 1, Step 930, Batch 930/1961, Loss: 1.4047
# Epoch 1, Step 940, Batch 940/1961, Loss: 1.3866
# Epoch 1, Step 950, Batch 950/1961, Loss: 1.3979
# Epoch 1, Step 960, Batch 960/1961, Loss: 1.3958
# Epoch 1, Step 970, Batch 970/1961, Loss: 1.4017
# Epoch 1, Step 980, Batch 980/1961, Loss: 1.3963
# Epoch 1, Step 990, Batch 990/1961, Loss: 1.4013
# Epoch 1, Step 1000, Batch 1000/1961, Loss: 1.3680
# Epoch 1, Step 1010, Batch 1010/1961, Loss: 1.3764
# Epoch 1, Step 1020, Batch 1020/1961, Loss: 1.3957
# Epoch 1, Step 1030, Batch 1030/1961, Loss: 1.3967
# Epoch 1, Step 1040, Batch 1040/1961, Loss: 1.3834
# Epoch 1, Step 1050, Batch 1050/1961, Loss: 1.4075
# Epoch 1, Step 1060, Batch 1060/1961, Loss: 1.3874
# Epoch 1, Step 1070, Batch 1070/1961, Loss: 1.3897
# Epoch 1, Step 1080, Batch 1080/1961, Loss: 1.3732
# Epoch 1, Step 1090, Batch 1090/1961, Loss: 1.3703
# Epoch 1, Step 1100, Batch 1100/1961, Loss: 1.3634
# Epoch 1, Step 1110, Batch 1110/1961, Loss: 1.3894
# Epoch 1, Step 1120, Batch 1120/1961, Loss: 1.3852
# Epoch 1, Step 1130, Batch 1130/1961, Loss: 1.3640
# Epoch 1, Step 1140, Batch 1140/1961, Loss: 1.3675
# Epoch 1, Step 1150, Batch 1150/1961, Loss: 1.3782
# Epoch 1, Step 1160, Batch 1160/1961, Loss: 1.3754
# Epoch 1, Step 1170, Batch 1170/1961, Loss: 1.3836
# Epoch 1, Step 1180, Batch 1180/1961, Loss: 1.3700
# Epoch 1, Step 1190, Batch 1190/1961, Loss: 1.3601
# Epoch 1, Step 1200, Batch 1200/1961, Loss: 1.3721
# Epoch 1, Step 1210, Batch 1210/1961, Loss: 1.3614
# Epoch 1, Step 1220, Batch 1220/1961, Loss: 1.3743
# Epoch 1, Step 1230, Batch 1230/1961, Loss: 1.3673
# Epoch 1, Step 1240, Batch 1240/1961, Loss: 1.3565
# Epoch 1, Step 1250, Batch 1250/1961, Loss: 1.3839
# Epoch 1, Step 1260, Batch 1260/1961, Loss: 1.3518
# Epoch 1, Step 1270, Batch 1270/1961, Loss: 1.3607
# Epoch 1, Step 1280, Batch 1280/1961, Loss: 1.3630
# Epoch 1, Step 1290, Batch 1290/1961, Loss: 1.3529
# Epoch 1, Step 1300, Batch 1300/1961, Loss: 1.3527
# Epoch 1, Step 1310, Batch 1310/1961, Loss: 1.3452
# Epoch 1, Step 1320, Batch 1320/1961, Loss: 1.3511
# Epoch 1, Step 1330, Batch 1330/1961, Loss: 1.3645
# Epoch 1, Step 1340, Batch 1340/1961, Loss: 1.3426
# Epoch 1, Step 1350, Batch 1350/1961, Loss: 1.3474
# Epoch 1, Step 1360, Batch 1360/1961, Loss: 1.3530
# Epoch 1, Step 1370, Batch 1370/1961, Loss: 1.3355
# Epoch 1, Step 1380, Batch 1380/1961, Loss: 1.3439
# Epoch 1, Step 1390, Batch 1390/1961, Loss: 1.3589
# Epoch 1, Step 1400, Batch 1400/1961, Loss: 1.3450
# Epoch 1, Step 1410, Batch 1410/1961, Loss: 1.3471
# Epoch 1, Step 1420, Batch 1420/1961, Loss: 1.3404
# Epoch 1, Step 1430, Batch 1430/1961, Loss: 1.3268
# Epoch 1, Step 1440, Batch 1440/1961, Loss: 1.3268
# Epoch 1, Step 1450, Batch 1450/1961, Loss: 1.3410
# Epoch 1, Step 1460, Batch 1460/1961, Loss: 1.3360
# Epoch 1, Step 1470, Batch 1470/1961, Loss: 1.3343
# Epoch 1, Step 1480, Batch 1480/1961, Loss: 1.3249
# Epoch 1, Step 1490, Batch 1490/1961, Loss: 1.3344
# Epoch 1, Step 1500, Batch 1500/1961, Loss: 1.3166
# Epoch 1, Step 1510, Batch 1510/1961, Loss: 1.3163
# Epoch 1, Step 1520, Batch 1520/1961, Loss: 1.3305
# Epoch 1, Step 1530, Batch 1530/1961, Loss: 1.3256
# Epoch 1, Step 1540, Batch 1540/1961, Loss: 1.3323
# Epoch 1, Step 1550, Batch 1550/1961, Loss: 1.3363
# Epoch 1, Step 1560, Batch 1560/1961, Loss: 1.3412
# Epoch 1, Step 1570, Batch 1570/1961, Loss: 1.3349
# Epoch 1, Step 1580, Batch 1580/1961, Loss: 1.3182
# Epoch 1, Step 1590, Batch 1590/1961, Loss: 1.3299
# Epoch 1, Step 1600, Batch 1600/1961, Loss: 1.3020
# Epoch 1, Step 1610, Batch 1610/1961, Loss: 1.3001
# Epoch 1, Step 1620, Batch 1620/1961, Loss: 1.3208
# Epoch 1, Step 1630, Batch 1630/1961, Loss: 1.3168
# Epoch 1, Step 1640, Batch 1640/1961, Loss: 1.3173
# Epoch 1, Step 1650, Batch 1650/1961, Loss: 1.3406
# Epoch 1, Step 1660, Batch 1660/1961, Loss: 1.3127
# Epoch 1, Step 1670, Batch 1670/1961, Loss: 1.3118
# Epoch 1, Step 1680, Batch 1680/1961, Loss: 1.3024
# Epoch 1, Step 1690, Batch 1690/1961, Loss: 1.3202
# Epoch 1, Step 1700, Batch 1700/1961, Loss: 1.3153
# Epoch 1, Step 1710, Batch 1710/1961, Loss: 1.3106
# Epoch 1, Step 1720, Batch 1720/1961, Loss: 1.3028
# Epoch 1, Step 1730, Batch 1730/1961, Loss: 1.3137
# Epoch 1, Step 1740, Batch 1740/1961, Loss: 1.3047
# Epoch 1, Step 1750, Batch 1750/1961, Loss: 1.3053
# Epoch 1, Step 1760, Batch 1760/1961, Loss: 1.3102
# Epoch 1, Step 1770, Batch 1770/1961, Loss: 1.3218
# Epoch 1, Step 1780, Batch 1780/1961, Loss: 1.3233
# Epoch 1, Step 1790, Batch 1790/1961, Loss: 1.3008
# Epoch 1, Step 1800, Batch 1800/1961, Loss: 1.2942
# Epoch 1, Step 1810, Batch 1810/1961, Loss: 1.3229
# Epoch 1, Step 1820, Batch 1820/1961, Loss: 1.3120
# Epoch 1, Step 1830, Batch 1830/1961, Loss: 1.2922
# Epoch 1, Step 1840, Batch 1840/1961, Loss: 1.3156
# Epoch 1, Step 1850, Batch 1850/1961, Loss: 1.3003
# Epoch 1, Step 1860, Batch 1860/1961, Loss: 1.3080
# Epoch 1, Step 1870, Batch 1870/1961, Loss: 1.3161
# Epoch 1, Step 1880, Batch 1880/1961, Loss: 1.3099
# Epoch 1, Step 1890, Batch 1890/1961, Loss: 1.2939
# Epoch 1, Step 1900, Batch 1900/1961, Loss: 1.3005
# Epoch 1, Step 1910, Batch 1910/1961, Loss: 1.2935
# Epoch 1, Step 1920, Batch 1920/1961, Loss: 1.3058
# Epoch 1, Step 1930, Batch 1930/1961, Loss: 1.3142
# Epoch 1, Step 1940, Batch 1940/1961, Loss: 1.2846
# Epoch 1, Step 1950, Batch 1950/1961, Loss: 1.2894
# Epoch 1, Step 1960, Batch 1960/1961, Loss: 1.2828
# Epoch 1/1, Train Loss: 1.2884, Val Loss: 1.6566, Epoch Time: 111.62s

# %%
# Text generation using validation data
val_sample, _ = next(iter(val_loader))
start_text = ''.join([idx_to_char[idx.item()] for idx in val_sample[0][:SEQUENCE_LENGTH]])
generated_text = generate_text(trained_model, char_to_idx, idx_to_char, start_text, device)
print(f"Generated text (starting with validation data [{start_text}]):")
print("-"*50)
print(generated_text)
# Out:
# Generated text (starting with validation data [
#
# GREMIO:
# Good morrow, neighbour Baptista.
#
# BAPTISTA:
# Good morro]):
# --------------------------------------------------
#
#
# GREMIO:
# Good morrow, neighbour Baptista.
#
# BAPTISTA:
# Good morrow, a plain of a miseate,
# Stand of Bines of you: this is the lare, her cold virtue,
# That thy toxty more, your hand
# Is three themselves his. Look, more, my lord? What! let me say to
# 'end it; you be again wit in this prevation,
# To been this every give that wilt thou sworn of it.
# 3 LARDITA:
# Now, even say, I'll go;
# When I would you have follows shalt to bed.
# What is, pray you Polixene, these upliched the sore thing on
# they--the entreen lend than a golden new for merry,
# Known'd unmost will I see that

# %% [markdown]
# The generated text demonstrates that the model has learned some structure, but the coherence is still lacking.
#
# It can form character strings that resemble English but doesn’t create meaningful sentences. This is typical for early-stage character-level models, which struggle to capture long-term dependencies.

# %%
# After training a model (e.g., LSTM without RMSNorm), add its losses
add_loss_to_comparison('LSTM', train_losses_df, val_losses_df)

# %%
# Decoder Input/Output Example
sample_input, _ = next(iter(val_loader))
sample_input = sample_input[0].unsqueeze(0).to(device)  # Add batch dimension

trained_model.eval()
with torch.no_grad():
    output, _ = trained_model(sample_input)

print("\nSample Input:")
print(''.join([idx_to_char[idx.item()] for idx in sample_input[0]]))

print("\nModel Output (logits for next character prediction):")
print(output.shape)
print(output[0, 0, :10])  # Print first 10 logits of the first timestep

print("\nPredicted next character:")
predicted_char_idx = torch.argmax(output[0, -1]).item()
print(idx_to_char[predicted_char_idx])
# Out:
# Sample Input:
#
#
# GREMIO:
# Good morrow, neighbour Baptista.
#
# BAPTISTA:
# Good morro
#
# Model Output (logits for next character prediction):
# torch.Size([1, 64, 65])
# tensor([ 4.5106e+00,  2.6498e-02, -3.0894e+00, -2.7885e+00, -2.2771e+00,
#          1.2855e+00, -2.5797e+00, -8.7692e-01, -2.3546e+00, -7.2815e-04],
#        device='cuda:0')
#
# Predicted next character:
# w

# %%
# After you've added multiple models, plot the comparison
plot_loss_comparisons()

# %% [markdown]
# We now transition to the core LLaMA components.
#
# From this point, we’ll begin building the essential structures of LLaMA, starting with simple single-head attention-based decoders. We will progressively add complexity to the model, block by block, to achieve a full implementation of LLaMA 1.
#
# Here’s an overview of the steps we’ll follow to build the complete model:
#
# 1. **Single-Head Attention Decoder**:
#    - We start with a basic single-head attention mechanism to familiarize ourselves with attention layers.
#    - This will serve as a foundational block for more complex attention architectures.
#
# 2. **Positional Encoding**:
#    - To provide the model with an understanding of token order, we will add learnable positional embeddings, helping the model understand sequence order and relationships.
#
# 3. **Look-Ahead Masking**:
#    - To prevent the model from seeing future tokens during training, we’ll implement look-ahead masking, ensuring proper autoregressive behavior.
#
# 4. **Layer Normalization (LayerNorm)**:
#    - We’ll introduce LayerNorm, which stabilizes the training process by normalizing the outputs of each layer, improving convergence.
#
# 5. **RMSNorm**:
#    - Next, we’ll swap out LayerNorm with RMSNorm, a more efficient normalization technique used in LLaMA for larger model scalability and better computational efficiency.
#
# 6. **Residual Connections**:
#    - Adding residual connections to preserve important information and prevent the degradation of signals as they pass through multiple layers.
#
# 7. **Feed-Forward Networks (FFNs)**:
#    - We’ll introduce traditional feed-forward layers, followed by LLaMA’s more advanced SwiGLU activation-based feed-forward network, which allows for efficient representation mixing.
#
# 8. **Rotary Position Embedding (RoPE)**:
#    - We’ll enhance the model’s ability to capture positional information by replacing the learnable positional embeddings with Rotary Position Embedding (RoPE), improving the model’s handling of longer sequences.
#
# 9. **Multi-Head Attention (MHA)**:
#    - To scale the attention mechanism, we’ll move from single-head to multi-head attention, allowing the model to attend to multiple parts of the sequence simultaneously.
#
# 10. **Stacking Layers**:
#     - Finally, we will scale the architecture by stacking multiple layers, creating a multi-layer transformer with multi-head attention and feed-forward networks, which is the backbone of the LLaMA architecture.
#
# 11. **Final Verification**:
#     - Once all components are in place, we’ll compare our custom implementation with Hugging Face's official LLaMA 1 model, ensuring that our implementation is accurate and produces identical results in a high-precision environment.
#
# ---

# %% [markdown]
# # Simple Single-Head Attention-Based Decoder
#
# In this section, we implement a basic single-head attention mechanism as a step towards LLaMA.
#
# Attention mechanisms allow models to focus on specific parts of the input sequence when generating predictions, improving the ability to capture relationships between distant tokens.

# %%
import torch
import torch.nn.functional as F

# Single-Head Attention (Very Basic)
class SingleHeadAttention(nn.Module):
    def __init__(self, d_model, seq_length):
        super(SingleHeadAttention, self).__init__()
        self.d_model = d_model
        self.seq_length = seq_length

        self.query = nn.Linear(d_model, d_model, bias=False)
        self.key = nn.Linear(d_model, d_model, bias=False)
        self.value = nn.Linear(d_model, d_model, bias=False)
        self.fc_out = nn.Linear(d_model, d_model, bias=False)

    def forward(self, x):
        Q = self.query(x)
        K = self.key(x)
        V = self.value(x)

        # Scaled dot-product attention
        attention_scores = torch.matmul(Q, K.transpose(-2, -1)) / (self.d_model ** 0.5)

        attention_probs = F.softmax(attention_scores, dim=-1)
        attention_output = torch.matmul(attention_probs, V)

        return self.fc_out(attention_output)


# LLaMA Decoder Layer
class LLaMADecoderLayer(nn.Module):
    def __init__(self, embedding_dim, seq_length):
        super(LLaMADecoderLayer, self).__init__()
        self.attention = SingleHeadAttention(embedding_dim, seq_length)

    def forward(self, x):
        attention_output = self.attention(x)
        return attention_output


class LLaMAModel(nn.Module):
    def __init__(self, vocab_size, embedding_dim, seq_length):
        super(LLaMAModel, self).__init__()
        self.embedding = nn.Embedding(vocab_size, embedding_dim)
        self.layer = LLaMADecoderLayer(embedding_dim, seq_length)
        self.fc_out = nn.Linear(embedding_dim, vocab_size, bias=False) # lm_head

    def forward(self, idx, targets=None):
        x = self.embedding(idx)
        x = self.layer(x)
        logits = self.fc_out(x)

        if targets is not None:
            loss = F.cross_entropy(logits.view(-1, logits.size(-1)), targets.view(-1))
            return logits, loss
        return logits, None

# %% [markdown]
# For this initial implementation, we employ a simple approach to text generation using single-head attention.
#
# Although there are more sophisticated generation methods, this basic version will allow us to observe the performance of the model with attention mechanisms in place.

# %%
def generate_text_attention(model, char_to_idx, idx_to_char, start_text, device, max_length=500):
    model.eval()
    current_text = start_text

    with torch.no_grad():
        for _ in range(max_length):
            # Convert the last sequence of characters to indices and feed it to the model
            x = torch.tensor([[char_to_idx[ch] for ch in current_text[-SEQUENCE_LENGTH:]]]).to(device)
            output = model(x)[0]  # No hidden state needed for attention-based models
            probs = torch.softmax(output[0, -1], dim=0)
            next_char_idx = torch.multinomial(probs, 1).item()
            next_char = idx_to_char[next_char_idx]
            current_text += next_char

    return current_text

# %%
def train_and_test(model_desc, start_text):
    # Initialize the model
    model_llama = LLaMAModel(vocab_size, EMBEDDING_DIM, SEQUENCE_LENGTH).to(device)

    # Use the same optimizer and criterion
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model_llama.parameters(), lr=LEARNING_RATE)

    # Train the model
    trained_model, train_losses_df, val_losses_df = train_model(
        model_llama, train_loader, val_loader, criterion, optimizer, device, EPOCHS
    )

    # Generate text
    generated_text = generate_text_attention(trained_model, char_to_idx, idx_to_char, start_text, device)
    print(f"Generated text [{start_text}]:")
    print("-"*50)
    print(generated_text)

    add_loss_to_comparison(model_desc, train_losses_df, val_losses_df)

    # Plot loss comparisons including this model
    plot_loss_comparisons()

# %%
train_and_test("SHA", start_text)
# Out:
# Epoch 1/1
# Epoch 1, Step 10, Batch 10/1961, Loss: 3.1757
# Epoch 1, Step 20, Batch 20/1961, Loss: 2.8897
# Epoch 1, Step 30, Batch 30/1961, Loss: 2.7948
# Epoch 1, Step 40, Batch 40/1961, Loss: 2.7274
# Epoch 1, Step 50, Batch 50/1961, Loss: 2.6863
# Epoch 1, Step 60, Batch 60/1961, Loss: 2.6538
# Epoch 1, Step 70, Batch 70/1961, Loss: 2.6312
# Epoch 1, Step 80, Batch 80/1961, Loss: 2.5958
# Epoch 1, Step 90, Batch 90/1961, Loss: 2.5826
# Epoch 1, Step 100, Batch 100/1961, Loss: 2.5626
# Epoch 1, Step 110, Batch 110/1961, Loss: 2.5485
# Epoch 1, Step 120, Batch 120/1961, Loss: 2.5488
# Epoch 1, Step 130, Batch 130/1961, Loss: 2.5267
# Epoch 1, Step 140, Batch 140/1961, Loss: 2.5189
# Epoch 1, Step 150, Batch 150/1961, Loss: 2.4975
# Epoch 1, Step 160, Batch 160/1961, Loss: 2.4981
# Epoch 1, Step 170, Batch 170/1961, Loss: 2.4912
# Epoch 1, Step 180, Batch 180/1961, Loss: 2
# Epoch 1, Step 1300, Batch 1300/1961, Loss: 2.2509
# Epoch 1, Step 1310, Batch 1310/1961, Loss: 2.2195
# Epoch 1, Step 1320, Batch 1320/1961, Loss: 2.2297
# Epoch 1, Step 1330, Batch 1330/1961, Loss: 2.2321
# Epoch 1, Step 1340, Batch 1340/1961, Loss: 2.2232
# Epoch 1, Step 1350, Batch 1350/1961, Loss: 2.2136
# Epoch 1, Step 1360, Batch 1360/1961, Loss: 2.2285
# Epoch 1, Step 1370, Batch 1370/1961, Loss: 2.2296
# Epoch 1, Step 1380, Batch 1380/1961, Loss: 2.2284
# Epoch 1, Step 1390, Batch 1390/1961, Loss: 2.2223
# Epoch 1, Step 1400, Batch 1400/1961, Loss: 2.2292
# Epoch 1, Step 1410, Batch 1410/1961, Loss: 2.2357
# Epoch 1, Step 1420, Batch 1420/1961, Loss: 2.2347
# Epoch 1, Step 1430, Batch 1430/1961, Loss: 2.2433
# Epoch 1, Step 1440, Batch 1440/1961, Loss: 2.2323
# Epoch 1, Step 1450, Batch 1450/1961, Loss: 2.2524
# Epoch 1, Step 1460, Batch 1460/1961, Loss: 2.2281
# Epoch 1, Step 1470, Batch 1470/1961, Loss: 2.2342
# Epoch 1, Step 1480, Batch 1480/1961, Loss: 2.2300
# Epoch 1, Step 1490, Batch 1490/1961, Loss: 2.2307
# Epoch 1, Step 1500, Batch 1500/1961, Loss: 2.2339
# Epoch 1, Step 1510, Batch 1510/1961, Loss: 2.2145
# Epoch 1, Step 1520, Batch 1520/1961, Loss: 2.2358
# Epoch 1, Step 1530, Batch 1530/1961, Loss: 2.2182
# Epoch 1, Step 1540, Batch 1540/1961, Loss: 2.2240
# Epoch 1, Step 1550, Batch 1550/1961, Loss: 2.2390
# Epoch 1, Step 1560, Batch 1560/1961, Loss: 2.2368
# Epoch 1, Step 1570, Batch 1570/1961, Loss: 2.2265
# Epoch 1, Step 1580, Batch 1580/1961, Loss: 2.2314
# Epoch 1, Step 1590, Batch 1590/1961, Loss: 2.2135
# Epoch 1, Step 1600, Batch 1600/1961, Loss: 2.2254
# Epoch 1, Step 1610, Batch 1610/1961, Loss: 2.2101
# Epoch 1, Step 1620, Batch 1620/1961, Loss: 2.2418
# Epoch 1, Step 1630, Batch 1630/1961, Loss: 2.2302
# Epoch 1, Step 1640, Batch 1640/1961, Loss: 2.2240
# Epoch 1, Step 1650, Batch 1650/1961, Loss: 2.2287
# Epoch 1, Step 1660, Batch 1660/1961, Loss: 2.2267
# Epoch 1, Step 1670, Batch 1670/1961, Loss: 2.2126
# Epoch 1, Step 1680, Batch 1680/1961, Loss: 2.2309
# Epoch 1, Step 1690, Batch 1690/1961, Loss: 2.2195
# Epoch 1, Step 1700, Batch 1700/1961, Loss: 2.2213
# Epoch 1, Step 1710, Batch 1710/1961, Loss: 2.2293
# Epoch 1, Step 1720, Batch 1720/1961, Loss: 2.2152
# Epoch 1, Step 1730, Batch 1730/1961, Loss: 2.2331
# Epoch 1, Step 1740, Batch 1740/1961, Loss: 2.2276
# Epoch 1, Step 1750, Batch 1750/1961, Loss: 2.2168
# Epoch 1, Step 1760, Batch 1760/1961, Loss: 2.2344
# Epoch 1, Step 1770, Batch 1770/1961, Loss: 2.2339
# Epoch 1, Step 1780, Batch 1780/1961, Loss: 2.2294
# Epoch 1, Step 1790, Batch 1790/1961, Loss: 2.2210
# Epoch 1, Step 1800, Batch 1800/1961, Loss: 2.2095
# Epoch 1, Step 1810, Batch 1810/1961, Loss: 2.2202
# Epoch 1, Step 1820, Batch 1820/1961, Loss: 2.2185
# Epoch 1, Step 1830, Batch 1830/1961, Loss: 2.2319
# Epoch 1, Step 1840, Batch 1840/1961, Loss: 2.2078
# Epoch 1, Step 1850, Batch 1850/1961, Loss: 2.2218
# Epoch 1, Step 1860, Batch 1860/1961, Loss: 2.2314
# Epoch 1, Step 1870, Batch 1870/1961, Loss: 2.2312
# Epoch 1, Step 1880, Batch 1880/1961, Loss: 2.2096
# Epoch 1, Step 1890, Batch 1890/1961, Loss: 2.2173
# Epoch 1, Step 1900, Batch 1900/1961, Loss: 2.2178
# Epoch 1, Step 1910, Batch 1910/1961, Loss: 2.2161
# Epoch 1, Step 1920, Batch 1920/1961, Loss: 2.2261
# Epoch 1, Step 1930, Batch 1930/1961, Loss: 2.2157
# Epoch 1, Step 1940, Batch 1940/1961, Loss: 2.2202
# Epoch 1, Step 1950, Batch 1950/1961, Loss: 2.2196
# Epoch 1, Step 1960, Batch 1960/1961, Loss: 2.2155
# Epoch 1/1, Train Loss: 2.2245, Val Loss: 2.4099, Epoch Time: 87.98s
# Generated text [
#
# GREMIO:
# Good morrow, neighbour Baptista.
#
# BAPTISTA:
# Good morro]:
# --------------------------------------------------
#
#
# GREMIO:
# Good morrow, neighbour Baptista.
#
# BAPTISTA:
# Good morroud chy orrongs ss carn mar,
# wh
# I rabu din wary stund ho,
# As whis you brive! Towrs thanw? A you preid harien nate fes thand se ay denek. Yent avin I chy till per thibe noecourch,-
# Thes thig ive, sos st bra de sche eve forele tha tihs at spoif farlove tun,
# I hat thrir far jwyeimpel
# Abule hat sursameen; inneorwir!
#
# RICLARD:
# Nous, to bant the ngangor, torne haurck hopearbur, thiriel toownor thangot hso haflavinge anno the, rmayr noble narby, hath erak I trad the et Diig do'st goe bolw y'd your ordo

# %% [markdown]
# With look-ahead masking, we obtain more *realistic* performance curves. This method ensures the model no longer has access to future tokens, providing a more challenging, yet authentic, learning task. We now begin to observe the expected loss behavior.

# %% [markdown]
# ## SHA + POS + Masking + Norm(LayerNorm)
#
# Next, we introduce normalization layers into the model. Layer normalization (LayerNorm) stabilizes the training process by normalizing the output of each layer, preventing issues such as exploding or vanishing gradients. We apply LayerNorm before and after the attention mechanism and the feed-forward layer.

# %%
import torch
import torch.nn.functional as F

class SingleHeadAttention(nn.Module):
    def __init__(self, d_model, seq_length):
        super(SingleHeadAttention, self).__init__()
        self.d_model = d_model
        self.seq_length = seq_length

        self.query = nn.Linear(d_model, d_model, bias=False)
        self.key = nn.Linear(d_model, d_model, bias=False)
        self.value = nn.Linear(d_model, d_model, bias=False)
        self.fc_out = nn.Linear(d_model, d_model, bias=False)

    def forward(self, x, mask=None):
        Q = self.query(x)
        K = self.key(x)
        V = self.value(x)

        # Scaled dot-product attention
        attention_scores = torch.matmul(Q, K.transpose(-2, -1)) / (self.d_model ** 0.5)

        # look-ahead masking!
        if mask is not None:
            attention_scores = attention_scores.masked_fill(mask == 0, float('-inf'))

        attention_probs = F.softmax(attention_scores, dim=-1)
        attention_output = torch.matmul(attention_probs, V)

        return self.fc_out(attention_output)


# LLaMA Decoder Layer
class LLaMADecoderLayer(nn.Module):
    def __init__(self, embedding_dim, seq_length):
        super(LLaMADecoderLayer, self).__init__()
        self.attention = SingleHeadAttention(embedding_dim, seq_length)
        self.layernorm1 = nn.LayerNorm(embedding_dim) # pre-norm
        self.layernorm2 = nn.LayerNorm(embedding_dim) # post-norm

    def forward(self, x, mask):
        # Pre-Norm
        normed_x = self.layernorm1(x)

        # Attention
        attention_output = self.attention(normed_x, mask)

        # Post-Norm
        normed_x = self.layernorm2(attention_output)

        return x

class LLaMAModel(nn.Module):
    def __init__(self, vocab_size, embedding_dim, seq_length):
        super(LLaMAModel, self).__init__()
        self.embedding = nn.Embedding(vocab_size, embedding_dim)
        self.layer = LLaMADecoderLayer(embedding_dim, seq_length)
        self.fc_out = nn.Linear(embedding_dim, vocab_size, bias=False) # lm_head

        # final norm after top-layer
        self.layernorm3 = nn.LayerNorm(embedding_dim) # final-norm

        # Learnable Positional Embedding
        self.positional_embedding = nn.Embedding(seq_length, embedding_dim)

    def forward(self, idx, targets=None):
        x = self.embedding(idx)

        # Add positional embeddings to input embeddings
        seq_positions = torch.arange(0, x.size(1), device=x.device).unsqueeze(0)  # Create position indices
        x = x + self.positional_embedding(seq_positions)

        # Look-Ahead Masking
        seq_length = x.size(1)
        mask = torch.tril(torch.ones(seq_length, seq_length)).to(x.device)

        x = self.layer(x, mask)

        # Normalization
        x = self.layernorm3(x)

        logits = self.fc_out(x)

        if targets is not None:
            loss = F.cross_entropy(logits.view(-1, logits.size(-1)), targets.view(-1))
            return logits, loss
        return logits, None

# %%
train_and_test("SHA + POS + Masking + Norm(LayerNorm)", start_text)
# Out:
# Epoch 1/1
# Epoch 1, Step 10, Batch 10/1961, Loss: 3.7962
# Epoch 1, Step 20, Batch 20/1961, Loss: 3.3714
# Epoch 1, Step 30, Batch 30/1961, Loss: 3.0919
# Epoch 1, Step 40, Batch 40/1961, Loss: 2.8856
# Epoch 1, Step 50, Batch 50/1961, Loss: 2.7795
# Epoch 1, Step 60, Batch 60/1961, Loss: 2.7030
# Epoch 1, Step 70, Batch 70/1961, Loss: 2.6472
# Epoch 1, Step 80, Batch 80/1961, Loss: 2.5993
# Epoch 1, Step 90, Batch 90/1961, Loss: 2.5812
# Epoch 1, Step 100, Batch 100/1961, Loss: 2.5575
# Epoch 1, Step 110, Batch 110/1961, Loss: 2.5554
# Epoch 1, Step 120, Batch 120/1961, Loss: 2.5309
# Epoch 1, Step 130, Batch 130/1961, Loss: 2.5290
# Epoch 1, Step 140, Batch 140/1961, Loss: 2.5154
# Epoch 1, Step 150, Batch 150/1961, Loss: 2.5054
# Epoch 1, Step 160, Batch 160/1961, Loss: 2.5062
# Epoch 1, Step 170, Batch 170/1961, Loss: 2.5017
# Epoch 1, Step 180, Batch 180/1961, Loss: 2.5006
# Epoch 1, Step 190, Batch 190/1961, Loss: 2.4898
# Epoch 1, Step 200, Batch 200/1961, Loss: 2.4987
# Epoch 1, Step 210, Batch 210/1961, Loss: 2.4764
# Epoch 1, Step 220, Batch 220/1961, Loss: 2.4822
# Epoch 1, Step 230, Batch 230/1961, Loss: 2.4786
# Epoch 1, Step 240, Batch 240/1961, Loss: 2.4810
# Epoch 1, Step 250, Batch 250/1961, Loss: 2.4639
# Epoch 1, Step 260, Batch 260/1961, Loss: 2.4674
# Epoch 1, Step 270, Batch 270/1961, Loss: 2.4787
# Epoch 1, Step 280, Batch 280/1961, Loss: 2.4733
# Epoch 1, Step 290, Batch 290/1961, Loss: 2.4683
# Epoch 1, Step 300, Batch 300/1961, Loss: 2.4655
# Epoch 1, Step 310, Batch 310/1961, Loss: 2.4650
# Epoch 1, Step 320, Batch 320/1961, Loss: 2.4658
# Epoch 1, Step 330, Batch 330/1961, Loss: 2.4671
# Epoch 1, Step 340, Batch 340/1961, Loss: 2.4653
# Epoch 1, Step 350, Batch 350/1961, Loss: 2.4714
# Epoch 1, Step 360, Batch 360/1961, Loss: 2.4699
# Epoch 1, Step 370, Batch 370/1961, Loss: 2.4735
# Epoch 1, Step 380, Batch 380/1961, Loss: 2.4629
# Epoch 1, Step 390, Batch 390/1961, Loss: 2.4667
# Epoch 1, Step 400, Batch 400/1961, Loss: 2.4671
# Epoch 1, Step 410, Batch 410/1961, Loss: 2.4667
# Epoch 1, Step 420, Batch 420/1961, Loss: 2.4517
# Epoch 1, Step 430, Batch 430/1961, Loss: 2.4601
# Epoch 1, Step 440, Batch 440/1961, Loss: 2.4645
# Epoch 1, Step 450, Batch 450/1961, Loss: 2.4619
# Epoch 1, Step 460, Batch 460/1961, Loss: 2.4594
# Epoch 1, Step 470, Batch 470/1961, Loss: 2.4561
# Epoch 1, Step 480, Batch 480/1961, Loss: 2.4608
# Epoch 1, Step 490, Batch 490/1961, Loss: 2.4587
# Epoch 1, Step 500, Batch 500/1961, Loss: 2.4621
# Epoch 1, Step 510, Batch 510/1961, Loss: 2.4525
# Epoch 1, Step 520, Batch 520/1961, Loss: 2.4700
# Epoch 1, Step 530, Batch 530/1961, Loss: 2.4654
# Epoch 1, Step 540, Batch 540/1961, Loss: 2.4576
# Epoch 1, Step 550, Batch 550/1961, Loss: 2.4584
# Epoch 1, Step 560, Batch 560/1961, Loss: 2.4574
# Epoch 1, Step 570, Batch 570/1961, Loss: 2.4524
# Epoch 1, Step 580, Batch 580/1961, Loss: 2.4675
# Epoch 1, Step 590, Batch 590/1961, Loss: 2.4685
# Epoch 1, Step 600, Batch 600/1961, Loss: 2.4539
# Epoch 1, Step 610, Batch 610/1961, Loss: 2.4530
# Epoch 1, Step 620, Batch 620/1961, Loss: 2.4582
# Epoch 1, Step 630, Batch 630/1961, Loss: 2.4619
# Epoch 1, Step 640, Batch 640/1961, Loss: 2.4608
# Epoch 1, Step 650, Batch 650/1961, Loss: 2.4476
# Epoch 1, Step 660, Batch 660/1961, Loss: 2.4686
# Epoch 1, Step 670, Batch 670/1961, Loss: 2.4579
# Epoch 1, Step 680, Batch 680/1961, Loss: 2.4526
# Epoch 1, Step 690, Batch 690/1961, Loss: 2.4689
# Epoch 1, Step 700, Batch 700/1961, Loss: 2.4606
# Epoch 1, Step 710, Batch 710/1961, Loss: 2.4557
# Epoch 1, Step 720, Batch 720/1961, Loss: 2.4626
# Epoch 1, Step 730, Batch 730/1961, Loss: 2.4512
# Epoch 1, Step 740, Batch 740/1961, Loss: 2.4656
# Epoch 1, Step 750, Batch 750/1961, Loss: 2.4580
# Epoch 1, Step 760, Batch 760/1961, Loss: 2.4573
# Epoch 1, Step 770, Batch 770/1961, Loss: 2.4522
# Epoch 1, Step 780, Batch 780/1961, Loss: 2.4506
# Epoch 1, Step 790, Batch 790/1961, Loss: 2.4499
# Epoch 1, Step 800, Batch 800/1961, Loss: 2.4626
# Epoch 1, Step 810, Batch 810/1961, Loss: 2.4533
# Epoch 1, Step 820, Batch 820/1961, Loss: 2.4606
# Epoch 1, Step 830, Batch 830/1961, Loss: 2.4641
# Epoch 1, Step 840, Batch 840/1961, Loss: 2.4633
# Epoch 1, Step 850, Batch 850/1961, Loss: 2.4444
# Epoch 1, Step 860, Batch 860/1961, Loss: 2.4491
# Epoch 1, Step 870, Batch 870/1961, Loss: 2.4592
# Epoch 1, Step 880, Batch 880/1961, Loss: 2.4446
# Epoch 1, Step 890, Batch 890/1961, Loss: 2.4567
# Epoch 1, Step 900, Batch 900/1961, Loss: 2.4593
# Epoch 1, Step 910, Batch 910/1961, Loss: 2.4594
# Epoch 1, Step 920, Batch 920/1961, Loss: 2.4605
# Epoch 1, Step 930, Batch 930/1961, Loss: 2.4588
# Epoch 1, Step 940, Batch 940/1961, Loss: 2.4601
# Epoch 1, Step 950, Batch 950/1961, Loss: 2.4645
# Epoch 1, Step 960, Batch 960/1961, Loss: 2.4507
# Epoch 1, Step 970, Batch 970/1961, Loss: 2.4611
# Epoch 1, Step 980, Batch 980/1961, Loss: 2.4580
# Epoch 1, Step 990, Batch 990/1961, Loss: 2.4519
# Epoch 1, Step 1000, Batch 1000/1961, Loss: 2.4581
# Epoch 1, Step 1010, Batch 1010/1961, Loss: 2.4611
# Epoch 1, Step 1020, Batch 1020/1961, Loss: 2.4574
# Epoch 1, Step 1030, Batch 1030/1961, Loss: 2.4544
# Epoch 1, Step 1040, Batch 1040/1961, Loss: 2.4686
# Epoch 1, Step 1050, Batch 1050/1961, Loss: 2.4658
# Epoch 1, Step 1060, Batch 1060/1961, Loss: 2.4626
# Epoch 1, Step 1070, Batch 1070/1961, Loss: 2.4517
# Epoch 1, Step 1080, Batch 1080/1961, Loss: 2.4520
# Epoch 1, Step 1090, Batch 1090/1961, Loss: 2.4567
# Epoch 1, Step 1100, Batch 1100/1961, Loss: 2.4666
# Epoch 1, Step 1110, Batch 1110/1961, Loss: 2.4554
# Epoch 1, Step 1120, Batch 1120/1961, Loss: 2.4519
# Epoch 1, Step 1130, Batch 1130/1961, Loss: 2.4619
# Epoch 1, Step 1140, Batch 1140/1961, Loss: 2.4571
# Epoch 1, Step 1150, Batch 1150/1961, Loss: 2.4442
# Epoch 1, Step 1160, Batch 1160/1961, Loss: 2.4536
# Epoch 1, Step 1170, Batch 1170/1961, Loss: 2.4506
# Epoch 1, Step 1180, Batch 1180/1961, Loss: 2.4565
# Epoch 1, Step 1190, Batch 1190/1961, Loss: 2.4508
# Epoch 1, Step 1200, Batch 1200/1961, Loss: 2.4613
# Epoch 1, Step 1210, Batch 1210/1961, Loss: 2.4610
# Epoch 1, Step 1220, Batch 1220/1961, Loss: 2.4596
# Epoch 1, Step 1230, Batch 1230/1961, Loss: 2.4570
# Epoch 1, Step 1240, Batch 1240/1961, Loss: 2.4514
# Epoch 1, Step 1250, Batch 1250/1961, Loss: 2.4656
# Epoch 1, Step 1260, Batch 1260/1961, Loss: 2.4572
# Epoch 1, Step 1270, Batch 1270/1961, Loss: 2.4502
# Epoch 1, Step 1280, Batch 1280/1961, Loss: 2.4557
# Epoch 1, Step 1290, Batch 1290/1961, Loss: 2.4540
# Epoch 1, Step 1300, Batch 1300/1961, Loss: 2.4642
# Epoch 1, Step 1310, Batch 1310/1961, Loss: 2.4570
# Epoch 1, Step 1320, Batch 1320/1961, Loss: 2.4436
# Epoch 1, Step 1330, Batch 1330/1961, Loss: 2.4505
# Epoch 1, Step 1340, Batch 1340/1961, Loss: 2.4494
# Epoch 1, Step 1350, Batch 1350/1961, Loss: 2.4628
# Epoch 1, Step 1360, Batch 1360/1961, Loss: 2.4611
# Epoch 1, Step 1370, Batch 1370/1961, Loss: 2.4595
# Epoch 1, Step 1380, Batch 1380/1961, Loss: 2.4636
# Epoch 1, Step 1390, Batch 1390/1961, Loss: 2.4575
# Epoch 1, Step 1400, Batch 1400/1961, Loss: 2.4591
# Epoch 1, Step 1410, Batch 1410/1961, Loss: 2.4469
# Epoch 1, Step 1420, Batch 1420/1961, Loss: 2.4583
# Epoch 1, Step 1430, Batch 1430/1961, Loss: 2.4618
# Epoch 1, Step 1440, Batch 1440/1961, Loss: 2.4598
# Epoch 1, Step 1450, Batch 1450/1961, Loss: 2.4479
# Epoch 1, Step 1460, Batch 1460/1961, Loss: 2.4545
# Epoch 1, Step 1470, Batch 1470/1961, Loss: 2.4534
# Epoch 1, Step 1480, Batch 1480/1961, Loss: 2.4544
# Epoch 1, Step 1490, Batch 1490/1961, Loss: 2.4619
# Epoch 1, Step 1500, Batch 1500/1961, Loss: 2.4537
# Epoch 1, Step 1510, Batch 1510/1961, Loss: 2.4645
# Epoch 1, Step 1520, Batch 1520/1961, Loss: 2.4507
# Epoch 1, Step 1530, Batch 1530/1961, Loss: 2.4637
# Epoch 1, Step 1540, Batch 1540/1961, Loss: 2.4739
# Epoch 1, Step 1550, Batch 1550/1961, Loss: 2.4578
# Epoch 1, Step 1560, Batch 1560/1961, Loss: 2.4641
# Epoch 1, Step 1570, Batch 1570/1961, Loss: 2.4592
# Epoch 1, Step 1580, Batch 1580/1961, Loss: 2.4574
# Epoch 1, Step 1590, Batch 1590/1961, Loss: 2.4462
# Epoch 1, Step 1600, Batch 1600/1961, Loss: 2.4530
# Epoch 1, Step 1610, Batch 1610/1961, Loss: 2.4644
# Epoch 1, Step 1620, Batch 1620/1961, Loss: 2.4586
# Epoch 1, Step 1630, Batch 1630/1961, Loss: 2.4572
# Epoch 1, Step 1640, Batch 1640/1961, Loss: 2.4552
# Epoch 1, Step 1650, Batch 1650/1961, Loss: 2.4496
# Epoch 1, Step 1660, Batch 1660/1961, Loss: 2.4522
# Epoch 1, Step 1670, Batch 1670/1961, Loss: 2.4628
# Epoch 1, Step 1680, Batch 1680/1961, Loss: 2.4646
# Epoch 1, Step 1690, Batch 1690/1961, Loss: 2.4615
# Epoch 1, Step 1700, Batch 1700/1961, Loss: 2.4609
# Epoch 1, Step 1710, Batch 1710/1961, Loss: 2.4534
# Epoch 1, Step 1720, Batch 1720/1961, Loss: 2.4681
# Epoch 1, Step 1730, Batch 1730/1961, Loss: 2.4509
# Epoch 1, Step 1740, Batch 1740/1961, Loss: 2.4599
# Epoch 1, Step 1750, Batch 1750/1961, Loss: 2.4521
# Epoch 1, Step 1760, Batch 1760/1961, Loss: 2.4548
# Epoch 1, Step 1770, Batch 1770/1961, Loss: 2.4585
# Epoch 1, Step 1780, Batch 1780/1961, Loss: 2.4490
# Epoch 1, Step 1790, Batch 1790/1961, Loss: 2.4623
# Epoch 1, Step 1800, Batch 1800/1961, Loss: 2.4555
# Epoch 1, Step 1810, Batch 1810/1961, Loss: 2.4478
# Epoch 1, Step 1820, Batch 1820/1961, Loss: 2.4604
# Epoch 1, Step 1830, Batch 1830/1961, Loss: 2.4437
# Epoch 1, Step 1840, Batch 1840/1961, Loss: 2.4557
# Epoch 1, Step 1850, Batch 1850/1961, Loss: 2.4567
# Epoch 1, Step 1860, Batch 1860/1961, Loss: 2.4546
# Epoch 1, Step 1870, Batch 1870/1961, Loss: 2.4574
# Epoch 1, Step 1880, Batch 1880/1961, Loss: 2.4432
# Epoch 1, Step 1890, Batch 1890/1961, Loss: 2.4566
# Epoch 1, Step 1900, Batch 1900/1961, Loss: 2.4478
# Epoch 1, Step 1910, Batch 1910/1961, Loss: 2.4482
# Epoch 1, Step 1920, Batch 1920/1961, Loss: 2.4549
# Epoch 1, Step 1930, Batch 1930/1961, Loss: 2.4608
# Epoch 1, Step 1940, Batch 1940/1961, Loss: 2.4553
# Epoch 1, Step 1950, Batch 1950/1961, Loss: 2.4556
# Epoch 1, Step 1960, Batch 1960/1961, Loss: 2.4425
# Epoch 1/1, Train Loss: 2.4572, Val Loss: 2.5621, Epoch Time: 86.27s
# Generated text [
#
# GREMIO:
# Good morrow, neighbour Baptista.
#
# BAPTISTA:
# Good morro]:
# --------------------------------------------------
#
#
# GREMIO:
# Good morrow, neighbour Baptista.
#
# BAPTISTA:
# Good morroutolaved os wh moiels?
# Winde
# BUSantemele ce G blonerusthy mopapliuser,
# D uleneseailfaticharean rerifo as br.
# CEESceat o atou ove he pay bomaivebr meby f d ir sce nche co hes t,
# S: sis Ourd bet y ld:
#
#
# Whthevese
# Th bandeat dak mathoreack mpar, thikines l oleve bugam hil withas ulwhakever bithe co dr.
# GByour I tharonthay y? Thaindithe netourd.
# AUSllocropl.
# Folll r th therthaw in ailir!
# SThesurdeay pe.
# Tod br acepee wit:
# Teeom'? mas.
# D uthe.
# K:
# Busthe me.
# ORI
# I:
# Ty
# I fare brak wilousor! t as, nda o

# %% [markdown]
# ## SHA + POS + Masking + Norm(RMSNorm)

# %% [markdown]
# RMSNorm is a variation of LayerNorm that is more efficient for certain architectures, such as LLaMA. Instead of normalizing across all dimensions, it normalizes only across the root mean square of the dimensions, improving stability in large models. We now replace LayerNorm with RMSNorm for comparison.

# %%
import torch
import torch.nn.functional as F

class SingleHeadAttention(nn.Module):
    def __init__(self, d_model, seq_length):
        super(SingleHeadAttention, self).__init__()
        self.d_model = d_model
        self.seq_length = seq_length

        self.query = nn.Linear(d_model, d_model, bias=False)
        self.key = nn.Linear(d_model, d_model, bias=False)
        self.value = nn.Linear(d_model, d_model, bias=False)
        self.fc_out = nn.Linear(d_model, d_model, bias=False)

    def forward(self, x, mask=None):
        Q = self.query(x)
        K = self.key(x)
        V = self.value(x)

        # Scaled dot-product attention
        attention_scores = torch.matmul(Q, K.transpose(-2, -1)) / (self.d_model ** 0.5)

        # look-ahead masking!
        if mask is not None:
            attention_scores = attention_scores.masked_fill(mask == 0, float('-inf'))

        attention_probs = F.softmax(attention_scores, dim=-1)
        attention_output = torch.matmul(attention_probs, V)

        return self.fc_out(attention_output)


# Custom RMSNorm to match LLaMA 1 official implementation
class RMSNorm(nn.Module):
    def __init__(self, d_model, eps=1e-6):
        super(RMSNorm, self).__init__()
        self.weight = nn.Parameter(torch.ones(d_model))
        self.eps = eps

    def _norm(self, x):
        # Compute variance and apply reciprocal square root for RMS normalization
        return x * torch.rsqrt(x.pow(2).mean(-1, keepdim=True) + self.eps)

    def forward(self, x):
        # Convert to float32 for precision, then back to original dtype
        output = self._norm(x.float()).type_as(x)
        return output * self.weight


# LLaMA Decoder Layer
class LLaMADecoderLayer(nn.Module):
    def __init__(self, embedding_dim, seq_length):
        super(LLaMADecoderLayer, self).__init__()
        self.attention = SingleHeadAttention(embedding_dim, seq_length)
        self.rmsnorm1 = RMSNorm(embedding_dim) # pre-norm
        self.rmsnorm2 = RMSNorm(embedding_dim) # post-norm

    def forward(self, x, mask):
        # Pre-Norm
        normed_x = self.rmsnorm1(x)

        # Attention
        attention_output = self.attention(normed_x, mask)

        # Post-Norm
        normed_x = self.rmsnorm2(attention_output)

        return normed_x

class LLaMAModel(nn.Module):
    def __init__(self, vocab_size, embedding_dim, seq_length):
        super(LLaMAModel, self).__init__()
        self.embedding = nn.Embedding(vocab_size, embedding_dim)
        self.layer = LLaMADecoderLayer(embedding_dim, seq_length)
        self.fc_out = nn.Linear(embedding_dim, vocab_size, bias=False) # lm_head

        self.rmsnorm_f = RMSNorm(embedding_dim) # final_norm

        # Learnable Positional Embedding
        self.positional_embedding = nn.Embedding(seq_length, embedding_dim)

    def forward(self, idx, targets=None):
        x = self.embedding(idx)

        # Add positional embeddings to input embeddings
        seq_positions = torch.arange(0, x.size(1), device=x.device).unsqueeze(0)  # Create position indices
        x = x + self.positional_embedding(seq_positions)

        # Look-Ahead Masking
        seq_length = x.size(1)
        mask = torch.tril(torch.ones(seq_length, seq_length)).to(x.device)

        x = self.layer(x, mask)

        # final norm
        x = self.rmsnorm_f(x)

        logits = self.fc_out(x)

        if targets is not None:
            loss = F.cross_entropy(logits.view(-1, logits.size(-1)), targets.view(-1))
            return logits, loss
        return logits, None

# %%
train_and_test("SHA + POS + Masking + Norm(RMSNorm)", start_text)
# Out:
# Epoch 1/1
# Epoch 1, Step 10, Batch 10/1961, Loss: 3.0573
# Epoch 1, Step 20, Batch 20/1961, Loss: 2.8206
# Epoch 1, Step 30, Batch 30/1961, Loss: 2.7107
# Epoch 1, Step 40, Batch 40/1961, Loss: 2.6608
# Epoch 1, Step 50, Batch 50/1961, Loss: 2.6151
# Epoch 1, Step 60, Batch 60/1961, Loss: 2.5616
# Epoch 1, Step 70, Batch 70/1961, Loss: 2.5386
# Epoch 1, Step 80, Batch 80/1961, Loss: 2.4700
# Epoch 1, Step 90, Batch 90/1961, Loss: 2.4322
# Epoch 1, Step 100, Batch 100/1961, Loss: 2.4000
# Epoch 1, Step 110, Batch 110/1961, Loss: 2.3589
# Epoch 1, Step 120, Batch 120/1961, Loss: 2.3514
# Epoch 1, Step 130, Batch 130/1961, Loss: 2.3268
# Epoch 1, Step 140, Batch 140/1961, Loss: 2.3283
# Epoch 1, Step 150, Batch 150/1961, Loss: 2.3080
# Epoch 1, Step 160, Batch 160/1961, Loss: 2.3097
# Epoch 1, Step 170, Batch 170/1961, Loss: 2.3032
# Epoch 1, Step 180, Batch 180/1961, Loss: 2.2942
# Epoch 1, Step 190, Batch 190/1961, Loss: 2.2882
# Epoch 1, Step 200, Batch 200/1961, Loss: 2.2819
# Epoch 1, Step 210, Batch 210/1961, Loss: 2.2911
# Epoch 1, Step 220, Batch 220/1961, Loss: 2.2676
# Epoch 1, Step 230, Batch 230/1961, Loss: 2.2750
# Epoch 1, Step 240, Batch 240/1961, Loss: 2.2670
# Epoch 1, Step 250, Batch 250/1961, Loss: 2.2660
# Epoch 1, Step 260, Batch 260/1961, Loss: 2.2660
# Epoch 1, Step 270, Batch 270/1961, Loss: 2.2661
# Epoch 1, Step 280, Batch 280/1961, Loss: 2.2634
# Epoch 1, Step 290, Batch 290/1961, Loss: 2.2650
# Epoch 1, Step 300, Batch 300/1961, Loss: 2.2683
# Epoch 1, Step 310, Batch 310/1961, Loss: 2.2499
# Epoch 1, Step 320, Batch 320/1961, Loss: 2.2490
# Epoch 1, Step 330, Batch 330/1961, Loss: 2.2428
# Epoch 1, Step 340, Batch 340/1961, Loss: 2.2569
# Epoch 1, Step 350, Batch 350/1961, Loss: 2.2467
# Epoch 1, Step 360, Batch 360/1961, Loss: 2.2507
# Epoch 1, Step 370, Batch 370/1961, Loss: 2.2436
# Epoch 1, Step 380, Batch 380/1961, Loss: 2.2561
# Epoch 1, Step 390, Batch 390/1961, Loss: 2.2488
# Epoch 1, Step 400, Batch 400/1961, Loss: 2.2309
# Epoch 1, Step 410, Batch 410/1961, Loss: 2.2393
# Epoch 1, Step 420, Batch 420/1961, Loss: 2.2318
# Epoch 1, Step 430, Batch 430/1961, Loss: 2.2457
# Epoch 1, Step 440, Batch 440/1961, Loss: 2.2294
# Epoch 1, Step 450, Batch 450/1961, Loss: 2.2513
# Epoch 1, Step 460, Batch 460/1961, Loss: 2.2233
# Epoch 1, Step 470, Batch 470/1961, Loss: 2.2305
# Epoch 1, Step 480, Batch 480/1961, Loss: 2.2297
# Epoch 1, Step 490, Batch 490/1961, Loss: 2.2443
# Epoch 1, Step 500, Batch 500/1961, Loss: 2.2313
# Epoch 1, Step 510, Batch 510/1961, Loss: 2.2274
# Epoch 1, Step 520, Batch 520/1961, Loss: 2.2333
# Epoch 1, Step 530, Batch 530/1961, Loss: 2.2428
# Epoch 1, Step 540, Batch 540/1961, Loss: 2.2344
# Epoch 1, Step 550, Batch 550/1961, Loss: 2.2240
# Epoch 1, Step 560, Batch 560/1961, Loss: 2.2086
# Epoch 1, Step 570, Batch 570/1961, Loss: 2.2379
# Epoch 1, Step 580, Batch 580/1961, Loss: 2.2209
# Epoch 1, Step 590, Batch 590/1961, Loss: 2.2275
# Epoch 1, Step 600, Batch 600/1961, Loss: 2.2411
# Epoch 1, Step 610, Batch 610/1961, Loss: 2.2263
# Epoch 1, Step 620, Batch 620/1961, Loss: 2.2309
# Epoch 1, Step 630, Batch 630/1961, Loss: 2.2310
# Epoch 1, Step 640, Batch 640/1961, Loss: 2.2226
# Epoch 1, Step 650, Batch 650/1961, Loss: 2.2305
# Epoch 1, Step 660, Batch 660/1961, Loss: 2.2061
# Epoch 1, Step 670, Batch 670/1961, Loss: 2.2192
# Epoch 1, Step 680, Batch 680/1961, Loss: 2.2223
# Epoch 1, Step 690, Batch 690/1961, Loss: 2.2165
# Epoch 1, Step 700, Batch 700/1961, Loss: 2.2274
# Epoch 1, Step 710, Batch 710/1961, Loss: 2.2307
# Epoch 1, Step 720, Batch 720/1961, Loss: 2.2165
# Epoch 1, Step 730, Batch 730/1961, Loss: 2.2292
# Epoch 1, Step 740, Batch 740/1961, Loss: 2.2297
# Epoch 1, Step 750, Batch 750/1961, Loss: 2.2211
# Epoch 1, Step 760, Batch 760/1961, Loss: 2.2189
# Epoch 1, Step 770, Batch 770/1961, Loss: 2.2128
# Epoch 1, Step 780, Batch 780/1961, Loss: 2.2138
# Epoch 1, Step 790, Batch 790/1961, Loss: 2.2157
# Epoch 1, Step 800, Batch 800/1961, Loss: 2.2171
# Epoch 1, Step 810, Batch 810/1961, Loss: 2.2097
# Epoch 1, Step 820, Batch 820/1961, Loss: 2.2010
# Epoch 1, Step 830, Batch 830/1961, Loss: 2.1941
# Epoch 1, Step 840, Batch 840/1961, Loss: 2.1946
# Epoch 1, Step 850, Batch 850/1961, Loss: 2.2161
# Epoch 1, Step 860, Batch 860/1961, Loss: 2.2180
# Epoch 1, Step 870, Batch 870/1961, Loss: 2.2218
# Epoch 1, Step 880, Batch 880/1961, Loss: 2.2109
# Epoch 1, Step 890, Batch 890/1961, Loss: 2.2209
# Epoch 1, Step 900, Batch 900/1961, Loss: 2.2179
# Epoch 1, Step 910, Batch 910/1961, Loss: 2.2043
# Epoch 1, Step 920, Batch 920/1961, Loss: 2.2164
# Epoch 1, Step 930, Batch 930/1961, Loss: 2.1969
# Epoch 1, Step 940, Batch 940/1961, Loss: 2.2051
# Epoch 1, Step 950, Batch 950/1961, Loss: 2.2005
# Epoch 1, Step 960, Batch 960/1961, Loss: 2.2044
# Epoch 1, Step 970, Batch 970/1961, Loss: 2.1947
# Epoch 1, Step 980, Batch 980/1961, Loss: 2.2067
# Epoch 1, Step 990, Batch 990/1961, Loss: 2.2243
# Epoch 1, Step 1000, Batch 1000/1961, Loss: 2.2137
# Epoch 1, Step 1010, Batch 1010/1961, Loss: 2.2129
# Epoch 1, Step 1020, Batch 1020/1961, Loss: 2.2107
# Epoch 1, Step 1030, Batch 1030/1961, Loss: 2.2064
# Epoch 1, Step 1040, Batch 1040/1961, Loss: 2.2177
# Epoch 1, Step 1050, Batch 1050/1961, Loss: 2.2134
# Epoch 1, Step 1060, Batch 1060/1961, Loss: 2.2104
# Epoch 1, Step 1070, Batch 1070/1961, Loss: 2.2065
# Epoch 1, Step 1080, Batch 1080/1961, Loss: 2.1929
# Epoch 1, Step 1090, Batch 1090/1961, Loss: 2.2030
# Epoch 1, Step 1100, Batch 1100/1961, Loss: 2.2051
# Epoch 1, Step 1110, Batch 1110/1961, Loss: 2.2066
# Epoch 1, Step 1120, Batch 1120/1961, Loss: 2.1982
# Epoch 1, Step 1130, Batch 1130/1961, Loss: 2.2084
# Epoch 1, Step 1140, Batch 1140/1961, Loss: 2.2024
# Epoch 1, Step 1150, Batch 1150/1961, Loss: 2.1943
# Epoch 1, Step 1160, Batch 1160/1961, Loss: 2.2073
# Epoch 1, Step 1170, Batch 1170/1961, Loss: 2.2030
# Epoch 1, Step 1180, Batch 1180/1961, Loss: 2.2121
# Epoch 1, Step 1190, Batch 1190/1961, Loss: 2.2066
# Epoch 1, Step 1200, Batch 1200/1961, Loss: 2.2244
# Epoch 1, Step 1210, Batch 1210/1961, Loss: 2.1932
# Epoch 1, Step 1220, Batch 1220/1961, Loss: 2.1844
# Epoch 1, Step 1230, Batch 1230/1961, Loss: 2.1928
# Epoch 1, Step 1240, Batch 1240/1961, Loss: 2.2061
# Epoch 1, Step 1250, Batch 1250/1961, Loss: 2.1955
# Epoch 1, Step 1260, Batch 1260/1961, Loss: 2.1952
# Epoch 1, Step 1270, Batch 1270/1961, Loss: 2.1960
# Epoch 1, Step 1280, Batch 1280/1961, Loss: 2.2051
# Epoch 1, Step 1290, Batch 1290/1961, Loss: 2.1990
# Epoch 1, Step 1300, Batch 1300/1961, Loss: 2.2108
# Epoch 1, Step 1310, Batch 1310/1961, Loss: 2.1934
# Epoch 1, Step 1320, Batch 1320/1961, Loss: 2.2009
# Epoch 1, Step 1330, Batch 1330/1961, Loss: 2.2116
# Epoch 1, Step 1340, Batch 1340/1961, Loss: 2.2124
# Epoch 1, Step 1350, Batch 1350/1961, Loss: 2.2169
# Epoch 1, Step 1360, Batch 1360/1961, Loss: 2.2053
# Epoch 1, Step 1370, Batch 1370/1961, Loss: 2.2093
# Epoch 1, Step 1380, Batch 1380/1961, Loss: 2.2039
# Epoch 1, Step 1390, Batch 1390/1961, Loss: 2.1957
# Epoch 1, Step 1400, Batch 1400/1961, Loss: 2.1964
# Epoch 1, Step 1410, Batch 1410/1961, Loss: 2.1984
# Epoch 1, Step 1420, Batch 1420/1961, Loss: 2.1990
# Epoch 1, Step 1430, Batch 1430/1961, Loss: 2.2151
# Epoch 1, Step 1440, Batch 1440/1961, Loss: 2.2000
# Epoch 1, Step 1450, Batch 1450/1961, Loss: 2.2084
# Epoch 1, Step 1460, Batch 1460/1961, Loss: 2.2004
# Epoch 1, Step 1470, Batch 1470/1961, Loss: 2.1880
# Epoch 1, Step 1480, Batch 1480/1961, Loss: 2.2122
# Epoch 1, Step 1490, Batch 1490/1961, Loss: 2.2027
# Epoch 1, Step 1500, Batch 1500/1961, Loss: 2.1831
# Epoch 1, Step 1510, Batch 1510/1961, Loss: 2.2007
# Epoch 1, Step 1520, Batch 1520/1961, Loss: 2.1920
# Epoch 1, Step 1530, Batch 1530/1961, Loss: 2.1958
# Epoch 1, Step 1540, Batch 1540/1961, Loss: 2.1842
# Epoch 1, Step 1550, Batch 1550/1961, Loss: 2.2015
# Epoch 1, Step 1560, Batch 1560/1961, Loss: 2.2091
# Epoch 1, Step 1570, Batch 1570/1961, Loss: 2.1948
# Epoch 1, Step 1580, Batch 1580/1961, Loss: 2.1940
# Epoch 1, Step 1590, Batch 1590/1961, Loss: 2.2017
# Epoch 1, Step 1600, Batch 1600/1961, Loss: 2.1924
# Epoch 1, Step 1610, Batch 1610/1961, Loss: 2.1961
# Epoch 1, Step 1620, Batch 1620/1961, Loss: 2.1899
# Epoch 1, Step 1630, Batch 1630/1961, Loss: 2.2033
# Epoch 1, Step 1640, Batch 1640/1961, Loss: 2.2048
# Epoch 1, Step 1650, Batch 1650/1961, Loss: 2.1985
# Epoch 1, Step 1660, Batch 1660/1961, Loss: 2.2021
# Epoch 1, Step 1670, Batch 1670/1961, Loss: 2.1922
# Epoch 1, Step 1680, Batch 1680/1961, Loss: 2.1941
# Epoch 1, Step 1690, Batch 1690/1961, Loss: 2.2055
# Epoch 1, Step 1700, Batch 1700/1961, Loss: 2.1994
# Epoch 1, Step 1710, Batch 1710/1961, Loss: 2.1950
# Epoch 1, Step 1720, Batch 1720/1961, Loss: 2.1883
# Epoch 1, Step 1730, Batch 1730/1961, Loss: 2.1983
# Epoch 1, Step 1740, Batch 1740/1961, Loss: 2.1880
# Epoch 1, Step 1750, Batch 1750/1961, Loss: 2.1985
# Epoch 1, Step 1760, Batch 1760/1961, Loss: 2.1860
# Epoch 1, Step 1770, Batch 1770/1961, Loss: 2.1913
# Epoch 1, Step 1780, Batch 1780/1961, Loss: 2.2032
# Epoch 1, Step 1790, Batch 1790/1961, Loss: 2.1988
# Epoch 1, Step 1800, Batch 1800/1961, Loss: 2.2011
# Epoch 1, Step 1810, Batch 1810/1961, Loss: 2.2010
# Epoch 1, Step 1820, Batch 1820/1961, Loss: 2.1985
# Epoch 1, Step 1830, Batch 1830/1961, Loss: 2.2005
# Epoch 1, Step 1840, Batch 1840/1961, Loss: 2.2100
# Epoch 1, Step 1850, Batch 1850/1961, Loss: 2.1916
# Epoch 1, Step 1860, Batch 1860/1961, Loss: 2.1819
# Epoch 1, Step 1870, Batch 1870/1961, Loss: 2.1908
# Epoch 1, Step 1880, Batch 1880/1961, Loss: 2.1991
# Epoch 1, Step 1890, Batch 1890/1961, Loss: 2.1958
# Epoch 1, Step 1900, Batch 1900/1961, Loss: 2.2088
# Epoch 1, Step 1910, Batch 1910/1961, Loss: 2.2106
# Epoch 1, Step 1920, Batch 1920/1961, Loss: 2.1915
# Epoch 1, Step 1930, Batch 1930/1961, Loss: 2.2097
# Epoch 1, Step 1940, Batch 1940/1961, Loss: 2.1996
# Epoch 1, Step 1950, Batch 1950/1961, Loss: 2.1877
# Epoch 1, Step 1960, Batch 1960/1961, Loss: 2.1996
# Epoch 1/1, Train Loss: 2.1937, Val Loss: 2.4086, Epoch Time: 107.46s
# Generated text [
#
# GREMIO:
# Good morrow, neighbour Baptista.
#
# BAPTISTA:
# Good morro]:
# --------------------------------------------------
#
#
# GREMIO:
# Good morrow, neighbour Baptista.
#
# BAPTISTA:
# Good morrouss!
# 'Tis pran oull er if by le breerdu rigu like come
# Saf whit kin, se on boer thes an
# Ddo a go make?
#
# CIO ut paree heras wiere:
# it Ricnot Hir theonpefa witem ty, low aice for: therdenad, a
# thin tryo nocaveve,
# On, onwoleabecor: erat do puat,
# Ayu! hime, neifron dan aws' llt my ded like
# 'TR it ty Mady ss lef
# Hancore redn uto:
# Konull det,
# And uds thers at alid Rarm:
# I ay do, you tli tto stheir ay thyo wearim, ome sof whe,
# Theresfo tinglo st withlal ndist seer ce torud owrisl far'lei thoenam wel th

# %% [markdown]
# While RMSNorm hasn't shown a large improvement at this stage, it is expected to have a more significant impact on larger models.
#
# Its effectiveness becomes more pronounced as the model size and complexity increase. We'll see its benefits in later stages with more advanced architectures.

# %% [markdown]
# ## SHA + POS + Masking + Norm(RMSNorm) + Residual

# %%
import torch
import torch.nn.functional as F

class SingleHeadAttention(nn.Module):
    def __init__(self, d_model, seq_length):
        super(SingleHeadAttention, self).__init__()
        self.d_model = d_model
        self.seq_length = seq_length

        self.query = nn.Linear(d_model, d_model, bias=False)
        self.key = nn.Linear(d_model, d_model, bias=False)
        self.value = nn.Linear(d_model, d_model, bias=False)
        self.fc_out = nn.Linear(d_model, d_model, bias=False)

    def forward(self, x, mask=None):
        Q = self.query(x)
        K = self.key(x)
        V = self.value(x)

        # Scaled dot-product attention
        attention_scores = torch.matmul(Q, K.transpose(-2, -1)) / (self.d_model ** 0.5)

        # look-ahead masking!
        if mask is not None:
            attention_scores = attention_scores.masked_fill(mask == 0, float('-inf'))

        attention_probs = F.softmax(attention_scores, dim=-1)
        attention_output = torch.matmul(attention_probs, V)

        return self.fc_out(attention_output)


# Custom RMSNorm to match LLaMA 1 official implementation
class RMSNorm(nn.Module):
    def __init__(self, d_model, eps=1e-6):
        super(RMSNorm, self).__init__()
        self.weight = nn.Parameter(torch.ones(d_model))
        self.eps = eps

    def _norm(self, x):
        # Compute variance and apply reciprocal square root for RMS normalization
        return x * torch.rsqrt(x.pow(2).mean(-1, keepdim=True) + self.eps)

    def forward(self, x):
        # Convert to float32 for precision, then back to original dtype
        output = self._norm(x.float()).type_as(x)
        return output * self.weight


# LLaMA Decoder Layer
class LLaMADecoderLayer(nn.Module):
    def __init__(self, embedding_dim, seq_length):
        super(LLaMADecoderLayer, self).__init__()
        self.attention = SingleHeadAttention(embedding_dim, seq_length)
        self.rmsnorm1 = RMSNorm(embedding_dim) # pre-norm
        self.rmsnorm2 = RMSNorm(embedding_dim) # post-norm

    def forward(self, x, mask):

        # Pre-Norm
        normed_x = self.rmsnorm1(x)

        # Attention
        attention_output = self.attention(normed_x, mask)

        # Residual connection
        x = x + attention_output

        # Post-Norm
        normed_x = self.rmsnorm2(x)

        return x + normed_x

class LLaMAModel(nn.Module):
    def __init__(self, vocab_size, embedding_dim, seq_length):
        super(LLaMAModel, self).__init__()
        self.embedding = nn.Embedding(vocab_size, embedding_dim)
        self.layer = LLaMADecoderLayer(embedding_dim, seq_length)
        self.fc_out = nn.Linear(embedding_dim, vocab_size, bias=False) # lm_head

        self.rmsnorm_f = RMSNorm(embedding_dim) # final_norm

        # Learnable Positional Embedding
        self.positional_embedding = nn.Embedding(seq_length, embedding_dim)

    def forward(self, idx, targets=None):
        x = self.embedding(idx)

        # Add positional embeddings to input embeddings
        seq_positions = torch.arange(0, x.size(1), device=x.device).unsqueeze(0)  # Create position indices
        x = x + self.positional_embedding(seq_positions)

        # Look-Ahead Masking
        seq_length = x.size(1)
        mask = torch.tril(torch.ones(seq_length, seq_length)).to(x.device)

        x = self.layer(x, mask)

        # final norm
        x = self.rmsnorm_f(x)

        logits = self.fc_out(x)

        if targets is not None:
            loss = F.cross_entropy(logits.view(-1, logits.size(-1)), targets.view(-1))
            return logits, loss
        return logits, None

# %%
train_and_test("SHA + POS + Masking + Norm(RMSNorm) + Residual", start_text)
# Out:
# Epoch 1/1
# Epoch 1, Step 10, Batch 10/1961, Loss: 3.2192
# Epoch 1, Step 20, Batch 20/1961, Loss: 2.9672
# Epoch 1, Step 30, Batch 30/1961, Loss: 2.8241
# Epoch 1, Step 40, Batch 40/1961, Loss: 2.7008
# Epoch 1, Step 50, Batch 50/1961, Loss: 2.6395
# Epoch 1, Step 60, Batch 60/1961, Loss: 2.5958
# Epoch 1, Step 70, Batch 70/1961, Loss: 2.5403
# Epoch 1, Step 80, Batch 80/1961, Loss: 2.4947
# Epoch 1, Step 90, Batch 90/1961, Loss: 2.4439
# Epoch 1, Step 100, Batch 100/1961, Loss: 2.4176
# Epoch 1, Step 110, Batch 110/1961, Loss: 2.3787
# Epoch 1, Step 120, Batch 120/1961, Loss: 2.3386
# Epoch 1, Step 130, Batch 130/1961, Loss: 2.3304
# Epoch 1, Step 140, Batch 140/1961, Loss: 2.3023
# Epoch 1, Step 150, Batch 150/1961, Loss: 2.2686
# Epoch 1, Step 160, Batch 160/1961, Loss: 2.2597
# Epoch 1, Step 170, Batch 170/1961, Loss: 2.2583
# Epoch 1, Step 180, Batch 180/1961, Loss: 2.2451
# Epoch 1, Step 190, Batch 190/1961, Loss: 2.2141
# Epoch 1, Step 200, Batch 200/1961, Loss: 2.2058
# Epoch 1, Step 210, Batch 210/1961, Loss: 2.2077
# Epoch 1, Step 220, Batch 220/1961, Loss: 2.2014
# Epoch 1, Step 230, Batch 230/1961, Loss: 2.1672
# Epoch 1, Step 240, Batch 240/1961, Loss: 2.1612
# Epoch 1, Step 250, Batch 250/1961, Loss: 2.1782
# Epoch 1, Step 260, Batch 260/1961, Loss: 2.1592
# Epoch 1, Step 270, Batch 270/1961, Loss: 2.1584
# Epoch 1, Step 280, Batch 280/1961, Loss: 2.1523
# Epoch 1, Step 290, Batch 290/1961, Loss: 2.1358
# Epoch 1, Step 300, Batch 300/1961, Loss: 2.1532
# Epoch 1, Step 310, Batch 310/1961, Loss: 2.1327
# Epoch 1, Step 320, Batch 320/1961, Loss: 2.1516
# I'll sins das, dime,
# An it Dorey eas--
#
# AUDIIO: I live tet myser ery; yeret hir's
# O!
#
# QUEEN MERCAMARINCENTA:

# %% [markdown]
# Residual connections help prevent the degradation of information as it passes through multiple layers.
#
# By adding the input directly to the output of certain layers (e.g., attention and feed-forward layers), we ensure that important information isn't lost during the transformation process.

# %% [markdown]
# ## SHA + POS + Masking + RMSNorm + Residual + FeedForward(Original)

# %% [markdown]
# In the original transformer architecture, the feed-forward network consisted of a simple projection up to a higher dimensional space, followed by a projection back down. Typically, the up-projection dimension is four times the input dimension. This basic feed-forward architecture provides powerful feature mixing.

# %%
import torch
import torch.nn.functional as F

class SingleHeadAttention(nn.Module):
    def __init__(self, d_model, seq_length):
        super(SingleHeadAttention, self).__init__()
        self.d_model = d_model
        self.seq_length = seq_length

        self.query = nn.Linear(d_model, d_model, bias=False)
        self.key = nn.Linear(d_model, d_model, bias=False)
        self.value = nn.Linear(d_model, d_model, bias=False)
        self.fc_out = nn.Linear(d_model, d_model, bias=False)

    def forward(self, x, mask=None):
        Q = self.query(x)
        K = self.key(x)
        V = self.value(x)

        # Scaled dot-product attention
        attention_scores = torch.matmul(Q, K.transpose(-2, -1)) / (self.d_model ** 0.5)

        # look-ahead masking!
        if mask is not None:
            attention_scores = attention_scores.masked_fill(mask == 0, float('-inf'))

        attention_probs = F.softmax(attention_scores, dim=-1)
        attention_output = torch.matmul(attention_probs, V)

        return self.fc_out(attention_output)


# Custom RMSNorm to match LLaMA 1 official implementation
class RMSNorm(nn.Module):
    def __init__(self, d_model, eps=1e-6):
        super(RMSNorm, self).__init__()
        self.weight = nn.Parameter(torch.ones(d_model))
        self.eps = eps

    def _norm(self, x):
        # Compute variance and apply reciprocal square root for RMS normalization
        return x * torch.rsqrt(x.pow(2).mean(-1, keepdim=True) + self.eps)

    def forward(self, x):
        # Convert to float32 for precision, then back to original dtype
        output = self._norm(x.float()).type_as(x)
        return output * self.weight

# Original Feed-Forward Network
class FeedForward(nn.Module):
    def __init__(self, d_model):
        super(FeedForward, self).__init__()
        up_hidden_dim = d_model * 4
        self.up_proj = nn.Linear(d_model, up_hidden_dim, bias=False)
        self.down_proj = nn.Linear(up_hidden_dim, d_model, bias=False)
        self.act_fn = F.relu

    def forward(self, x):
        return self.down_proj(self.act_fn(self.up_proj(x)))

# LLaMA Decoder Layer
class LLaMADecoderLayer(nn.Module):
    def __init__(self, embedding_dim, seq_length):
        super(LLaMADecoderLayer, self).__init__()
        self.attention = SingleHeadAttention(embedding_dim, seq_length)
        self.rmsnorm1 = RMSNorm(embedding_dim) # pre-norm
        self.rmsnorm2 = RMSNorm(embedding_dim) # post-norm
        self.feed_forward = FeedForward(embedding_dim)

    def forward(self, x, mask):
        # Pre-Norm
        normed_x = self.rmsnorm1(x)

        # Attention
        attention_output = self.attention(normed_x, mask)

        # Residual connection
        x = x + attention_output

        # Post-Norm
        normed_x = self.rmsnorm2(x)

        feed_forward_output = self.feed_forward(normed_x)

        # Residual Connection
        return x + feed_forward_output

class LLaMAModel(nn.Module):
    def __init__(self, vocab_size, embedding_dim, seq_length):
        super(LLaMAModel, self).__init__()
        self.embedding = nn.Embedding(vocab_size, embedding_dim)
        self.layer = LLaMADecoderLayer(embedding_dim, seq_length)
        self.fc_out = nn.Linear(embedding_dim, vocab_size, bias=False) # lm_head

        self.rmsnorm_f = RMSNorm(embedding_dim) # final_norm

        # Learnable Positional Embedding
        self.positional_embedding = nn.Embedding(seq_length, embedding_dim)

    def forward(self, idx, targets=None):
        x = self.embedding(idx)

        # Add positional embeddings to input embeddings
        seq_positions = torch.arange(0, x.size(1), device=x.device).unsqueeze(0)  # Create position indices
        x = x + self.positional_embedding(seq_positions)

        # Look-Ahead Masking
        seq_length = x.size(1)
        mask = torch.tril(torch.ones(seq_length, seq_length)).to(x.device)

        x = self.layer(x, mask)

        # final norm
        x = self.rmsnorm_f(x)

        logits = self.fc_out(x)

        if targets is not None:
            loss = F.cross_entropy(logits.view(-1, logits.size(-1)), targets.view(-1))
            return logits, loss
        return logits, None

# %%
train_and_test("SHA + POS + Masking + RMSNorm + Residual + FF(Original) ", start_text)
# Out:
# Epoch 1/1
# Epoch 1, Step 10, Batch 10/1961, Loss: 3.0100
# Epoch 1, Step 20, Batch 20/1961, Loss: 2.7564
# Epoch 1, Step 30, Batch 30/1961, Loss: 2.6229
# Epoch 1, Step 40, Batch 40/1961, Loss: 2.5604
# Epoch 1, Step 50, Batch 50/1961, Loss: 2.5260
# Epoch 1, Step 60, Batch 60/1961, Loss: 2.4579
# Epoch 1, Step 70, Batch 70/1961, Loss: 2.4031
# Epoch 1, Step 80, Batch 80/1961, Loss: 2.3308
# Epoch 1, Step 90, Batch 90/1961, Loss: 2.2587
# Epoch 1, Step 100, Batch 100/1961, Loss: 2.2289
# Epoch 1, Step 110, Batch 110/1961, Loss: 2.1898
# Epoch 1, Step 120, Batch 120/1961, Loss: 2.1578
# Epoch 1, Step 130, Batch 130/1961, Loss: 2.1322
# Epoch 1, Step 140, Batch 140/1961, Loss: 2.1020
# Epoch 1, Step 150, Batch 150/1961, Loss: 2.0634
# Epoch 1, Step 160, Batch 160/1961, Loss: 2.0564
# Epoch 1, Step 170, Batch 170/1961, Loss: 2.0422
# Epoch 1, Step 180, Batch 180/1961, Loss: 2.0239
# Epoch 1, Step 190, Batch 190/1961, Loss: 2.0235
# Epoch 1, Step 200, Batch 200/1961, Loss: 1.9974
# Epoch 1, Step 210, Batch 210/1961, Loss: 1.9623
# Epoch 1, Step 220, Batch 220/1961, Loss: 1.9417
# Epoch 1, Step 230, Batch 230/1961, Loss: 1.9435
# Epoch 1, Step 240, Batch 240/1961, Loss: 1.9091
# Epoch 1, Step 250, Batch 250/1961, Loss: 1.9010
# Epoch 1, Step 260, Batch 260/1961, Loss: 1.8959
# Epoch 1, Step 270, Batch 270/1961, Loss: 1.8898
# Epoch 1, Step 280, Batch 280/1961, Loss: 1.8749
# Epoch 1, Step 290, Batch 290/1961, Loss: 1.8837
# Epoch 1, Step 300, Batch 300/1961, Loss: 1.8656
# Epoch 1, Step 310, Batch 310/1961, Loss: 1.8228
# Epoch 1, Step 320, Batch 320/1961, Loss: 1.8270
# Epoch 1, Step 330, Batch 330/1961, Loss: 1.8171
# Epoch 1, Step 340, Batch 340/1961, Loss: 1.7958
# Epoch 1, Step 350, Batch 350/1961, Loss: 1.7879
# Epoch 1, Step 360, Batch 360/1961, Loss: 1.7968
# Epoch 1, Step 370, Batch 370/1961, Loss: 1.7864
# Epoch 1, Step 380, Batch 380/1961, Loss: 1.7787
# Epoch 1, Step 390, Batch 390/1961, Loss: 1.7511
# Epoch 1, Step 400, Batch 400/1961, Loss: 1.7510
# Epoch 1, Step 410, Batch 410/1961, Loss: 1.7616
# Epoch 1, Step 420, Batch 420/1961, Loss: 1.7691
# Epoch 1, Step 430, Batch 430/1961, Loss: 1.7455
# Epoch 1, Step 440, Batch 440/1961, Loss: 1.7348
# Epoch 1, Step 450, Batch 450/1961, Loss: 1.7255
# Epoch 1, Step 460, Batch 460/1961, Loss: 1.7155
# Epoch 1, Step 470, Batch 470/1961, Loss: 1.6967
# Epoch 1, Step 480, Batch 480/1961, Loss: 1.7130
# Epoch 1, Step 490, Batch 490/1961, Loss: 1.7078
# Epoch 1, Step 500, Batch 500/1961, Loss: 1.7018
# Epoch 1, Step 510, Batch 510/1961, Loss: 1.7014
# Epoch 1, Step 520, Batch 520/1961, Loss: 1.6859
# Epoch 1, Step 530, Batch 530/1961, Loss: 1.7051
# Epoch 1, Step 540, Batch 540/1961, Loss: 1.6670
# Epoch 1, Step 550, Batch 550/1961, Loss: 1.6901
# Epoch 1, Step 560, Batch 560/1961, Loss: 1.6700
# Epoch 1, Step 570, Batch 570/1961, Loss: 1.6750
# Epoch 1, Step 580, Batch 580/1961, Loss: 1.6651
# Epoch 1, Step 590, Batch 590/1961, Loss: 1.6576
# Epoch 1, Step 600, Batch 600/1961, Loss: 1.6411
# Epoch 1, Step 610, Batch 610/1961, Loss: 1.6472
# Epoch 1, Step 620, Batch 620/1961, Loss: 1.6560
# Epoch 1, Step 630, Batch 630/1961, Loss: 1.6461
# Epoch 1, Step 640, Batch 640/1961, Loss: 1.6312
# Epoch 1, Step 650, Batch 650/1961, Loss: 1.6540
# Epoch 1, Step 660, Batch 660/1961, Loss: 1.6418
# Epoch 1, Step 670, Batch 670/1961, Loss: 1.6305
# Epoch 1, Step 680, Batch 680/1961, Loss: 1.6227
# Epoch 1, Step 690, Batch 690/1961, Loss: 1.6419
# Epoch 1, Step 700, Batch 700/1961, Loss: 1.6153
# Epoch 1, Step 710, Batch 710/1961, Loss: 1.6023
# Epoch 1, Step 720, Batch 720/1961, Loss: 1.6089
# Epoch 1, Step 730, Batch 730/1961, Loss: 1.6415
# Epoch 1, Step 740, Batch 740/1961, Loss: 1.6148
# Epoch 1, Step 750, Batch 750/1961, Loss: 1.6214
# Epoch 1, Step 760, Batch 760/1961, Loss: 1.5998
# Epoch 1, Step 770, Batch 770/1961, Loss: 1.5958
# Epoch 1, Step 780, Batch 780/1961, Loss: 1.6020
# Epoch 1, Step 790, Batch 790/1961, Loss: 1.5882
# Epoch 1, Step 800, Batch 800/1961, Loss: 1.5905
# Epoch 1, Step 810, Batch 810/1961, Loss: 1.5802
# Epoch 1, Step 820, Batch 820/1961, Loss: 1.5928
# Epoch 1, Step 830, Batch 830/1961, Loss: 1.5887
# Epoch 1, Step 840, Batch 840/1961, Loss: 1.5845
# Epoch 1, Step 850, Batch 850/1961, Loss: 1.5681
# Epoch 1, Step 860, Batch 860/1961, Loss: 1.5750
# Epoch 1, Step 870, Batch 870/1961, Loss: 1.5938
# Epoch 1, Step 880, Batch 880/1961, Loss: 1.5592
# Epoch 1, Step 890, Batch 890/1961, Loss: 1.5678
# Epoch 1, Step 900, Batch 900/1961, Loss: 1.5735
# Epoch 1, Step 910, Batch 910/1961, Loss: 1.5530
# Epoch 1, Step 920, Batch 920/1961, Loss: 1.5755
# Epoch 1, Step 930, Batch 930/1961, Loss: 1.5636
# Epoch 1, Step 940, Batch 940/1961, Loss: 1.5717
# Epoch 1, Step 950, Batch 950/1961, Loss: 1.5665
# Epoch 1, Step 960, Batch 960/1961, Loss: 1.5537
# Epoch 1, Step 970, Batch 970/1961, Loss: 1.5533
# Epoch 1, Step 980, Batch 980/1961, Loss: 1.5693
# Epoch 1, Step 990, Batch 990/1961, Loss: 1.5606
# Epoch 1, Step 1000, Batch 1000/1961, Loss: 1.5409
# Epoch 1, Step 1010, Batch 1010/1961, Loss: 1.5590
# Epoch 1, Step 1020, Batch 1020/1961, Loss: 1.5497
# Epoch 1, Step 1030, Batch 1030/1961, Loss: 1.5395
# Epoch 1, Step 1040, Batch 1040/1961, Loss: 1.5342
# Epoch 1, Step 1050, Batch 1050/1961, Loss: 1.5520
# Epoch 1, Step 1060, Batch 1060/1961, Loss: 1.5431
# Epoch 1, Step 1070, Batch 1070/1961, Loss: 1.5522
# Epoch 1, Step 1080, Batch 1080/1961, Loss: 1.5267
# Epoch 1, Step 1090, Batch 1090/1961, Loss: 1.5307
# Epoch 1, Step 1100, Batch 1100/1961, Loss: 1.5199
# Epoch 1, Step 1110, Batch 1110/1961, Loss: 1.5239
# Epoch 1, Step 1120, Batch 1120/1961, Loss: 1.5234
# Epoch 1, Step 1130, Batch 1130/1961, Loss: 1.5409
# Epoch 1, Step 1140, Batch 1140/1961, Loss: 1.5157
# Epoch 1, Step 1150, Batch 1150/1961, Loss: 1.5177
# Epoch 1, Step 1160, Batch 1160/1961, Loss: 1.5197
# Epoch 1, Step 1170, Batch 1170/1961, Loss: 1.5322
# Epoch 1, Step 1180, Batch 1180/1961, Loss: 1.5498
# Epoch 1, Step 1190, Batch 1190/1961, Loss: 1.5339
# Epoch 1, Step 1200, Batch 1200/1961, Loss: 1.5180
# Epoch 1, Step 1210, Batch 1210/1961, Loss: 1.5191
# Epoch 1, Step 1220, Batch 1220/1961, Loss: 1.5410
# Epoch 1, Step 1230, Batch 1230/1961, Loss: 1.5370
# Epoch 1, Step 1240, Batch 1240/1961, Loss: 1.5165
# Epoch 1, Step 1250, Batch 1250/1961, Loss: 1.5269
# Epoch 1, Step 1260, Batch 1260/1961, Loss: 1.5209
# Epoch 1, Step 1270, Batch 1270/1961, Loss: 1.5143
# Epoch 1, Step 1280, Batch 1280/1961, Loss: 1.5311
# Epoch 1, Step 1290, Batch 1290/1961, Loss: 1.5283
# Epoch 1, Step 1300, Batch 1300/1961, Loss: 1.5181
# Epoch 1, Step 1310, Batch 1310/1961, Loss: 1.5097
# Epoch 1, Step 1320, Batch 1320/1961, Loss: 1.5342
# Epoch 1, Step 1330, Batch 1330/1961, Loss: 1.4934
# Epoch 1, Step 1340, Batch 1340/1961, Loss: 1.4974
# Epoch 1, Step 1350, Batch 1350/1961, Loss: 1.5202
# Epoch 1, Step 1360, Batch 1360/1961, Loss: 1.5004
# Epoch 1, Step 1370, Batch 1370/1961, Loss: 1.5076
# Epoch 1, Step 1380, Batch 1380/1961, Loss: 1.5114
# Epoch 1, Step 1390, Batch 1390/1961, Loss: 1.4966
# Epoch 1, Step 1400, Batch 1400/1961, Loss: 1.4933
# Epoch 1, Step 1410, Batch 1410/1961, Loss: 1.4993
# Epoch 1, Step 1420, Batch 1420/1961, Loss: 1.5104
# Epoch 1, Step 1430, Batch 1430/1961, Loss: 1.4922
# Epoch 1, Step 1440, Batch 1440/1961, Loss: 1.4873
# Epoch 1, Step 1450, Batch 1450/1961, Loss: 1.4959
# Epoch 1, Step 1460, Batch 1460/1961, Loss: 1.4944
# Epoch 1, Step 1470, Batch 1470/1961, Loss: 1.4989
# Epoch 1, Step 1480, Batch 1480/1961, Loss: 1.5038
# Epoch 1, Step 1490, Batch 1490/1961, Loss: 1.4914
# Epoch 1, Step 1500, Batch 1500/1961, Loss: 1.5046
# Epoch 1, Step 1510, Batch 1510/1961, Loss: 1.4831
# Epoch 1, Step 1520, Batch 1520/1961, Loss: 1.4982
# Epoch 1, Step 1530, Batch 1530/1961, Loss: 1.4887
# Epoch 1, Step 1540, Batch 1540/1961, Loss: 1.4862
# Epoch 1, Step 1550, Batch 1550/1961, Loss: 1.5072
# Epoch 1, Step 1560, Batch 1560/1961, Loss: 1.4880
# Epoch 1, Step 1570, Batch 1570/1961, Loss: 1.4911
# Epoch 1, Step 1580, Batch 1580/1961, Loss: 1.4825
# Epoch 1, Step 1590, Batch 1590/1961, Loss: 1.4932
# Epoch 1, Step 1600, Batch 1600/1961, Loss: 1.4925
# Epoch 1, Step 1610, Batch 1610/1961, Loss: 1.4863
# Epoch 1, Step 1620, Batch 1620/1961, Loss: 1.4692
# Epoch 1, Step 1630, Batch 1630/1961, Loss: 1.4982
# Epoch 1, Step 1640, Batch 1640/1961, Loss: 1.4963
# Epoch 1, Step 1650, Batch 1650/1961, Loss: 1.4780
# Epoch 1, Step 1660, Batch 1660/1961, Loss: 1.4728
# Epoch 1, Step 1670, Batch 1670/1961, Loss: 1.4803
# Epoch 1, Step 1680, Batch 1680/1961, Loss: 1.4655
# Epoch 1, Step 1690, Batch 1690/1961, Loss: 1.4814
# Epoch 1, Step 1700, Batch 1700/1961, Loss: 1.4855
# Epoch 1, Step 1710, Batch 1710/1961, Loss: 1.4703
# Epoch 1, Step 1720, Batch 1720/1961, Loss: 1.4718
# Epoch 1, Step 1730, Batch 1730/1961, Loss: 1.4815
# Epoch 1, Step 1740, Batch 1740/1961, Loss: 1.4626
# Epoch 1, Step 1750, Batch 1750/1961, Loss: 1.4868
# Epoch 1, Step 1760, Batch 1760/1961, Loss: 1.4891
# Epoch 1, Step 1770, Batch 1770/1961, Loss: 1.4758
# Epoch 1, Step 1780, Batch 1780/1961, Loss: 1.4825
# Epoch 1, Step 1790, Batch 1790/1961, Loss: 1.4681
# Epoch 1, Step 1800, Batch 1800/1961, Loss: 1.4928
# Epoch 1, Step 1810, Batch 1810/1961, Loss: 1.4677
# Epoch 1, Step 1820, Batch 1820/1961, Loss: 1.4718
# Epoch 1, Step 1830, Batch 1830/1961, Loss: 1.4847
# Epoch 1, Step 1840, Batch 1840/1961, Loss: 1.4738
# Epoch 1, Step 1850, Batch 1850/1961, Loss: 1.4688
# Epoch 1, Step 1860, Batch 1860/1961, Loss: 1.4775
# Epoch 1, Step 1870, Batch 1870/1961, Loss: 1.4639
# Epoch 1, Step 1880, Batch 1880/1961, Loss: 1.4591
# Epoch 1, Step 1890, Batch 1890/1961, Loss: 1.4722
# Epoch 1, Step 1900, Batch 1900/1961, Loss: 1.4864
# Epoch 1, Step 1910, Batch 1910/1961, Loss: 1.4867
# Epoch 1, Step 1920, Batch 1920/1961, Loss: 1.4884
# Epoch 1, Step 1930, Batch 1930/1961, Loss: 1.4810
# Epoch 1, Step 1940, Batch 1940/1961, Loss: 1.4716
# Epoch 1, Step 1950, Batch 1950/1961, Loss: 1.4805
# Epoch 1, Step 1960, Batch 1960/1961, Loss: 1.4553
# Epoch 1/1, Train Loss: 1.4739, Val Loss: 1.9781, Epoch Time: 160.95s
# Generated text [
#
# GREMIO:
# Good morrow, neighbour Baptista.
#
# BAPTISTA:
# Good morro]:
# --------------------------------------------------
#
#
# GREMIO:
# Good morrow, neighbour Baptista.
#
# BAPTISTA:
# Good morrown, revenge of heart
# In horses vate the Lord Master, sirs are not have my shall her father,
# Madam, but soon'd with heaven, son so;
# For Pompey, not love's matter
# To seeing Edward bring
# That this credertaines
# Advine man-trute enjoy.
# Spower:
# A qued, brother of reason'd forble
# joys with is theeld full soot let word.
# I gread miseez are it fires, I child buy move look
# Ageancest, he thou were to-need makedom at,
# And chis vitors: lover, who she aloney.
#
# ESCALUS:
# Imay:
# And I will him kiss thee? tis.
#
# LEO

# %% [markdown]
# Introducing the feed-forward network brings the performance closer to that of the LSTM model. The network now has a mechanism for better mixing information across dimensions, resulting in improved predictions.

# %% [markdown]
# ```
# # 코드로 형식 지정됨
# ```
#
# ## SHA + POS + Masking + RMSNorm + Residual + FeedForward(Implicit Gating)
#
# LLaMA uses a more advanced feed-forward mechanism called SwiGLU, which incorporates implicit gating and SiLU activations. This design is more efficient in handling non-linearities and enhances model expressiveness. We will now switch to this feed-forward method to observe its impact.

# %%
import torch
import torch.nn.functional as F

class SingleHeadAttention(nn.Module):
    def __init__(self, d_model, seq_length):
        super(SingleHeadAttention, self).__init__()
        self.d_model = d_model
        self.seq_length = seq_length

        self.query = nn.Linear(d_model, d_model, bias=False)
        self.key = nn.Linear(d_model, d_model, bias=False)
        self.value = nn.Linear(d_model, d_model, bias=False)
        self.fc_out = nn.Linear(d_model, d_model, bias=False)

    def forward(self, x, mask=None):
        Q = self.query(x)
        K = self.key(x)
        V = self.value(x)

        # Scaled dot-product attention
        attention_scores = torch.matmul(Q, K.transpose(-2, -1)) / (self.d_model ** 0.5)

        # look-ahead masking!
        if mask is not None:
            attention_scores = attention_scores.masked_fill(mask == 0, float('-inf'))

        attention_probs = F.softmax(attention_scores, dim=-1)
        attention_output = torch.matmul(attention_probs, V)

        return self.fc_out(attention_output)


# Custom RMSNorm to match LLaMA 1 official implementation
class RMSNorm(nn.Module):
    def __init__(self, d_model, eps=1e-6):
        super(RMSNorm, self).__init__()
        self.weight = nn.Parameter(torch.ones(d_model))
        self.eps = eps

    def _norm(self, x):
        # Compute variance and apply reciprocal square root for RMS normalization
        return x * torch.rsqrt(x.pow(2).mean(-1, keepdim=True) + self.eps)

    def forward(self, x):
        # Convert to float32 for precision, then back to original dtype
        output = self._norm(x.float()).type_as(x)
        return output * self.weight

# Feed-Forward Network with implicit gating
import math
class FeedForward(nn.Module):
    def __init__(self, d_model, multiple_of):
        super(FeedForward, self).__init__()
        up_hidden_dim = multiple_of * math.ceil((d_model * 4 * 2 / 3) / multiple_of)
        ###### self.gate_proj, self.up_proj, self.down_proj 정의 ######
        self.gate_proj = nn.Linear(d_model, up_hidden_dim, bias=False)
        self.up_proj = nn.Linear(d_model, up_hidden_dim, bias=False)
        self.down_proj = nn.Linear(up_hidden_dim, d_model, bias=False)
        self.act_fn = F.silu  # SiLU activation

    def forward(self, x):
        ### feedforward 작성 ###
        return self.down_proj(self.act_fn(self.gate_proj(x)) * self.up_proj(x))

# LLaMA Decoder Layer
class LLaMADecoderLayer(nn.Module):
    def __init__(self, embedding_dim, multiple_of, seq_length):
        super(LLaMADecoderLayer, self).__init__()
        self.attention = SingleHeadAttention(embedding_dim, seq_length)
        self.rmsnorm1 = RMSNorm(embedding_dim) # pre-norm
        self.rmsnorm2 = RMSNorm(embedding_dim) # post-norm

        self.feed_forward = FeedForward(embedding_dim, multiple_of)


    def forward(self, x, mask):
        # Pre-Norm
        normed_x = self.rmsnorm1(x)

        # Attention
        attention_output = self.attention(normed_x, mask)

        # Residual connection
        x = x + attention_output

        # Post-Norm
        normed_x = self.rmsnorm2(x)

        feed_forward_output = self.feed_forward(normed_x)

        # Residual Connection
        return x + feed_forward_output


class LLaMAModel(nn.Module):
    def __init__(self, vocab_size, embedding_dim, seq_length, multiple_of):
        super(LLaMAModel, self).__init__()
        self.embedding = nn.Embedding(vocab_size, embedding_dim)
        self.layer = LLaMADecoderLayer(embedding_dim, multiple_of, seq_length)
        self.fc_out = nn.Linear(embedding_dim, vocab_size, bias=False) # lm_head

        self.rmsnorm_f = RMSNorm(embedding_dim) # final_norm

        # Learnable Positional Embedding
        self.positional_embedding = nn.Embedding(seq_length, embedding_dim)


    def forward(self, idx, targets=None):
        x = self.embedding(idx)

        # Add positional embeddings to input embeddings
        seq_positions = torch.arange(0, x.size(1), device=x.device).unsqueeze(0)  # Create position indices
        x = x + self.positional_embedding(seq_positions)

        # Look-Ahead Masking
        seq_length = x.size(1)
        mask = torch.tril(torch.ones(seq_length, seq_length)).to(x.device)

        x = self.layer(x, mask)

        # final norm
        x = self.rmsnorm_f(x)

        logits = self.fc_out(x)

        if targets is not None:
            loss = F.cross_entropy(logits.view(-1, logits.size(-1)), targets.view(-1))
            return logits, loss
        return logits, None

# %%
def train_and_test(model_desc, start_text, multiple_of):
    # Initialize the model
    model_llama = LLaMAModel(vocab_size, EMBEDDING_DIM, SEQUENCE_LENGTH, multiple_of).to(device)

    # Use the same optimizer and criterion
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model_llama.parameters(), lr=LEARNING_RATE)

    # Train the model
    trained_model, train_losses_df, val_losses_df = train_model(
        model_llama, train_loader, val_loader, criterion, optimizer, device, EPOCHS
    )

    # Generate text
    generated_text = generate_text_attention(trained_model, char_to_idx, idx_to_char, start_text, device)
    print(f"Generated text [{start_text}]:")
    print("-"*50)
    print(generated_text)

    add_loss_to_comparison(model_desc, train_losses_df, val_losses_df)

    # Plot loss comparisons including this model
    plot_loss_comparisons()

# %% [markdown]
# In the LLaMA 1 implementation, the up-projection dimension is not simply calculated as 4 times the hidden dimension, as seen in the original transformers. Instead, LLaMA uses a more efficient approach where the up-projection dimension is a multiple of a specific value, often 256, to optimize for GPU performance.
#
# The formula for calculating the up-projection dimension is as follows:
#
# $$
# up\_hidden\_dim = multiple\_of \times \left\lceil \frac{hidden\_dim \times 4 \times \frac{2}{3}}{multiple\_of} \right\rceil
# $$
#
# For example, if the hidden dimension is 4096 and the `multiple_of` value is 256, the calculation is:
#
# $$
# up\_hidden\_dim = 256 \times \left\lceil \frac{4096 \times 4 \times \frac{2}{3}}{256} \right\rceil
# $$
#
# This results in:
#
# $$
# up\_hidden\_dim = 256 \times \left\lceil \frac{10922.6667}{256} \right\rceil = 256 \times 43 = 11008
# $$
#
# #### Why use `multiple_of = 256`?
#
# - **GPU Efficiency**:
#   - Modern hardware like GPUs and TPUs are optimized for matrix operations when the tensor dimensions are multiples of powers of 2, such as 32, 64, 128, or 256.
#   - Rounding dimensions to multiples of 256 ensures memory alignment and maximizes parallel processing efficiency, reducing wasted memory bandwidth and improving throughput during matrix computations.
#
# In this example, instead of using LLaMA 1's typical value of 256 for `multiple_of`, we use a smaller value, such as 8, for demonstration purposes. This allows us to explore the architecture with limited computational resources while maintaining the structure of the model.

# %%
multiple_of = 8   # roughly dim * 1/16
train_and_test("SHA + POS + Masking + RMSNorm + Residual + FF(SwiGLU)", start_text, multiple_of)
# Out:
# Epoch 1/1
# Epoch 1, Step 10, Batch 10/1961, Loss: 2.9900
# Epoch 1, Step 20, Batch 20/1961, Loss: 2.7009
# Epoch 1, Step 30, Batch 30/1961, Loss: 2.5738
# Epoch 1, Step 40, Batch 40/1961, Loss: 2.5315
# Epoch 1, Step 50, Batch 50/1961, Loss: 2.4765
# Epoch 1, Step 60, Batch 60/1961, Loss: 2.4605
# Epoch 1, Step 70, Batch 70/1961, Loss: 2.4359
# Epoch 1, Step 80, Batch 80/1961, Loss: 2.3903
# Epoch 1, Step 90, Batch 90/1961, Loss: 2.3218
# Epoch 1, Step 100, Batch 100/1961, Loss: 2.2605
# Epoch 1, Step 110, Batch 110/1961, Loss: 2.2016
# Epoch 1, Step 120, Batch 120/1961, Loss: 2.1566
# Epoch 1, Step 130, Batch 130/1961, Loss: 2.1041
# Epoch 1, Step 140, Batch 140/1961, Loss: 2.0781
# Epoch 1, Step 150, Batch 150/1961, Loss: 2.0372
# Epoch 1, Step 160, Batch 160/1961, Loss: 2.0275
# Epoch 1, Step 170, Batch 170/1961, Loss: 1.9886
# Epoch 1, Step 180, Batch 180/1961, Loss: 1.9604
# Epoch 1, Step 190, Batch 190/1961, Loss: 1.9352
# Epoch 1, Step 200, Batch 200/1961, Loss: 1.9176
# Epoch 1, Step 210, Batch 210/1961, Loss: 1.9025
# Epoch 1, Step 220, Batch 220/1961, Loss: 1.8906
# Epoch 1, Step 230, Batch 230/1961, Loss: 1.8649
# Epoch 1, Step 240, Batch 240/1961, Loss: 1.8441
# Epoch 1, Step 250, Batch 250/1961, Loss: 1.8526
# Epoch 1, Step 260, Batch 260/1961, Loss: 1.8255
# Epoch 1, Step 270, Batch 270/1961, Loss: 1.8131
# Epoch 1, Step 280, Batch 280/1961, Loss: 1.8143
# Epoch 1, Step 290, Batch 290/1961, Loss: 1.8086
# Epoch 1, Step 300, Batch 300/1961, Loss: 1.7988
# Epoch 1, Step 310, Batch 310/1961, Loss: 1.7614
# Epoch 1, Step 320, Batch 320/1961, Loss: 1.7551
# Epoch 1, Step 330, Batch 330/1961, Loss: 1.7250
# Epoch 1, Step 340, Batch 340/1961, Loss: 1.7397
# Epoch 1, Step 350, Batch 350/1961, Loss: 1.7380
# Epoch 1, Step 360, Batch 360/1961, Loss: 1.7114
# Epoch 1, Step 370, Batch 370/1961, Loss: 1.7018
# Epoch 1, Step 380, Batch 380/1961, Loss: 1.7121
# Epoch 1, Step 390, Batch 390/1961, Loss: 1.6889
# Epoch 1, Step 400, Batch 400/1961, Loss: 1.7069
# Epoch 1, Step 410, Batch 410/1961, Loss: 1.6841
# Epoch 1, Step 420, Batch 420/1961, Loss: 1.6837
# Epoch 1, Step 430, Batch 430/1961, Loss: 1.6587
# Epoch 1, Step 440, Batch 440/1961, Loss: 1.6719
# Epoch 1, Step 450, Batch 450/1961, Loss: 1.6464
# Epoch 1, Step 460, Batch 460/1961, Loss: 1.6461
# Epoch 1, Step 470, Batch 470/1961, Loss: 1.6399
# Epoch 1, Step 480, Batch 480/1961, Loss: 1.6372
# Epoch 1, Step 490, Batch 490/1961, Loss: 1.6326
# Epoch 1, Step 500, Batch 500/1961, Loss: 1.6259
# Epoch 1, Step 510, Batch 510/1961, Loss: 1.6336
# Epoch 1, Step 520, Batch 520/1961, Loss: 1.6248
# Epoch 1, Step 530, Batch 530/1961, Loss: 1.6007
# Epoch 1, Step 540, Batch 540/1961, Loss: 1.5952
# Epoch 1, Step 550, Batch 550/1961, Loss: 1.6099
# Epoch 1, Step 560, Batch 560/1961, Loss: 1.5916
# Epoch 1, Step 570, Batch 570/1961, Loss: 1.6079
# Epoch 1, Step 580, Batch 580/1961, Loss: 1.5916
# Epoch 1, Step 590, Batch 590/1961, Loss: 1.5895
# Epoch 1, Step 600, Batch 600/1961, Loss: 1.5884
# Epoch 1, Step 610, Batch 610/1961, Loss: 1.5786
# Epoch 1, Step 620, Batch 620/1961, Loss: 1.5655
# Epoch 1, Step 630, Batch 630/1961, Loss: 1.5646
# Epoch 1, Step 640, Batch 640/1961, Loss: 1.5749
# Epoch 1, Step 650, Batch 650/1961, Loss: 1.5797
# Epoch 1, Step 660, Batch 660/1961, Loss: 1.5712
# Epoch 1, Step 670, Batch 670/1961, Loss: 1.5596
# Epoch 1, Step 680, Batch 680/1961, Loss: 1.5617
# Epoch 1, Step 690, Batch 690/1961, Loss: 1.5776
# Epoch 1, Step 700, Batch 700/1961, Loss: 1.5401
# Epoch 1, Step 710, Batch 710/1961, Loss: 1.5370
# Epoch 1, Step 720, Batch 720/1961, Loss: 1.5423
# Epoch 1, Step 730, Batch 730/1961, Loss: 1.5451
# Epoch 1, Step 740, Batch 740/1961, Loss: 1.5322
# Epoch 1, Step 750, Batch 750/1961, Loss: 1.5588
# Epoch 1, Step 760, Batch 760/1961, Loss: 1.5511
# Epoch 1, Step 770, Batch 770/1961, Loss: 1.5488
# Epoch 1, Step 780, Batch 780/1961, Loss: 1.5340
# Epoch 1, Step 790, Batch 790/1961, Loss: 1.5449
# Epoch 1, Step 800, Batch 800/1961, Loss: 1.5303
# Epoch 1, Step 810, Batch 810/1961, Loss: 1.5393
# Epoch 1, Step 820, Batch 820/1961, Loss: 1.5471
# Epoch 1, Step 830, Batch 830/1961, Loss: 1.5343
# Epoch 1, Step 840, Batch 840/1961, Loss: 1.5433
# Epoch 1, Step 850, Batch 850/1961, Loss: 1.5211
# Epoch 1, Step 860, Batch 860/1961, Loss: 1.5119
# Epoch 1, Step 870, Batch 870/1961, Loss: 1.5217
# Epoch 1, Step 880, Batch 880/1961, Loss: 1.5330
# Epoch 1, Step 890, Batch 890/1961, Loss: 1.5238
# Epoch 1, Step 900, Batch 900/1961, Loss: 1.5212
# Epoch 1, Step 910, Batch 910/1961, Loss: 1.5240
# Epoch 1, Step 920, Batch 920/1961, Loss: 1.5097
# Epoch 1, Step 930, Batch 930/1961, Loss: 1.4856
# Epoch 1, Step 940, Batch 940/1961, Loss: 1.5092
# Epoch 1, Step 950, Batch 950/1961, Loss: 1.4965
# Epoch 1, Step 960, Batch 960/1961, Loss: 1.5093
# Epoch 1, Step 970, Batch 970/1961, Loss: 1.5154
# Epoch 1, Step 980, Batch 980/1961, Loss: 1.5191
# Epoch 1, Step 990, Batch 990/1961, Loss: 1.5064
# Epoch 1, Step 1000, Batch 1000/1961, Loss: 1.5040
# Epoch 1, Step 1010, Batch 1010/1961, Loss: 1.4792
# Epoch 1, Step 1020, Batch 1020/1961, Loss: 1.5020
# Epoch 1, Step 1030, Batch 1030/1961, Loss: 1.4903
# Epoch 1, Step 1040, Batch 1040/1961, Loss: 1.4929
# Epoch 1, Step 1050, Batch 1050/1961, Loss: 1.4808
# Epoch 1, Step 1060, Batch 1060/1961, Loss: 1.4986
# Epoch 1, Step 1070, Batch 1070/1961, Loss: 1.4749
# Epoch 1, Step 1080, Batch 1080/1961, Loss: 1.4906
# Epoch 1, Step 1090, Batch 1090/1961, Loss: 1.4789
# Epoch 1, Step 1100, Batch 1100/1961, Loss: 1.4966
# Epoch 1, Step 1110, Batch 1110/1961, Loss: 1.4867
# Epoch 1, Step 1120, Batch 1120/1961, Loss: 1.4858
# Epoch 1, Step 1130, Batch 1130/1961, Loss: 1.4716
# Epoch 1, Step 1140, Batch 1140/1961, Loss: 1.4810
# Epoch 1, Step 1150, Batch 1150/1961, Loss: 1.4849
# Epoch 1, Step 1160, Batch 1160/1961, Loss: 1.4718
# Epoch 1, Step 1170, Batch 1170/1961, Loss: 1.4935
# Epoch 1, Step 1180, Batch 1180/1961, Loss: 1.4742
# Epoch 1, Step 1190, Batch 1190/1961, Loss: 1.4594
# Epoch 1, Step 1200, Batch 1200/1961, Loss: 1.4746
# Epoch 1, Step 1210, Batch 1210/1961, Loss: 1.4859
# Epoch 1, Step 1220, Batch 1220/1961, Loss: 1.4925
# Epoch 1, Step 1230, Batch 1230/1961, Loss: 1.4668
# Epoch 1, Step 1240, Batch 1240/1961, Loss: 1.4607
# Epoch 1, Step 1250, Batch 1250/1961, Loss: 1.4623
# Epoch 1, Step 1260, Batch 1260/1961, Loss: 1.4730
# Epoch 1, Step 1270, Batch 1270/1961, Loss: 1.4622
# Epoch 1, Step 1280, Batch 1280/1961, Loss: 1.4603
# Epoch 1, Step 1290, Batch 1290/1961, Loss: 1.4623
# Epoch 1, Step 1300, Batch 1300/1961, Loss: 1.4620
# Epoch 1, Step 1310, Batch 1310/1961, Loss: 1.4707
# Epoch 1, Step 1320, Batch 1320/1961, Loss: 1.4798
# Epoch 1, Step 1330, Batch 1330/1961, Loss: 1.4685
# Epoch 1, Step 1340, Batch 1340/1961, Loss: 1.4561
# Epoch 1, Step 1350, Batch 1350/1961, Loss: 1.4676
# Epoch 1, Step 1360, Batch 1360/1961, Loss: 1.4768
# Epoch 1, Step 1370, Batch 1370/1961, Loss: 1.4497
# Epoch 1, Step 1380, Batch 1380/1961, Loss: 1.4656
# Epoch 1, Step 1390, Batch 1390/1961, Loss: 1.4574
# Epoch 1, Step 1400, Batch 1400/1961, Loss: 1.4470
# Epoch 1, Step 1410, Batch 1410/1961, Loss: 1.4649
# Epoch 1, Step 1420, Batch 1420/1961, Loss: 1.4565
# Epoch 1, Step 1430, Batch 1430/1961, Loss: 1.4715
# Epoch 1, Step 1440, Batch 1440/1961, Loss: 1.4751
# Epoch 1, Step 1450, Batch 1450/1961, Loss: 1.4673
# Epoch 1, Step 1460, Batch 1460/1961, Loss: 1.4580
# Epoch 1, Step 1470, Batch 1470/1961, Loss: 1.4809
# Epoch 1, Step 1480, Batch 1480/1961, Loss: 1.4495
# Epoch 1, Step 1490, Batch 1490/1961, Loss: 1.4363
# Epoch 1, Step 1500, Batch 1500/1961, Loss: 1.4346
# Epoch 1, Step 1510, Batch 1510/1961, Loss: 1.4361
# Epoch 1, Step 1520, Batch 1520/1961, Loss: 1.4489
# Epoch 1, Step 1530, Batch 1530/1961, Loss: 1.4516
# Epoch 1, Step 1540, Batch 1540/1961, Loss: 1.4470
# Epoch 1, Step 1550, Batch 1550/1961, Loss: 1.4444
# Epoch 1, Step 1560, Batch 1560/1961, Loss: 1.4431
# Epoch 1, Step 1570, Batch 1570/1961, Loss: 1.4101
# Epoch 1, Step 1580, Batch 1580/1961, Loss: 1.4447
# Epoch 1, Step 1590, Batch 1590/1961, Loss: 1.4477
# Epoch 1, Step 1600, Batch 1600/1961, Loss: 1.4570
# Epoch 1, Step 1610, Batch 1610/1961, Loss: 1.4405
# Epoch 1, Step 1620, Batch 1620/1961, Loss: 1.4345
# Epoch 1, Step 1630, Batch 1630/1961, Loss: 1.4414
# Epoch 1, Step 1640, Batch 1640/1961, Loss: 1.4436
# Epoch 1, Step 1650, Batch 1650/1961, Loss: 1.4500
# Epoch 1, Step 1660, Batch 1660/1961, Loss: 1.4299
# Epoch 1, Step 1670, Batch 1670/1961, Loss: 1.4357
# Epoch 1, Step 1680, Batch 1680/1961, Loss: 1.4210
# Epoch 1, Step 1690, Batch 1690/1961, Loss: 1.4206
# Epoch 1, Step 1700, Batch 1700/1961, Loss: 1.4243
# Epoch 1, Step 1710, Batch 1710/1961, Loss: 1.4481
# Epoch 1, Step 1720, Batch 1720/1961, Loss: 1.4275
# Epoch 1, Step 1730, Batch 1730/1961, Loss: 1.4350
# Epoch 1, Step 1740, Batch 1740/1961, Loss: 1.4294
# Epoch 1, Step 1750, Batch 1750/1961, Loss: 1.4338
# Epoch 1, Step 1760, Batch 1760/1961, Loss: 1.4509
# Epoch 1, Step 1770, Batch 1770/1961, Loss: 1.4261
# Epoch 1, Step 1780, Batch 1780/1961, Loss: 1.4062
# Epoch 1, Step 1790, Batch 1790/1961, Loss: 1.4262
# Epoch 1, Step 1800, Batch 1800/1961, Loss: 1.4313
# Epoch 1, Step 1810, Batch 1810/1961, Loss: 1.4337
# Epoch 1, Step 1820, Batch 1820/1961, Loss: 1.4267
# Epoch 1, Step 1830, Batch 1830/1961, Loss: 1.4278
# Epoch 1, Step 1840, Batch 1840/1961, Loss: 1.4187
# Epoch 1, Step 1850, Batch 1850/1961, Loss: 1.4219
# Epoch 1, Step 1860, Batch 1860/1961, Loss: 1.4272
# Epoch 1, Step 1870, Batch 1870/1961, Loss: 1.4277
# Epoch 1, Step 1880, Batch 1880/1961, Loss: 1.4311
# Epoch 1, Step 1890, Batch 1890/1961, Loss: 1.4374
# Epoch 1, Step 1900, Batch 1900/1961, Loss: 1.4363
# Epoch 1, Step 1910, Batch 1910/1961, Loss: 1.4045
# Epoch 1, Step 1920, Batch 1920/1961, Loss: 1.4420
# Epoch 1, Step 1930, Batch 1930/1961, Loss: 1.4184
# Epoch 1, Step 1940, Batch 1940/1961, Loss: 1.4252
# Epoch 1, Step 1950, Batch 1950/1961, Loss: 1.4218
# Epoch 1, Step 1960, Batch 1960/1961, Loss: 1.4248
# Epoch 1/1, Train Loss: 1.4097, Val Loss: 1.9132, Epoch Time: 171.71s
# Generated text [
#
# GREMIO:
# Good morrow, neighbour Baptista.
#
# BAPTISTA:
# Good morro]:
# --------------------------------------------------
#
#
# GREMIO:
# Good morrow, neighbour Baptista.
#
# BAPTISTA:
# Good morrow, rile come
# Lies health Mowbring tempiate.
# When it hath bed; he leavel
# And to for as from of babide you reeks;
# here been here sharp on his
# and have all
# Have say good rather's their Bonant? hereafter these it him rest part
# Dip roather stay
# I will forth man-ife, and I would live.
#
# LEONTES:
# A like heaven; therefore, but as he were all my soul,
# Thy soul a me strings, will not letter is you.
#
# HENRY VI:
# Let yourself and lady, more, be streely;
# So helmselves, and with thy the fault,
# You not a imp; let

# %% [markdown]
# With SwiGLU, we achieve performance similar to simpler models. However, its true strength becomes apparent in larger models and datasets. As model scale increases, SwiGLU outperforms simpler feed-forward mechanisms. Next, we'll swap out the learnable positional encoding for RoPE.

# %% [markdown]
# ## SHA + POS(ROPE) + Masking + RMSNorm + Residual + FeedForward(Implicit Gating)
#
# Rotary Position Embedding (RoPE) is an advanced method for injecting positional information into the model. It provides a more efficient and scalable way to handle positional information compared to learnable embeddings, especially for longer sequences. RoPE also improves the model's ability to generalize across different sequence lengths.

# %%
import torch
import torch.nn.functional as F

# RoPE: Rotary Position Embedding function
def apply_rotary_pos_emb(q, k, sin, cos):
    ###### 여기 채우기 #####
    q_rot = (q * cos) + (rotate_half(q) * sin)
    k_rot = (k * cos) + (rotate_half(k) * sin)
    return q_rot, k_rot

def rotate_half(x):
    x1, x2 = x.chunk(2, dim=-1)
    return torch.cat((-x2, x1), dim=-1)

# in case of single-head head_dim = dim
def build_rope_cache(seq_len, head_dim, device):
    inv_freq = 1.0 / (10000 ** (torch.arange(0, head_dim, 2).float().to(device) / head_dim))
    t = torch.arange(seq_len, device=device).float()
    freqs = torch.einsum('i,j->ij', t, inv_freq)
    emb = torch.cat((freqs, freqs), dim=-1)
    sin, cos = emb.sin(), emb.cos()
    return sin, cos

# Single-Head Attention (Very Basic)
class SingleHeadAttention(nn.Module):
    def __init__(self, d_model, seq_length):
        super(SingleHeadAttention, self).__init__()
        self.d_model = d_model
        self.seq_length = seq_length

        self.query = nn.Linear(d_model, d_model, bias=False)
        self.key = nn.Linear(d_model, d_model, bias=False)
        self.value = nn.Linear(d_model, d_model, bias=False)
        self.fc_out = nn.Linear(d_model, d_model, bias=False)

        # Build RoPE cache
        self.sin, self.cos = build_rope_cache(seq_length, d_model, torch.device('cpu'))

    def forward(self, x, mask=None):
        Q = self.query(x)
        K = self.key(x)
        V = self.value(x)

        # Apply RoPE to Q and K
        batch_size, seq_length, _ = x.size()
        sin, cos = self.sin[:seq_length, :].to(x.device), self.cos[:seq_length, :].to(x.device)
        Q_rot, K_rot = apply_rotary_pos_emb(Q, K, sin, cos)

        # Scaled dot-product attention
        attention_scores = torch.matmul(Q_rot, K_rot.transpose(-2, -1)) / (self.d_model ** 0.5)

        # look-ahead masking!
        if mask is not None:
            attention_scores = attention_scores.masked_fill(mask == 0, float('-inf'))

        attention_probs = F.softmax(attention_scores, dim=-1)
        attention_output = torch.matmul(attention_probs, V)

        return self.fc_out(attention_output)


# Custom RMSNorm to match LLaMA 1 official implementation
class RMSNorm(nn.Module):
    def __init__(self, d_model, eps=1e-6):
        super(RMSNorm, self).__init__()
        self.weight = nn.Parameter(torch.ones(d_model))
        self.eps = eps

    def _norm(self, x):
        # Compute variance and apply reciprocal square root for RMS normalization
        return x * torch.rsqrt(x.pow(2).mean(-1, keepdim=True) + self.eps)

    def forward(self, x):
        # Convert to float32 for precision, then back to original dtype
        output = self._norm(x.float()).type_as(x)
        return output * self.weight

# Feed-Forward Network with implicit gating
import math
class FeedForward(nn.Module):
    def __init__(self, d_model, multiple_of):
        super(FeedForward, self).__init__()
        up_hidden_dim = multiple_of * math.ceil((d_model * 4 * 2 / 3) / multiple_of)
        ###### self.gate_proj, self.up_proj, self.down_proj 정의 ######
        self.gate_proj = nn.Linear(d_model, up_hidden_dim, bias=False)
        self.up_proj = nn.Linear(d_model, up_hidden_dim, bias=False)
        self.down_proj = nn.Linear(up_hidden_dim, d_model, bias=False)
        self.act_fn = F.silu  # SiLU activation

    def forward(self, x):
        ### feedforward 작성 ###
        return self.down_proj(self.act_fn(self.gate_proj(x)) * self.up_proj(x))

# LLaMA Decoder Layer
class LLaMADecoderLayer(nn.Module):
    def __init__(self, embedding_dim, multiple_of, seq_length):
        super(LLaMADecoderLayer, self).__init__()
        self.attention = SingleHeadAttention(embedding_dim, seq_length)
        self.rmsnorm1 = RMSNorm(embedding_dim) # pre-norm
        self.rmsnorm2 = RMSNorm(embedding_dim) # post-norm

        self.feed_forward = FeedForward(embedding_dim, multiple_of)


    def forward(self, x, mask):
        # Pre-Norm
        normed_x = self.rmsnorm1(x)

        # Attention
        attention_output = self.attention(normed_x, mask)

        # Residual connection
        x = x + attention_output

        # Post-Norm
        normed_x = self.rmsnorm2(x)

        feed_forward_output = self.feed_forward(normed_x)

        # Residual Connection
        return x + feed_forward_output


class LLaMAModel(nn.Module):
    def __init__(self, vocab_size, embedding_dim, seq_length, multiple_of):
        super(LLaMAModel, self).__init__()
        self.embedding = nn.Embedding(vocab_size, embedding_dim)
        self.layer = LLaMADecoderLayer(embedding_dim, multiple_of, seq_length)
        self.fc_out = nn.Linear(embedding_dim, vocab_size, bias=False) # lm_head

        self.rmsnorm_f = RMSNorm(embedding_dim) # final_norm

    def forward(self, idx, targets=None):
        x = self.embedding(idx)

        # Look-Ahead Masking
        seq_length = x.size(1)
        mask = torch.tril(torch.ones(seq_length, seq_length)).to(x.device)

        x = self.layer(x, mask)

        # final norm
        x = self.rmsnorm_f(x)

        logits = self.fc_out(x)

        if targets is not None:
            loss = F.cross_entropy(logits.view(-1, logits.size(-1)), targets.view(-1))
            return logits, loss
        return logits, None

# %%
multiple_of = 8   # roughly dim * 1/16
train_and_test("SHA + POS(RoPE) + Masking + Residual + RMSNorm + FF(SwiGLU)", start_text, multiple_of)
# Out:
# Epoch 1/1
# Epoch 1, Step 10, Batch 10/1961, Loss: 2.7775
# Epoch 1, Step 20, Batch 20/1961, Loss: 2.5667
# Epoch 1, Step 30, Batch 30/1961, Loss: 2.4850
# Epoch 1, Step 40, Batch 40/1961, Loss: 2.4105
# Epoch 1, Step 50, Batch 50/1961, Loss: 2.3498
# Epoch 1, Step 60, Batch 60/1961, Loss: 2.3058
# Epoch 1, Step 70, Batch 70/1961, Loss: 2.2870
# Epoch 1, Step 80, Batch 80/1961, Loss: 2.2524
# Epoch 1, Step 90, Batch 90/1961, Loss: 2.2135
# Epoch 1, Step 100, Batch 100/1961, Loss: 2.1842
# Epoch 1, Step 110, Batch 110/1961, Loss: 2.1702
# Epoch 1, Step 120, Batch 120/1961, Loss: 2.1403
# Epoch 1, Step 130, Batch 130/1961, Loss: 2.1257
# Epoch 1, Step 140, Batch 140/1961, Loss: 2.0849
# Epoch 1, Step 150, Batch 150/1961, Loss: 2.0790
# Epoch 1, Step 160, Batch 160/1961, Loss: 2.0797
# Epoch 1, Step 170, Batch 170/1961, Loss: 2.0563
# Epoch 1, Step 180, Batch 180/1961, Loss: 2.0400
# Epoch 1, Step 190, Batch 190/1961, Loss: 2.0168
# Epoch 1, Step 200, Batch 200/1961, Loss: 2.0213
# Epoch 1, Step 210, Batch 210/1961, Loss: 1.9880
# Epoch 1, Step 220, Batch 220/1961, Loss: 1.9706
# Epoch 1, Step 230, Batch 230/1961, Loss: 1.9739
# Epoch 1, Step 240, Batch 240/1961, Loss: 1.9573
# Epoch 1, Step 250, Batch 250/1961, Loss: 1.9590
# Epoch 1, Step 260, Batch 260/1961, Loss: 1.9277
# Epoch 1, Step 270, Batch 270/1961, Loss: 1.9357
# Epoch 1, Step 280, Batch 280/1961, Loss: 1.8989
# Epoch 1, Step 290, Batch 290/1961, Loss: 1.8894
# Epoch 1, Step 300, Batch 300/1961, Loss: 1.8836
# Epoch 1, Step 310, Batch 310/1961, Loss: 1.8630
# Epoch 1, Step 320, Batch 320/1961, Loss: 1.8747
# Epoch 1, Step 330, Batch 330/1961, Loss: 1.8508
# Epoch 1, Step 340, Batch 340/1961, Loss: 1.8296
# Epoch 1, Step 350, Batch 350/1961, Loss: 1.8280
# Epoch 1, Step 360, Batch 360/1961, Loss: 1.8313
# Epoch 1, Step 370, Batch 370/1961, Loss: 1.8045
# Epoch 1, Step 380, Batch 380/1961, Loss: 1.7916
# Epoch 1, Step 390, Batch 390/1961, Loss: 1.7746
# Epoch 1, Step 400, Batch 400/1961, Loss: 1.7675
# Epoch 1, Step 410, Batch 410/1961, Loss: 1.7507
# Epoch 1, Step 420, Batch 420/1961, Loss: 1.7551
# Epoch 1, Step 430, Batch 430/1961, Loss: 1.7493
# Epoch 1, Step 440, Batch 440/1961, Loss: 1.7332
# Epoch 1, Step 450, Batch 450/1961, Loss: 1.7300
# Epoch 1, Step 460, Batch 460/1961, Loss: 1.7069
# Epoch 1, Step 470, Batch 470/1961, Loss: 1.6915
# Epoch 1, Step 480, Batch 480/1961, Loss: 1.7080
# Epoch 1, Step 490, Batch 490/1961, Loss: 1.6922
# Epoch 1, Step 500, Batch 500/1961, Loss: 1.6616
# Epoch 1, Step 510, Batch 510/1961, Loss: 1.6610
# Epoch 1, Step 520, Batch 520/1961, Loss: 1.6636
# Epoch 1, Step 530, Batch 530/1961, Loss: 1.6785
# Epoch 1, Step 540, Batch 540/1961, Loss: 1.6615
# Epoch 1, Step 550, Batch 550/1961, Loss: 1.6488
# Epoch 1, Step 560, Batch 560/1961, Loss: 1.6257
# Epoch 1, Step 570, Batch 570/1961, Loss: 1.6373
# Epoch 1, Step 580, Batch 580/1961, Loss: 1.6375
# Epoch 1, Step 590, Batch 590/1961, Loss: 1.6197
# Epoch 1, Step 600, Batch 600/1961, Loss: 1.6013
# Epoch 1, Step 610, Batch 610/1961, Loss: 1.6050
# Epoch 1, Step 620, Batch 620/1961, Loss: 1.6098
# Epoch 1, Step 630, Batch 630/1961, Loss: 1.6132
# Epoch 1, Step 640, Batch 640/1961, Loss: 1.5898
# Epoch 1, Step 650, Batch 650/1961, Loss: 1.6081
# Epoch 1, Step 660, Batch 660/1961, Loss: 1.5796
# Epoch 1, Step 670, Batch 670/1961, Loss: 1.5720
# Epoch 1, Step 680, Batch 680/1961, Loss: 1.5688
# Epoch 1, Step 690, Batch 690/1961, Loss: 1.5798
# Epoch 1, Step 700, Batch 700/1961, Loss: 1.5787
# Epoch 1, Step 710, Batch 710/1961, Loss: 1.5648
# Epoch 1, Step 720, Batch 720/1961, Loss: 1.5576
# Epoch 1, Step 730, Batch 730/1961, Loss: 1.5690
# Epoch 1, Step 740, Batch 740/1961, Loss: 1.5481
# Epoch 1, Step 750, Batch 750/1961, Loss: 1.5363
# Epoch 1, Step 760, Batch 760/1961, Loss: 1.5585
# Epoch 1, Step 770, Batch 770/1961, Loss: 1.5322
# Epoch 1, Step 780, Batch 780/1961, Loss: 1.5284
# Epoch 1, Step 790, Batch 790/1961, Loss: 1.5355
# Epoch 1, Step 800, Batch 800/1961, Loss: 1.5500
# Epoch 1, Step 810, Batch 810/1961, Loss: 1.5436
# Epoch 1, Step 820, Batch 820/1961, Loss: 1.5243
# Epoch 1, Step 830, Batch 830/1961, Loss: 1.5223
# Epoch 1, Step 840, Batch 840/1961, Loss: 1.5261
# Epoch 1, Step 850, Batch 850/1961, Loss: 1.5057
# Epoch 1, Step 860, Batch 860/1961, Loss: 1.5192
# Epoch 1, Step 870, Batch 870/1961, Loss: 1.5079
# Epoch 1, Step 880, Batch 880/1961, Loss: 1.5076
# Epoch 1, Step 890, Batch 890/1961, Loss: 1.5111
# Epoch 1, Step 900, Batch 900/1961, Loss: 1.4864
# Epoch 1, Step 910, Batch 910/1961, Loss: 1.5092
# Epoch 1, Step 920, Batch 920/1961, Loss: 1.5450
# Epoch 1, Step 930, Batch 930/1961, Loss: 1.5079
# Epoch 1, Step 940, Batch 940/1961, Loss: 1.5006
# Epoch 1, Step 950, Batch 950/1961, Loss: 1.5082
# Epoch 1, Step 960, Batch 960/1961, Loss: 1.5103
# Epoch 1, Step 970, Batch 970/1961, Loss: 1.5061
# Epoch 1, Step 980, Batch 980/1961, Loss: 1.4916
# Epoch 1, Step 990, Batch 990/1961, Loss: 1.4841
# Epoch 1, Step 1000, Batch 1000/1961, Loss: 1.4867
# Epoch 1, Step 1010, Batch 1010/1961, Loss: 1.4897
# Epoch 1, Step 1020, Batch 1020/1961, Loss: 1.4800
# Epoch 1, Step 1030, Batch 1030/1961, Loss: 1.4797
# Epoch 1, Step 1040, Batch 1040/1961, Loss: 1.4836
# Epoch 1, Step 1050, Batch 1050/1961, Loss: 1.4832
# Epoch 1, Step 1060, Batch 1060/1961, Loss: 1.4783
# Epoch 1, Step 1070, Batch 1070/1961, Loss: 1.4798
# Epoch 1, Step 1080, Batch 1080/1961, Loss: 1.4950
# Epoch 1, Step 1090, Batch 1090/1961, Loss: 1.4876
# Epoch 1, Step 1100, Batch 1100/1961, Loss: 1.4734
# Epoch 1, Step 1110, Batch 1110/1961, Loss: 1.4782
# Epoch 1, Step 1120, Batch 1120/1961, Loss: 1.4632
# Epoch 1, Step 1130, Batch 1130/1961, Loss: 1.4797
# Epoch 1, Step 1140, Batch 1140/1961, Loss: 1.4644
# Epoch 1, Step 1150, Batch 1150/1961, Loss: 1.4731
# Epoch 1, Step 1160, Batch 1160/1961, Loss: 1.4780
# Epoch 1, Step 1170, Batch 1170/1961, Loss: 1.4782
# Epoch 1, Step 1180, Batch 1180/1961, Loss: 1.4742
# Epoch 1, Step 1190, Batch 1190/1961, Loss: 1.4527
# Epoch 1, Step 1200, Batch 1200/1961, Loss: 1.4588
# Epoch 1, Step 1210, Batch 1210/1961, Loss: 1.4600
# Epoch 1, Step 1220, Batch 1220/1961, Loss: 1.4598
# Epoch 1, Step 1230, Batch 1230/1961, Loss: 1.4608
# Epoch 1, Step 1240, Batch 1240/1961, Loss: 1.4624
# Epoch 1, Step 1250, Batch 1250/1961, Loss: 1.4424
# Epoch 1, Step 1260, Batch 1260/1961, Loss: 1.4350
# Epoch 1, Step 1270, Batch 1270/1961, Loss: 1.4597
# Epoch 1, Step 1280, Batch 1280/1961, Loss: 1.4677
# Epoch 1, Step 1290, Batch 1290/1961, Loss: 1.4584
# Epoch 1, Step 1300, Batch 1300/1961, Loss: 1.4301
# Epoch 1, Step 1310, Batch 1310/1961, Loss: 1.4457
# Epoch 1, Step 1320, Batch 1320/1961, Loss: 1.4425
# Epoch 1, Step 1330, Batch 1330/1961, Loss: 1.4520
# Epoch 1, Step 1340, Batch 1340/1961, Loss: 1.4347
# Epoch 1, Step 1350, Batch 1350/1961, Loss: 1.4301
# Epoch 1, Step 1360, Batch 1360/1961, Loss: 1.4474
# Epoch 1, Step 1370, Batch 1370/1961, Loss: 1.4347
# Epoch 1, Step 1380, Batch 1380/1961, Loss: 1.4442
# Epoch 1, Step 1390, Batch 1390/1961, Loss: 1.4418
# Epoch 1, Step 1400, Batch 1400/1961, Loss: 1.4352
# Epoch 1, Step 1410, Batch 1410/1961, Loss: 1.4553
# Epoch 1, Step 1420, Batch 1420/1961, Loss: 1.4429
# Epoch 1, Step 1430, Batch 1430/1961, Loss: 1.4340
# Epoch 1, Step 1440, Batch 1440/1961, Loss: 1.4391
# Epoch 1, Step 1450, Batch 1450/1961, Loss: 1.4384
# Epoch 1, Step 1460, Batch 1460/1961, Loss: 1.4332
# Epoch 1, Step 1470, Batch 1470/1961, Loss: 1.4355
# Epoch 1, Step 1480, Batch 1480/1961, Loss: 1.4317
# Epoch 1, Step 1490, Batch 1490/1961, Loss: 1.4455
# Epoch 1, Step 1500, Batch 1500/1961, Loss: 1.4384
# Epoch 1, Step 1510, Batch 1510/1961, Loss: 1.4430
# Epoch 1, Step 1520, Batch 1520/1961, Loss: 1.4366
# Epoch 1, Step 1530, Batch 1530/1961, Loss: 1.4236
# Epoch 1, Step 1540, Batch 1540/1961, Loss: 1.4374
# Epoch 1, Step 1550, Batch 1550/1961, Loss: 1.4175
# Epoch 1, Step 1560, Batch 1560/1961, Loss: 1.4337
# Epoch 1, Step 1570, Batch 1570/1961, Loss: 1.4364
# Epoch 1, Step 1580, Batch 1580/1961, Loss: 1.4078
# Epoch 1, Step 1590, Batch 1590/1961, Loss: 1.4269
# Epoch 1, Step 1600, Batch 1600/1961, Loss: 1.4351
# Epoch 1, Step 1610, Batch 1610/1961, Loss: 1.4300
# Epoch 1, Step 1620, Batch 1620/1961, Loss: 1.4328
# Epoch 1, Step 1630, Batch 1630/1961, Loss: 1.4195
# Epoch 1, Step 1640, Batch 1640/1961, Loss: 1.4222
# Epoch 1, Step 1650, Batch 1650/1961, Loss: 1.4192
# Epoch 1, Step 1660, Batch 1660/1961, Loss: 1.4330
# Epoch 1, Step 1670, Batch 1670/1961, Loss: 1.4204
# Epoch 1, Step 1680, Batch 1680/1961, Loss: 1.3964
# Epoch 1, Step 1690, Batch 1690/1961, Loss: 1.4287
# Epoch 1, Step 1700, Batch 1700/1961, Loss: 1.4139
# Epoch 1, Step 1710, Batch 1710/1961, Loss: 1.4037
# Epoch 1, Step 1720, Batch 1720/1961, Loss: 1.4297
# Epoch 1, Step 1730, Batch 1730/1961, Loss: 1.4250
# Epoch 1, Step 1740, Batch 1740/1961, Loss: 1.4008
# Epoch 1, Step 1750, Batch 1750/1961, Loss: 1.4181
# Epoch 1, Step 1760, Batch 1760/1961, Loss: 1.4232
# Epoch 1, Step 1770, Batch 1770/1961, Loss: 1.4090
# Epoch 1, Step 1780, Batch 1780/1961, Loss: 1.4066
# Epoch 1, Step 1790, Batch 1790/1961, Loss: 1.4052
# Epoch 1, Step 1800, Batch 1800/1961, Loss: 1.4063
# Epoch 1, Step 1810, Batch 1810/1961, Loss: 1.4133
# Epoch 1, Step 1820, Batch 1820/1961, Loss: 1.4111
# Epoch 1, Step 1830, Batch 1830/1961, Loss: 1.4107
# Epoch 1, Step 1840, Batch 1840/1961, Loss: 1.3991
# Epoch 1, Step 1850, Batch 1850/1961, Loss: 1.4264
# Epoch 1, Step 1860, Batch 1860/1961, Loss: 1.3826
# Epoch 1, Step 1870, Batch 1870/1961, Loss: 1.4049
# Epoch 1, Step 1880, Batch 1880/1961, Loss: 1.4304
# Epoch 1, Step 1890, Batch 1890/1961, Loss: 1.4055
# Epoch 1, Step 1900, Batch 1900/1961, Loss: 1.4075
# Epoch 1, Step 1910, Batch 1910/1961, Loss: 1.3972
# Epoch 1, Step 1920, Batch 1920/1961, Loss: 1.3871
# Epoch 1, Step 1930, Batch 1930/1961, Loss: 1.4007
# Epoch 1, Step 1940, Batch 1940/1961, Loss: 1.3948
# Epoch 1, Step 1950, Batch 1950/1961, Loss: 1.4004
# Epoch 1, Step 1960, Batch 1960/1961, Loss: 1.3960
# Epoch 1/1, Train Loss: 1.3833, Val Loss: 1.8268, Epoch Time: 187.37s
# Generated text [
#
# GREMIO:
# Good morrow, neighbour Baptista.
#
# BAPTISTA:
# Good morro]:
# --------------------------------------------------
#
#
# GREMIO:
# Good morrow, neighbour Baptista.
#
# BAPTISTA:
# Good morrow ilward, myself,
# Let my friends; and welcomes of what father's swarm,
# Hif we of or shapes wife, an 'te out and country:
# I'll set tongue.
#
# CLAUDIO:
# My lord.
#
# KING RICHARD II:
# A know other set as tree Could raften ging.
# Our idliam confess' blood arms blood
# The you so, achievers, if generar.
#
# JULIET:
# The shall for edtion a kinger and die.
#
# KING RICHARD III:
# And all vow'd fair straitor, Germainished!
#
# Page:
# Be it pear but to that I omeet tabb'd upon.
#
# YORK:
# Hath state hither. Praising:
# Said, and th

# %% [markdown]
# Introducing RoPE shows a noticeable improvement in performance, with the model now generating more coherent text. The loss curve aligns more closely with our expectations, reaching a point where it starts to rival LSTM performance. This confirms that RoPE is well-suited for transformer-based models.

# %% [markdown]
# We now conclude our single-head attention series and move on to multi-head attention, which significantly boosts performance.
#
# Multi-head attention allows the model to focus on different parts of the input sequence simultaneously, providing a richer representation of the data and improving learning efficiency.

# %% [markdown]
# ## Multihead Attention

# %%
import torch
import torch.nn.functional as F
import torch.nn as nn
import math

# RoPE: Rotary Position Embedding function
def apply_rotary_pos_emb(q, k, sin, cos):
    ###### 여기 채우기 #####
    q_rot = (q * cos) + (rotate_half(q) * sin)
    k_rot = (k * cos) + (rotate_half(k) * sin)
    return q_rot, k_rot

def rotate_half(x):
    x1, x2 = x.chunk(2, dim=-1)
    return torch.cat((-x2, x1), dim=-1)

def build_rope_cache(seq_len, head_dim, device):
    inv_freq = 1.0 / (10000 ** (torch.arange(0, head_dim, 2).float().to(device) / head_dim))
    t = torch.arange(seq_len, device=device).float()
    freqs = torch.einsum('i,j->ij', t, inv_freq)
    emb = torch.cat((freqs, freqs), dim=-1)
    sin, cos = emb.sin(), emb.cos()
    return sin, cos

# Custom RMSNorm to match LLaMA 1 official implementation
class RMSNorm(nn.Module):
    def __init__(self, d_model, eps=1e-6):
        super(RMSNorm, self).__init__()
        self.weight = nn.Parameter(torch.ones(d_model))
        self.eps = eps

    def _norm(self, x):
        # Compute variance and apply reciprocal square root for RMS normalization
        return x * torch.rsqrt(x.pow(2).mean(-1, keepdim=True) + self.eps)

    def forward(self, x):
        # Convert to float32 for precision, then back to original dtype
        output = self._norm(x.float()).type_as(x)
        return output * self.weight

# Feed-Forward Network with implicit gating
class FeedForward(nn.Module):
    def __init__(self, d_model, multiple_of):
        super(FeedForward, self).__init__()
        up_hidden_dim = multiple_of * math.ceil((d_model * 4 * 2 / 3) / multiple_of)
        ###### self.gate_proj, self.up_proj, self.down_proj 정의 ######
        self.gate_proj = nn.Linear(d_model, up_hidden_dim, bias=False)
        self.up_proj = nn.Linear(d_model, up_hidden_dim, bias=False)
        self.down_proj = nn.Linear(up_hidden_dim, d_model, bias=False)
        self.act_fn = F.silu  # SiLU activation

    def forward(self, x):
        ### feedforward 작성 ###
        return self.down_proj(self.act_fn(self.gate_proj(x)) * self.up_proj(x))

# Multi-Head Attention with Causal Masking and RoPE
class MultiHeadAttention(nn.Module):
    def __init__(self, d_model, num_heads, seq_length):
        super(MultiHeadAttention, self).__init__()
        self.num_heads = num_heads
        self.d_model = d_model
        self.head_dim = d_model // num_heads
        self.seq_length = seq_length

        self.query = nn.Linear(d_model, d_model, bias=False)
        self.key = nn.Linear(d_model, d_model, bias=False)
        self.value = nn.Linear(d_model, d_model, bias=False)
        self.fc_out = nn.Linear(d_model, d_model, bias=False)

        # Build RoPE cache
        self.sin, self.cos = build_rope_cache(seq_length, self.head_dim, torch.device('cpu'))

    def forward(self, x, mask=None):

        ########## 여기 작성 ###########
        batch_size = x.size(0)

        q = self.query(x).view(batch_size, self.seq_length, self.num_heads, self.head_dim)
        k = self.key(x).view(batch_size, self.seq_length, self.num_heads, self.head_dim)
        v = self.value(x).view(batch_size, self.seq_length, self.num_heads, self.head_dim)

        self.sin = self.sin.to(x.device)
        self.cos = self.cos.to(x.device)

        cos_cache = self.cos.unsqueeze(0).unsqueeze(2)
        sin_cache = self.sin.unsqueeze(0).unsqueeze(2)

        q, k = apply_rotary_pos_emb(q, k , sin_cache, cos_cache)

        q = q.transpose(1, 2)
        k = k.transpose(1, 2)
        v = v.transpose(1, 2)

        scores = torch.matmul(q, k.transpose(-2, -1)) / math.sqrt(self.head_dim)

        scores = scores.masked_fill(mask == 0, float('-inf'))
        attention_weights = F.softmax(scores, dim=-1)
        output = torch.matmul(attention_weights, v)

        output = output.transpose(1, 2).contiguous().view(batch_size, self.seq_length, self.d_model)

        x = self.fc_out(output)

        return x

# LLaMA Decoder Layer with Multi-Head Attention and RoPE
class LLaMADecoderLayer(nn.Module):
    def __init__(self, embedding_dim, multiple_of, num_heads, seq_length):
        super(LLaMADecoderLayer, self).__init__()
        self.rmsnorm1 = RMSNorm(embedding_dim)
        self.attention = MultiHeadAttention(embedding_dim, num_heads, seq_length)
        self.rmsnorm2 = RMSNorm(embedding_dim)
        self.feed_forward = FeedForward(embedding_dim, multiple_of)

    def forward(self, x, mask):
        normed_x = self.rmsnorm1(x)
        attention_output = self.attention(normed_x, mask)
        x = x + attention_output  # Residual connection
        normed_x = self.rmsnorm2(x)
        feed_forward_output = self.feed_forward(normed_x)
        return x + feed_forward_output  # Residual connection

class LLaMAModel(nn.Module):
    def __init__(self, vocab_size, embedding_dim, seq_length, num_heads, multiple_of):
        super(LLaMAModel, self).__init__()
        self.embedding = nn.Embedding(vocab_size, embedding_dim)
        self.layer = LLaMADecoderLayer(embedding_dim, multiple_of, num_heads, seq_length)
        self.rmsnorm_f = RMSNorm(embedding_dim)
        self.fc_out = nn.Linear(embedding_dim, vocab_size, bias=False)

    def forward(self, idx, targets=None):
        x = self.embedding(idx)
        seq_length = x.size(1)
        mask = torch.tril(torch.ones(seq_length, seq_length)).to(x.device)

        x = self.layer(x, mask)

        x = self.rmsnorm_f(x)
        logits = self.fc_out(x)

        if targets is not None:
            loss = F.cross_entropy(logits.view(-1, logits.size(-1)), targets.view(-1))
            return logits, loss
        return logits, None

# %%
def train_and_test(model_desc, start_text, multiple_of, num_heads):
    # Initialize the model
    model_llama = LLaMAModel(vocab_size, EMBEDDING_DIM, SEQUENCE_LENGTH, num_heads, multiple_of).to(device)

    # Use the same optimizer and criterion
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model_llama.parameters(), lr=LEARNING_RATE)

    # Train the model
    trained_model, train_losses_df, val_losses_df = train_model(
        model_llama, train_loader, val_loader, criterion, optimizer, device, EPOCHS
    )

    # Generate text
    generated_text = generate_text_attention(trained_model, char_to_idx, idx_to_char, start_text, device)
    print(f"Generated text [{start_text}]:")
    print("-"*50)
    print(generated_text)

    add_loss_to_comparison(model_desc, train_losses_df, val_losses_df)

    # Plot loss comparisons including this model
    plot_loss_comparisons()

# %%
multiple_of = 8   # roughly dim * 1/16
num_heads = 8
train_and_test("MHA + POS(RoPE) + Masking + Residual + RMSNorm + FF(SwiGLU)", start_text, multiple_of, num_heads)
# Out:
# Epoch 1/1
# Epoch 1, Step 10, Batch 10/1961, Loss: 2.8161
# Epoch 1, Step 20, Batch 20/1961, Loss: 2.5706
# Epoch 1, Step 30, Batch 30/1961, Loss: 2.4640
# Epoch 1, Step 40, Batch 40/1961, Loss: 2.3849
# Epoch 1, Step 50, Batch 50/1961, Loss: 2
# Epoch 1, Step 1180, Batch 1180/1961, Loss: 1.3586
# Epoch 1, Step 1190, Batch 1190/1961, Loss: 1.3540
# Epoch 1, Step 1200, Batch 1200/1961, Loss: 1.3643
# Epoch 1, Step 1210, Batch 1210/1961, Loss: 1.3413
# Epoch 1, Step 1220, Batch 1220/1961, Loss: 1.3468
# Epoch 1, Step 1230, Batch 1230/1961, Loss: 1.3546
# Epoch 1, Step 1240, Batch 1240/1961, Loss: 1.3393
# Epoch 1, Step 1250, Batch 1250/1961, Loss: 1.3576
# Epoch 1, Step 1260, Batch 1260/1961, Loss: 1.3299
# Epoch 1, Step 1270, Batch 1270/1961, Loss: 1.3519
# Epoch 1, Step 1280, Batch 1280/1961, Loss: 1.3394
# Epoch 1, Step 1290, Batch 1290/1961, Loss: 1.3339
# Epoch 1, Step 1300, Batch 1300/1961, Loss: 1.3512
# Epoch 1, Step 1310, Batch 1310/1961, Loss: 1.3377
# Epoch 1, Step 1320, Batch 1320/1961, Loss: 1.3252
# Epoch 1, Step 1330, Batch 1330/1961, Loss: 1.3413
# Epoch 1, Step 1340, Batch 1340/1961, Loss: 1.3450
# Epoch 1, Step 1350, Batch 1350/1961, Loss: 1.3231
# Epoch 1, Step 1360, Batch 1360/1961, Loss: 1.3218
# Epoch 1, Step 1370, Batch 1370/1961, Loss: 1.3298
# Epoch 1, Step 1380, Batch 1380/1961, Loss: 1.3110
# Epoch 1, Step 1390, Batch 1390/1961, Loss: 1.3461
# Epoch 1, Step 1400, Batch 1400/1961, Loss: 1.3292
# Epoch 1, Step 1410, Batch 1410/1961, Loss: 1.3388
# Epoch 1, Step 1420, Batch 1420/1961, Loss: 1.3332
# Epoch 1, Step 1430, Batch 1430/1961, Loss: 1.3218
# Epoch 1, Step 1440, Batch 1440/1961, Loss: 1.3148
# Epoch 1, Step 1450, Batch 1450/1961, Loss: 1.3299
# Epoch 1, Step 1460, Batch 1460/1961, Loss: 1.3213
# Epoch 1, Step 1470, Batch 1470/1961, Loss: 1.3319
# Epoch 1, Step 1480, Batch 1480/1961, Loss: 1.3149
# Epoch 1, Step 1490, Batch 1490/1961, Loss: 1.3138
# Epoch 1, Step 1500, Batch 1500/1961, Loss: 1.3278
# Epoch 1, Step 1510, Batch 1510/1961, Loss: 1.3143
# Epoch 1, Step 1520, Batch 1520/1961, Loss: 1.3283
# Epoch 1, Step 1530, Batch 1530/1961, Loss: 1.3150
# Epoch 1, Step 1540, Batch 1540/1961, Loss: 1.3155
# Epoch 1, Step 1550, Batch 1550/1961, Loss: 1.3148
# Epoch 1, Step 1560, Batch 1560/1961, Loss: 1.3017
# Epoch 1, Step 1570, Batch 1570/1961, Loss: 1.3321
# Epoch 1, Step 1580, Batch 1580/1961, Loss: 1.2970
# Epoch 1, Step 1590, Batch 1590/1961, Loss: 1.3177
# Epoch 1, Step 1600, Batch 1600/1961, Loss: 1.3103
# Epoch 1, Step 1610, Batch 1610/1961, Loss: 1.3088
# Epoch 1, Step 1620, Batch 1620/1961, Loss: 1.2988
# Epoch 1, Step 1630, Batch 1630/1961, Loss: 1.3241
# Epoch 1, Step 1640, Batch 1640/1961, Loss: 1.3187
# Epoch 1, Step 1650, Batch 1650/1961, Loss: 1.3176
# Epoch 1, Step 1660, Batch 1660/1961, Loss: 1.3078
# Epoch 1, Step 1670, Batch 1670/1961, Loss: 1.3270
# Epoch 1, Step 1680, Batch 1680/1961, Loss: 1.3018
# Epoch 1, Step 1690, Batch 1690/1961, Loss: 1.2963
# Epoch 1, Step 1700, Batch 1700/1961, Loss: 1.3089
# Epoch 1, Step 1710, Batch 1710/1961, Loss: 1.3126
# Epoch 1, Step 1720, Batch 1720/1961, Loss: 1.2953
# Epoch 1, Step 1730, Batch 1730/1961, Loss: 1.2902
# Epoch 1, Step 1740, Batch 1740/1961, Loss: 1.2831
# Epoch 1, Step 1750, Batch 1750/1961, Loss: 1.3015
# Epoch 1, Step 1760, Batch 1760/1961, Loss: 1.3116
# Epoch 1, Step 1770, Batch 1770/1961, Loss: 1.3005
# Epoch 1, Step 1780, Batch 1780/1961, Loss: 1.3225
# Epoch 1, Step 1790, Batch 1790/1961, Loss: 1.2994
# Epoch 1, Step 1800, Batch 1800/1961, Loss: 1.3019
# Epoch 1, Step 1810, Batch 1810/1961, Loss: 1.2848
# Epoch 1, Step 1820, Batch 1820/1961, Loss: 1.2880
# Epoch 1, Step 1830, Batch 1830/1961, Loss: 1.3070
# Epoch 1, Step 1840, Batch 1840/1961, Loss: 1.2780
# Epoch 1, Step 1850, Batch 1850/1961, Loss: 1.2856
# Epoch 1, Step 1860, Batch 1860/1961, Loss: 1.2950
# Epoch 1, Step 1870, Batch 1870/1961, Loss: 1.2854
# Epoch 1, Step 1880, Batch 1880/1961, Loss: 1.2984
# Epoch 1, Step 1890, Batch 1890/1961, Loss: 1.2981
# Epoch 1, Step 1900, Batch 1900/1961, Loss: 1.2949
# Epoch 1, Step 1910, Batch 1910/1961, Loss: 1.3010
# Epoch 1, Step 1920, Batch 1920/1961, Loss: 1.2812
# Epoch 1, Step 1930, Batch 1930/1961, Loss: 1.2863
# Epoch 1, Step 1940, Batch 1940/1961, Loss: 1.2927
# Epoch 1, Step 1950, Batch 1950/1961, Loss: 1.2914
# Epoch 1, Step 1960, Batch 1960/1961, Loss: 1.2774
# Epoch 1/1, Train Loss: 1.2685, Val Loss: 1.8323, Epoch Time: 201.19s
# Generated text [
#
# GREMIO:
# Good morrow, neighbour Baptista.
#
# BAPTISTA:
# Good morro]:
# --------------------------------------------------
#
#
# GREMIO:
# Good morrow, neighbour Baptista.
#
# BAPTISTA:
# Good morrow thy thee and to the plate.
# Had he thus exiled labour's expect'st occup,
# And proper she throat it. What's thus.
#
# NORFOLK:
# Now, set yet the palace and thyself,
# The concerns to the sister
# May begin to me that I had thee my death?
# But when you well.
#
# This lies law fairy, becaused with ships.
#
# MERCUTIO:
# Then but a pens to going joy!
#
# ANTEd XIurdge:
# They she hath promisers' banish'd her?
#
# QUEEN MARGARET:
# O lament-triumph
# Rexeamiliament more,--
#
# ARCHID:
# I'll be a bay, not pity on: ci' tAwacred by the

# %% [markdown]
# As expected, multi-head attention dramatically improves the performance. The loss curve becomes much smoother, and the generated text is much more fluent and coherent. Multi-head attention allows the model to better capture complex relationships within the sequence.

# %% [markdown]
# # Multi-Layer
#
# Real-world transformers often have dozens of layers, with models like GPT-3 and LLaMA featuring as many as 32 layers or more. The true power of transformers comes from stacking multiple layers, which helps capture deeper patterns and relationships within the data. In this step, we extend our model to a multi-layer architecture.
#
# And one more change will be added. Previously, since there was only a single layer, the RoPE cache was placed inside the MHA. However, in the case of multiple layers, the RoPE cache is now created only once at the beginning and reused across all layers.

# %%
import torch
import torch.nn.functional as F
import torch.nn as nn
import math

# RoPE: Rotary Position Embedding function
def apply_rotary_pos_emb(q, k, sin, cos):
    ###### 여기 채우기 #####
    q_rot = (q * cos) + (rotate_half(q) * sin)
    k_rot = (k * cos) + (rotate_half(k) * sin)
    return q_rot, k_rot

def rotate_half(x):
    x1, x2 = x.chunk(2, dim=-1)
    return torch.cat((-x2, x1), dim=-1)


# Building the RoPE cache once, to be shared across layers
class RoPECache:
    def __init__(self, seq_len, head_dim, device):
        self.sin, self.cos = self.build_rope_cache(seq_len, head_dim, device)

    @staticmethod
    def build_rope_cache(seq_len, head_dim, device):
        inv_freq = 1.0 / (10000 ** (torch.arange(0, head_dim, 2).float().to(device) / head_dim))
        t = torch.arange(seq_len, device=device).float()
        freqs = torch.einsum('i,j->ij', t, inv_freq)
        emb = torch.cat((freqs, freqs), dim=-1)
        sin, cos = emb.sin(), emb.cos()
        return sin, cos

# Custom RMSNorm to match LLaMA 1 official implementation
class RMSNorm(nn.Module):
    def __init__(self, d_model, eps=1e-6):
        super(RMSNorm, self).__init__()
        self.weight = nn.Parameter(torch.ones(d_model))
        self.eps = eps

    def _norm(self, x):
        # Compute variance and apply reciprocal square root for RMS normalization
        return x * torch.rsqrt(x.pow(2).mean(-1, keepdim=True) + self.eps)

    def forward(self, x):
        # Convert to float32 for precision, then back to original dtype
        output = self._norm(x.float()).type_as(x)
        return output * self.weight

# Feed-Forward Network with implicit gating
class FeedForward(nn.Module):
    def __init__(self, d_model, multiple_of):
        super(FeedForward, self).__init__()
        up_hidden_dim = multiple_of * math.ceil((d_model * 4 * 2 / 3) / multiple_of)
        ###### self.gate_proj, self.up_proj, self.down_proj 정의 ######
        self.gate_proj = nn.Linear(d_model, up_hidden_dim, bias=False)
        self.up_proj = nn.Linear(d_model, up_hidden_dim, bias=False)
        self.down_proj = nn.Linear(up_hidden_dim, d_model, bias=False)
        self.act_fn = F.silu  # SiLU activation

    def forward(self, x):
        ### feedforward 작성 ###
        return self.down_proj(self.act_fn(self.gate_proj(x)) * self.up_proj(x))

# Multi-Head Attention with Causal Masking and RoPE
class MultiHeadAttention(nn.Module):
    def __init__(self, d_model, num_heads, seq_length, rope_cache):
        super(MultiHeadAttention, self).__init__()
        self.num_heads = num_heads
        self.d_model = d_model
        self.head_dim = d_model // num_heads
        self.seq_length = seq_length

        self.query = nn.Linear(d_model, d_model, bias=False)
        self.key = nn.Linear(d_model, d_model, bias=False)
        self.value = nn.Linear(d_model, d_model, bias=False)
        self.fc_out = nn.Linear(d_model, d_model, bias=False)

        # Use the shared RoPE cache
        self.rope_cache = rope_cache

    def forward(self, x, mask=None):

        ########## 여기 작성 ###########
        batch_size = x.size(0)

        q = self.query(x).view(batch_size, self.seq_length, self.num_heads, self.head_dim)
        k = self.key(x).view(batch_size, self.seq_length, self.num_heads, self.head_dim)
        v = self.value(x).view(batch_size, self.seq_length, self.num_heads, self.head_dim)

        sin = self.rope_cache.sin.to(x.device)
        cos = self.rope_cache.cos.to(x.device)

        cos_cache = cos.unsqueeze(0).unsqueeze(2)
        sin_cache = sin.unsqueeze(0).unsqueeze(2)

        q, k = apply_rotary_pos_emb(q, k , sin_cache, cos_cache)

        q = q.transpose(1, 2)
        k = k.transpose(1, 2)
        v = v.transpose(1, 2)

        scores = torch.matmul(q, k.transpose(-2, -1)) / math.sqrt(self.head_dim)

        scores = scores.masked_fill(mask == 0, float('-inf'))
        attention_weights = F.softmax(scores, dim=-1)
        output = torch.matmul(attention_weights, v)

        output = output.transpose(1, 2).contiguous().view(batch_size, self.seq_length, self.d_model)

        x = self.fc_out(output)

        return x

# LLaMA Decoder Layer with Multi-Head Attention and RoPE
class LLaMADecoderLayer(nn.Module):
    def __init__(self, embedding_dim, multiple_of, num_heads, seq_length, rms_norm_eps, rope_cache):
        super(LLaMADecoderLayer, self).__init__()
        self.rmsnorm1 = RMSNorm(embedding_dim, rms_norm_eps)
        self.attention = MultiHeadAttention(embedding_dim, num_heads, seq_length, rope_cache)
        self.rmsnorm2 = RMSNorm(embedding_dim, rms_norm_eps)
        self.feed_forward = FeedForward(embedding_dim, multiple_of)

    def forward(self, x, mask):
        normed_x = self.rmsnorm1(x)
        attention_output = self.attention(normed_x, mask)
        x = x + attention_output  # Residual connection
        normed_x = self.rmsnorm2(x)
        feed_forward_output = self.feed_forward(normed_x)
        return x + feed_forward_output  # Residual connection

# LLaMA Model with RoPE and Multi-Layer
class LLaMAModel(nn.Module):
    def __init__(self, vocab_size, embedding_dim, seq_length, num_heads, num_layers, multiple_of, rms_norm_eps=1e-6):
        super(LLaMAModel, self).__init__()
        self.embedding = nn.Embedding(vocab_size, embedding_dim)

        # Initialize the shared RoPE cache once
        rope_cache = RoPECache(seq_length, embedding_dim // num_heads, torch.device('cpu'))

        self.layers = nn.ModuleList([LLaMADecoderLayer(embedding_dim, multiple_of, num_heads, seq_length, rms_norm_eps, rope_cache) for _ in range(num_layers)])
        self.rmsnorm_f = RMSNorm(embedding_dim, rms_norm_eps)
        self.fc_out = nn.Linear(embedding_dim, vocab_size, bias=False)

    def forward(self, idx, targets=None):
        x = self.embedding(idx)
        seq_length = x.size(1)
        mask = torch.tril(torch.ones(seq_length, seq_length)).to(x.device)

        for layer in self.layers:
            x = layer(x, mask)

        x = self.rmsnorm_f(x)
        logits = self.fc_out(x)

        if targets is not None:
            loss = F.cross_entropy(logits.view(-1, logits.size(-1)), targets.view(-1))
            return logits, loss
        return logits, None

# %%
def train_and_test(model_desc, start_text, multiple_of, num_heads, num_layers):
    # Initialize the model
    model_llama = LLaMAModel(vocab_size, EMBEDDING_DIM, SEQUENCE_LENGTH, num_heads, num_layers, multiple_of).to(device)

    # Use the same optimizer and criterion
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model_llama.parameters(), lr=LEARNING_RATE)

    # Train the model
    trained_model, train_losses_df, val_losses_df = train_model(
        model_llama, train_loader, val_loader, criterion, optimizer, device, EPOCHS
    )

    # Generate text
    generated_text = generate_text_attention(trained_model, char_to_idx, idx_to_char, start_text, device)
    print(f"Generated text [{start_text}]:")
    print("-"*50)
    print(generated_text)

    add_loss_to_comparison(model_desc, train_losses_df, val_losses_df)

    # Plot loss comparisons including this model
    plot_loss_comparisons()

# %%
multiple_of = 8   # roughly dim * 1/16
num_heads = 8
num_layers = 6

train_and_test("MultiLayer + MHA + POS(RoPE) + Masking + Residual + RMSNorm + FF(SwiGLU)", start_text, multiple_of, num_heads, num_layers)
# Out:
# Epoch 1/1
# Epoch 1, Step 10, Batch 10/1961, Loss: 2.5922
# Epoch 1, Step 20, Batch 20/1961, Loss: 2.4214
# Epoch 1, Step 30, Batch 30/1961, Loss: 2.2962
# Epoch 1, Step 40, Batch 40/1961, Loss: 2.1689
# Epoch 1, Step 50, Batch 50/1961, Loss: 2.0704
# Epoch 1, Step 60, Batch 60/1961, Loss: 1.9624
# Epoch 1, Step 70, Batch 70/1961, Loss: 1.8784
# Epoch 1, Step 80, Batch 80/1961, Loss: 1.8100
# Epoch 1, Step 90, Batch 90/1961, Loss: 1.7345
# Epoch 1, Step 100, Batch 100/1961, Loss: 1.6808
# Epoch 1, Step 110, Batch 110/1961, Loss: 1.6353
# Epoch 1, Step 120, Batch 120/1961, Loss: 1.5695
# Epoch 1, Step 130, Batch 130/1961, Loss: 1.5368
# Epoch 1, Step 140, Batch 140/1961, Loss: 1.5290
# Epoch 1, Step 150, Batch 150/1961, Loss: 1.4759
# Epoch 1, Step 160, Batch 160/1961, Loss: 1.4780
# Epoch 1, Step 170, Batch 170/1961, Loss: 1.4654
# Epoch 1, Step 180, Batch 180/1961, Loss: 1.4244
# Epoch 1, Step 190, Batch 190/1961, Loss: 1.4025
# Epoch 1, Step 200, Batch 200/1961, Loss: 1.3867
# Epoch 1, Step 210, Batch 210/1961, Loss: 1.3718
# Epoch 1, Step 220, Batch 220/1961, Loss: 1.3716
# Epoch 1, Step 230, Batch 230/1961, Loss: 1.3772
# Epoch 1, Step 240, Batch 240/1961, Loss: 1.3481
# Epoch 1, Step 250, Batch 250/1961, Loss: 1.3539
# Epoch 1, Step 260, Batch 260/1961, Loss: 1.3421
# Epoch 1, Step 270, Batch 270/1961, Loss: 1.3212
# Epoch 1, Step 280, Batch 280/1961, Loss: 1.3026
# Epoch 1, Step 290, Batch 290/1961, Loss: 1.3060
# Epoch 1, Step 1690, Batch 1690/1961, Loss: 0.4371
# Epoch 1, Step 1700, Batch 1700/1961, Loss: 0.4461
# Epoch 1, Step 1710, Batch 1710/1961, Loss: 0.4299
# Epoch 1, Step 1720, Batch 1720/1961, Loss: 0.4349
# Epoch 1, Step 1730, Batch 1730/1961, Loss: 0.4313
# Epoch 1, Step 1740, Batch 1740/1961, Loss: 0.4188
# Epoch 1, Step 1750, Batch 1750/1961, Loss: 0.4246
# Epoch 1, Step 1760, Batch 1760/1961, Loss: 0.4165
# Epoch 1, Step 1770, Batch 1770/1961, Loss: 0.4159
# Epoch 1, Step 1780, Batch 1780/1961, Loss: 0.4136
# Epoch 1, Step 1790, Batch 1790/1961, Loss: 0.4118
# Epoch 1, Step 1800, Batch 1800/1961, Loss: 0.4149
# Epoch 1, Step 1810, Batch 1810/1961, Loss: 0.3995
# Epoch 1, Step 1820, Batch 1820/1961, Loss: 0.4093
# Epoch 1, Step 1830, Batch 1830/1961, Loss: 0.4007
# Epoch 1, Step 1840, Batch 1840/1961, Loss: 0.4076
# Epoch 1, Step 1850, Batch 1850/1961, Loss: 0.4046
# Epoch 1, Step 1860, Batch 1860/1961, Loss: 0.3981
# Epoch 1, Step 1870, Batch 1870/1961, Loss: 0.4005
# Epoch 1, Step 1880, Batch 1880/1961, Loss: 0.3955
# Epoch 1, Step 1890, Batch 1890/1961, Loss: 0.3897
# Epoch 1, Step 1900, Batch 1900/1961, Loss: 0.3955
# Epoch 1, Step 1910, Batch 1910/1961, Loss: 0.3991
# Epoch 1, Step 1920, Batch 1920/1961, Loss: 0.3992
# Epoch 1, Step 1930, Batch 1930/1961, Loss: 0.3965
# Epoch 1, Step 1940, Batch 1940/1961, Loss: 0.3946
# Epoch 1, Step 1950, Batch 1950/1961, Loss: 0.3833
# Epoch 1, Step 1960, Batch 1960/1961, Loss: 0.3864
# Epoch 1/1, Train Loss: 0.3793, Val Loss: 3.3245, Epoch Time: 1002.83s
# Generated text [
#
# GREMIO:
# Good morrow, neighbour Baptista.
#
# BAPTISTA:
# Good morro]:
# --------------------------------------------------
#
#
# GREMIO:
# Good morrow, neighbour Baptista.
#
# BAPTISTA:
# Good morrow, good night! we would not then be made bellanders cannot
# Betwixt the prince honours of the absent,
# When Jeorge, came not mend it, they are rising.
#
# AUFIDIUS:
# I cannot tell:
# We must proceed with her most sweet voices.
# Here comes the record of the sport to but thought of, twas that have
# forgedd our name o' the people.
#
# SICINIUS:
# 'Tis not to long thee passage of the heart,
# Like a poor prisoner in his thought upon, whence the rightly -bolequite.
#
# HERMIONE:
# Come on, then, a bloody minister,
# And cre

# %% [markdown]
# With multiple layers, we see a significant improvement in the loss curve and generated text quality. The model is now capable of producing grammatically correct sentences with more coherent meaning. This demonstrates the power of deep transformers, which become more effective as the number of layers increases.

# %% [markdown]
# # Conclusion
#
# In this notebook, we successfully implemented a custom version of the LLaMA model, progressively building from simple components to a complete, high-performing architecture. Starting with a baseline LSTM model, we gradually introduced key features of transformers such as attention, positional encoding, normalization, and residual connections. We incorporated advanced techniques like SwiGLU and RoPE, ultimately scaling the model to multiple layers and heads.
