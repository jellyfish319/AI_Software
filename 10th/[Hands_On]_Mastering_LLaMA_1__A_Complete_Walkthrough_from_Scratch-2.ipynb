# %% [markdown]
# # [Hands-On] Mastering LLaMA 1: A Complete Walkthrough from Scratch
#
# - Author: Sangkeun Jung (hugmanskj@gmail.com)
#
# > Educational Purpose
#
# **Copyright**: All rights reserved
#
# ---
#
# ### Overview
#
# This hands-on tutorial is designed for those who want to fully understand and master the LLaMA 1 architecture by building it from scratch. We'll break down every component of the model, covering the theory and practical implementation details, to provide a comprehensive guide from the very basics to the final construction.
#
# Throughout this walkthrough, you will:
# - Dive deep into the foundational concepts behind LLaMA 1, such as multi-head attention, feed-forward networks, and the SwiGLU activation function.
# - Implement advanced techniques like Rotary Position Embedding (RoPE) and RMSNorm, which optimize performance and efficiency in large models.
# - Explore LLaMA's key improvements over traditional transformer models, including how it achieves better scalability and efficiency.
# - Verify the correctness of your custom implementation by comparing it to Hugging Face’s official LLaMA 1 model at a high-precision level.
#
# By the end of this tutorial, you'll have a complete understanding of LLaMA 1’s architecture and how to implement it from scratch, making it a powerful resource for both learners and professionals looking to deepen their knowledge of large-scale language models.
#
# ---

# %% [markdown]
# We begin by implementing essential utility functions, such as data loading, model initialization, and training helper functions. These components will be reused across different experimental setups for consistency and efficiency.

# %%
## Importing Libraries

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import numpy as np
import time
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## Hyperparameters and Configuration

# %%
# Modified hyperparameters
SEQUENCE_LENGTH = 64

EMBEDDING_DIM = 256
HIDDEN_DIM = 256

BATCH_SIZE = 512
EPOCHS = 1
LEARNING_RATE = 0.001
PRINT_EVERY = 1000
VALIDATION_SPLIT = 0.1

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %% [markdown]
# ## Data Preparation
#
# We are using the TinyShakespeare dataset, a small character-level text corpus consisting of a subset of Shakespeare's plays. It's often used for testing sequence models, as it includes a rich set of vocabulary and provides a challenging task for next-character prediction.

# %%
## Utility Functions

def load_data(filename):
    with open(filename, 'r', encoding='utf-8') as f:
        return f.read()

def create_char_mappings(text):
    chars = sorted(list(set(text)))
    char_to_idx = {ch: i for i, ch in enumerate(chars)}
    idx_to_char = {i: ch for i, ch in enumerate(chars)}
    return chars, char_to_idx, idx_to_char

# %% [markdown]
# ## Dataset

# %%
# !wget --no-check-certificate 'https://drive.google.com/uc?export=download&id=19zosLuU0z4MxIMKbGVYEGlg52QyfbTIy' -O input.txt

# %%
class CharDataset(Dataset):
    def __init__(self, text, seq_length, char_to_idx):
        self.text = text
        self.seq_length = seq_length
        self.char_to_idx = char_to_idx

    def __len__(self):
        return len(self.text) - self.seq_length

    def __getitem__(self, idx):
        x = [self.char_to_idx[ch] for ch in self.text[idx:idx+self.seq_length]]
        y = [self.char_to_idx[ch] for ch in self.text[idx+1:idx+self.seq_length+1]]
        return torch.tensor(x), torch.tensor(y)

# %% [markdown]
# In autoregressive modeling, each input sequence predicts the next token. For this dataset, the input is a sequence of characters from the text, and the target is the same sequence shifted by one character. This technique allows the model to learn sequential dependencies within the text.

# %%
def prepare_data(text, seq_length, batch_size, val_split):
    chars, char_to_idx, idx_to_char = create_char_mappings(text)

    # Split data into train and validation
    val_size = int(len(text) * val_split)
    train_text, val_text = text[:-val_size], text[-val_size:]

    train_dataset = CharDataset(train_text, seq_length, char_to_idx)
    val_dataset = CharDataset(val_text, seq_length, char_to_idx)

    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

    return train_loader, val_loader, chars, char_to_idx, idx_to_char

# %%
# Load the data
text = load_data('input.txt')
train_loader, val_loader, chars, char_to_idx, idx_to_char = prepare_data(text, SEQUENCE_LENGTH, BATCH_SIZE, VALIDATION_SPLIT)
vocab_size = len(chars)

print(f"Total characters: {len(text)}")
print(f"Vocabulary size: {vocab_size}")
print(f"Train dataset size: {len(train_loader.dataset)}")
print(f"Validation dataset size: {len(val_loader.dataset)}")
# Out:
# Total characters: 1115394
# Vocabulary size: 65
# Train dataset size: 1003791
# Validation dataset size: 111475

# %% [markdown]
# ## Data Visualization

# %%
# Function to convert index sequence to character sequence
def indices_to_text(indices, idx_to_char):
    return ''.join([idx_to_char[idx.item()] for idx in indices])

# Get a batch of data
dataiter = iter(train_loader)
batch_x, batch_y = next(dataiter)

print(f"Input shape: {batch_x.shape}")
print(f"Target shape: {batch_y.shape}")

# Print a few samples from the batch
num_samples = 3
for i in range(num_samples):
    print(f"Sample {i+1}: ------------------------------" )
    print("Input sequence :", indices_to_text(batch_x[i], idx_to_char).replace('\n',''))
    print("Target sequence:", indices_to_text(batch_y[i], idx_to_char).replace('\n',''))
    print()
# Out:
# Input shape: torch.Size([512, 64])
# Target shape: torch.Size([512, 64])
# Sample 1: ------------------------------
# Input sequence : ne.LEONTES:Thou, traitor, hast set on thy wife to this.My ch
# Target sequence: e.LEONTES:Thou, traitor, hast set on thy wife to this.My chi
#
# Sample 2: ------------------------------
# Input sequence : d never will I undertake the thingWherein thy counsel and conse
# Target sequence:  never will I undertake the thingWherein thy counsel and consen
#
# Sample 3: ------------------------------
# Input sequence : cliff, let me tell thee this:To-day shalt thou behold a subject
# Target sequence: liff, let me tell thee this:To-day shalt thou behold a subject

# %% [markdown]
# ## Training Function

# %%
def train(model, dataloader, criterion, optimizer, device, epoch, step, log_interval=10):
    model.train()
    losses = []

    for batch, (x, y) in enumerate(dataloader):
        x, y = x.to(device), y.to(device)
        optimizer.zero_grad()
        output, _ = model(x)
        loss = criterion(output.view(-1, output.size(-1)), y.view(-1))
        loss.backward()
        optimizer.step()

        step += 1
        losses.append((step, epoch, loss.item()))

        if (batch + 1) % log_interval == 0:
            print(f'Epoch {epoch}, Step {step}, Batch {batch+1}/{len(dataloader)}, Loss: {loss.item():.4f}')

    return losses, step

# %%
def validate(model, dataloader, criterion, device, epoch, step):
    model.eval()
    losses = []

    with torch.no_grad():
        for x, y in dataloader:
            x, y = x.to(device), y.to(device)
            output, _ = model(x)
            loss = criterion(output.view(-1, output.size(-1)), y.view(-1))
            losses.append((step, epoch, loss.item()))

    return losses

# %% [markdown]
# ## Generation Function

# %%
def generate(model, char_to_idx, idx_to_char, start_char, max_length, device):
    model.eval()
    hidden = None
    current_char = start_char
    generated_text = current_char

    for _ in range(max_length):
        x = torch.tensor([[char_to_idx[current_char]]]).to(device)
        output, hidden = model(x, hidden)
        probs = torch.softmax(output[0, -1], dim=0)
        next_char_idx = torch.multinomial(probs, 1).item()
        current_char = idx_to_char[next_char_idx]
        generated_text += current_char

    return generated_text

# %%
def train_model(model, train_loader, val_loader, criterion, optimizer, device, epochs, log_interval=10):
    all_train_losses = []
    all_val_losses = []
    step = 0

    for epoch in range(1, epochs + 1):
        print(f"Epoch {epoch}/{epochs}")
        epoch_start_time = time.time()

        # Training phase
        epoch_train_losses, step = train(model, train_loader, criterion, optimizer, device, epoch, step, log_interval)
        all_train_losses.extend(epoch_train_losses)

        # Validation phase
        epoch_val_losses = validate(model, val_loader, criterion, device, epoch, step)
        all_val_losses.extend(epoch_val_losses)

        epoch_time = time.time() - epoch_start_time
        print(f'Epoch {epoch}/{epochs}, '
              f'Train Loss: {epoch_train_losses[-1][2]:.4f}, '
              f'Val Loss: {epoch_val_losses[-1][2]:.4f}, '
              f'Epoch Time: {epoch_time:.2f}s')

    # Create DataFrames after all epochs
    train_losses_df = pd.DataFrame(all_train_losses, columns=['step', 'epoch', 'loss_value'])
    val_losses_df = pd.DataFrame(all_val_losses, columns=['step', 'epoch', 'loss_value'])

    return model, train_losses_df, val_losses_df

# %%
def generate_text(model, char_to_idx, idx_to_char, start_text, device, max_length=500):
    model.eval()
    current_text = start_text
    hidden = None

    with torch.no_grad():
        for _ in range(max_length):
            x = torch.tensor([[char_to_idx[ch] for ch in current_text[-SEQUENCE_LENGTH:]]]).to(device)
            output, hidden = model(x, hidden)
            probs = torch.softmax(output[0, -1], dim=0)
            next_char_idx = torch.multinomial(probs, 1).item()
            next_char = idx_to_char[next_char_idx]
            current_text += next_char

    return current_text

# %%
# Utiltiy functions

# Dictionary to store the losses from different models/configurations
loss_comparison_dict = {}

# Function to add and store losses from different models
def add_loss_to_comparison(model_name, train_losses_df, val_losses_df):
    """
    Adds training and validation losses from a model to the comparison dictionary.

    Args:
    - model_name (str): A name to identify the model (e.g., 'LSTM', 'LSTM with RMSNorm')
    - train_losses_df (DataFrame): DataFrame containing the training losses.
    - val_losses_df (DataFrame): DataFrame containing the validation losses.
    """
    loss_comparison_dict[model_name] = {
        'train': train_losses_df,
        'val': val_losses_df
    }

# %%
# Function to plot loss curves
def plot_loss(train_losses_df, val_losses_df):
    plt.figure(figsize=(10, 5))

    # Plot training losses
    for epoch in train_losses_df['epoch'].unique():
        epoch_train_losses = train_losses_df[train_losses_df['epoch'] == epoch]
        plt.plot(epoch_train_losses['step'], epoch_train_losses['loss_value'],
                 color='blue', alpha=0.3)

    # scatter training loss at the end of each epoch
    last_train_losses = train_losses_df.groupby('epoch').last().reset_index()
    plt.scatter(last_train_losses['step'], last_train_losses['loss_value'],
                color='blue')

    # Plot and scatter validation loss at the end of each epoch
    last_val_losses = val_losses_df.groupby('epoch').last().reset_index()
    plt.plot(last_val_losses['step'], last_val_losses['loss_value'],
             color='orange', label='Validation Loss')
    plt.scatter(last_val_losses['step'], last_val_losses['loss_value'],
                color='orange')

    plt.xlabel('Steps')
    plt.ylabel('Loss')
    plt.title('Training and Validation Loss')
    plt.legend()
    plt.grid(True)
    plt.show()

# Function to print final loss values
def print_final_losses(train_losses_df, val_losses_df):
    print("Final Training Loss:", train_losses_df.groupby('epoch')['loss_value'].last().iloc[-1])
    print("Final Validation Loss:", val_losses_df.groupby('epoch')['loss_value'].last().iloc[-1])

# %%
# Function to plot loss curves for multiple models stored in loss_comparison_dict
def plot_loss_comparisons():
    """
    Plots the training and validation loss curves for multiple models added to the loss comparison dictionary.
    """
    plt.figure(figsize=(10, 5))

    # Get the last model in the dictionary
    last_model_name = list(loss_comparison_dict.keys())[-1]

    # Loop through each model in the loss dictionary
    for model_name, losses in loss_comparison_dict.items():
        train_losses_df = losses['train']
        val_losses_df = losses['val']

        # Plot training losses for each model
        plt.plot(train_losses_df['step'], train_losses_df['loss_value'],
                 label=f'{model_name}', linestyle='-', alpha=0.7)

        # scatter training loss at the end of each epoch
        last_train_losses = train_losses_df.groupby('epoch').last().reset_index()

        # Scatter normal points for all models
        plt.scatter(last_train_losses['step'], last_train_losses['loss_value'], marker='o', s=50)

        # If this is the last model, highlight the last point with a star (no label in legend)
        if model_name == last_model_name:
            final_step = train_losses_df['step'].iloc[-1]
            final_loss = train_losses_df['loss_value'].iloc[-1]
            plt.scatter(final_step, final_loss, marker='*', s=100, color='red', zorder=5)  # Reduced size to s=100

    plt.xlabel('Steps')
    plt.ylabel('Loss')
    plt.title('Training Loss Comparison')
    plt.legend()  # Legend will only show colors, no final star
    plt.grid(True)
    plt.show()

# %% [markdown]
# We have prepared the data and utility functions, let’s implement a simple LSTM-based decoder as a baseline.
#
# This is a foundational model that we’ll use to compare with more advanced architectures like LLaMA. The LSTM decoder will serve as a reference point in terms of performance and complexity.
#
# If you're already familiar with LSTM models, you can skip this section and proceed directly to LLaMA-specific techniques.

# %% [markdown]
# ## LSTM based Decoder

# %%
class LSTMDecoder(nn.Module):
    def __init__(self, vocab_size, embedding_dim, hidden_dim):
        super(LSTMDecoder, self).__init__()
        self.embedding = nn.Embedding(vocab_size, embedding_dim)
        self.lstm = nn.LSTM(embedding_dim, hidden_dim, batch_first=True)
        self.fc = nn.Linear(hidden_dim, vocab_size)

    def forward(self, x, hidden=None):
        embed = self.embedding(x)
        output, hidden = self.lstm(embed, hidden)
        output = self.fc(output)
        return output, hidden

# %%
### Model Initialization
model = LSTMDecoder(vocab_size, EMBEDDING_DIM, HIDDEN_DIM).to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=LEARNING_RATE)

# %%
## Training Loop
trained_model, train_losses_df, val_losses_df = train_model(model, train_loader, val_loader, criterion, optimizer, device, EPOCHS)
# Out:
# Epoch 1/1
# Epoch 1, Step 10, Batch 10/1961, Loss: 3.2082
# Epoch 1, Step 20, Batch 20/1961, Loss: 2.8637
# Epoch 1, Step 30, Batch 30/1961, Loss: 2.6380
# Epoch 1, Step 40, Batch 40/1961, Loss: 2.4971
# Epoch 1, Step 50, Batch 50/1961, Loss: 2.3914
# Epoch 1, Step 60, Batch 60/1961, Loss: 2.3159
# Epoch 1, Step 70, Batch 70/1961, Loss: 2.2400
# Epoch 1, Step 80, Batch 80/1961, Loss: 2.2013
# Epoch 1, Step 90, Batch 90/1961, Loss: 2.1315
# Epoch 1, Step 100, Batch 100/1961, Loss: 2.0965
# Epoch 1, Step 110, Batch 110/1961, Loss: 2.0468
# Epoch 1, Step 120, Batch 120/1961, Loss: 2.0335
# Epoch 1, Step 130, Batch 130/1961, Loss: 1.9996
# Epoch 1, Step 140, Batch 140/1961, Loss: 1.9631
# Epoch 1, Step 150, Batch 150/1961, Loss: 1.9384
# Epoch 1, Step 160, Batch 160/1961, Loss: 1.9222
# Epoch 1, Step 170, Batch 170/1961, Loss: 1.8972
# Epoch 1, Step 180, Batch 180/1961, Loss: 1.8749
# Epoch 1, Step 190, Batch 190/1961, Loss: 1.8399
# Epoch 1, Step 200, Batch 200/1961, Loss: 1.8098
# Epoch 1, Step 210, Batch 210/1961, Loss: 1.7987
# Epoch 1, Step 220, Batch 220/1961, Loss: 1.7971
# Epoch 1, Step 230, Batch 230/1961, Loss: 1.7809
# Epoch 1, Step 240, Batch 240/1961, Loss: 1.7676
# Epoch 1, Step 250, Batch 250/1961, Loss: 1.7386
# Epoch 1, Step 260, Batch 260/1961, Loss: 1.7527
# Epoch 1, Step 270, Batch 270/1961, Loss: 1.7387
# Epoch 1, Step 280, Batch 280/1961, Loss: 1.7187
# Epoch 1, Step 290, Batch 290/1961, Loss: 1.7091
# Epoch 1, Step 300, Batch 300/1961, Loss: 1.6882
# Epoch 1, Step 310, Batch 310/1961, Loss: 1.6958
# Epoch 1, Step 320, Batch 320/1961, Loss: 1.6954
# Epoch 1, Step 330, Batch 330/1961, Loss: 1.6497
# Epoch 1, Step 340, Batch 340/1961, Loss: 1.6396
# Epoch 1, Step 350, Batch 350/1961, Loss: 1.6410
# Epoch 1, Step 360, Batch 360/1961, Loss: 1.6308
# Epoch 1, Step 370, Batch 370/1961, Loss: 1.6157
# Epoch 1, Step 380, Batch 380/1961, Loss: 1.6323
# Epoch 1, Step 390, Batch 390/1961, Loss: 1.6126
# Epoch 1, Step 400, Batch 400/1961, Loss: 1.6012
# Epoch 1, Step 410, Batch 410/1961, Loss: 1.5955
# Epoch 1, Step 420, Batch 420/1961, Loss: 1.5832
# Epoch 1, Step 430, Batch 430/1961, Loss: 1.5790
# Epoch 1, Step 440, Batch 440/1961, Loss: 1.5834
# Epoch 1, Step 450, Batch 450/1961, Loss: 1.5843
# Epoch 1, Step 460, Batch 460/1961, Loss: 1.5700
# Epoch 1, Step 470, Batch 470/1961, Loss: 1.5539
# Epoch 1, Step 480, Batch 480/1961, Loss: 1.5483
# Epoch 1, Step 490, Batch 490/1961, Loss: 1.5685
# Epoch 1, Step 500, Batch 500/1961, Loss: 1.5183
# Epoch 1, Step 510, Batch 510/1961, Loss: 1.5214
# Epoch 1, Step 520, Batch 520/1961, Loss: 1.5261
# Epoch 1, Step 530, Batch 530/1961, Loss: 1.5449
# Epoch 1, Step 540, Batch 540/1961, Loss: 1.5285
# Epoch 1, Step 550, Batch 550/1961, Loss: 1.5233
# Epoch 1, Step 560, Batch 560/1961, Loss: 1.5110
# Epoch 1, Step 570, Batch 570/1961, Loss: 1.5207
# Epoch 1, Step 580, Batch 580/1961, Loss: 1.5212
# Epoch 1, Step 590, Batch 590/1961, Loss: 1.5050
# Epoch 1, Step 600, Batch 600/1961, Loss: 1.4994
# Epoch 1, Step 610, Batch 610/1961, Loss: 1.5017
# Epoch 1, Step 620, Batch 620/1961, Loss: 1.5002
# Epoch 1, Step 630, Batch 630/1961, Loss: 1.5044
# Epoch 1, Step 640, Batch 640/1961, Loss: 1.4697
# Epoch 1, Step 650, Batch 650/1961, Loss: 1.4887
# Epoch 1, Step 660, Batch 660/1961, Loss: 1.4962
# Epoch 1, Step 670, Batch 670/1961, Loss: 1.4708
# Epoch 1, Step 680, Batch 680/1961, Loss: 1.4844
# Epoch 1, Step 690, Batch 690/1961, Loss: 1.4705
# Epoch 1, Step 700, Batch 700/1961, Loss: 1.4826
# Epoch 1, Step 710, Batch 710/1961, Loss: 1.4782
# Epoch 1, Step 720, Batch 720/1961, Loss: 1.4759
# Epoch 1, Step 730, Batch 730/1961, Loss: 1.4638
# Epoch 1, Step 740, Batch 740/1961, Loss: 1.4697
# Epoch 1, Step 750, Batch 750/1961, Loss: 1.4590
# Epoch 1, Step 760, Batch 760/1961, Loss: 1.4521
# Epoch 1, Step 770, Batch 770/1961, Loss: 1.4735
# Epoch 1, Step 780, Batch 780/1961, Loss: 1.4246
# Epoch 1, Step 790, Batch 790/1961, Loss: 1.4505
# Epoch 1, Step 800, Batch 800/1961, Loss: 1.4463
# Epoch 1, Step 810, Batch 810/1961, Loss: 1.4227
# Epoch 1, Step 820, Batch 820/1961, Loss: 1.4426
# Epoch 1, Step 830, Batch 830/1961, Loss: 1.4528
# Epoch 1, Step 840, Batch 840/1961, Loss: 1.4360
# Epoch 1, Step 850, Batch 850/1961, Loss: 1.4410
# Epoch 1, Step 860, Batch 860/1961, Loss: 1.4413
# Epoch 1, Step 870, Batch 870/1961, Loss: 1.4322
# Epoch 1, Step 880, Batch 880/1961, Loss: 1.4454
# Epoch 1, Step 890, Batch 890/1961, Loss: 1.4000
# Epoch 1, Step 900, Batch 900/1961, Loss: 1.4385
# Epoch 1, Step 910, Batch 910/1961, Loss: 1.4402
# Epoch 1, Step 920, Batch 920/1961, Loss: 1.4431
# Epoch 1, Step 930, Batch 930/1961, Loss: 1.4054
# Epoch 1, Step 940, Batch 940/1961, Loss: 1.4235
# Epoch 1, Step 950, Batch 950/1961, Loss: 1.4097
# Epoch 1, Step 960, Batch 960/1961, Loss: 1.4233
# Epoch 1, Step 970, Batch 970/1961, Loss: 1.4255
# Epoch 1, Step 980, Batch 980/1961, Loss: 1.4225
# Epoch 1, Step 990, Batch 990/1961, Loss: 1.4025
# Epoch 1, Step 1000, Batch 1000/1961, Loss: 1.4138
# Epoch 1, Step 1010, Batch 1010/1961, Loss: 1.4122
# Epoch 1, Step 1020, Batch 1020/1961, Loss: 1.4068
# Epoch 1, Step 1030, Batch 1030/1961, Loss: 1.4079
# Epoch 1, Step 1040, Batch 1040/1961, Loss: 1.4053
# Epoch 1, Step 1050, Batch 1050/1961, Loss: 1.4025
# Epoch 1, Step 1060, Batch 1060/1961, Loss: 1.4065
# Epoch 1, Step 1070, Batch 1070/1961, Loss: 1.3940
# Epoch 1, Step 1080, Batch 1080/1961, Loss: 1.3872
# Epoch 1, Step 1090, Batch 1090/1961, Loss: 1.3959
# Epoch 1, Step 1100, Batch 1100/1961, Loss: 1.3896
# Epoch 1, Step 1110, Batch 1110/1961, Loss: 1.3909
# Epoch 1, Step 1120, Batch 1120/1961, Loss: 1.3898
# Epoch 1, Step 1130, Batch 1130/1961, Loss: 1.3867
# Epoch 1, Step 1140, Batch 1140/1961, Loss: 1.4012
# Epoch 1, Step 1150, Batch 1150/1961, Loss: 1.3717
# Epoch 1, Step 1160, Batch 1160/1961, Loss: 1.3744
# Epoch 1, Step 1170, Batch 1170/1961, Loss: 1.3806
# Epoch 1, Step 1180, Batch 1180/1961, Loss: 1.3733
# Epoch 1, Step 1190, Batch 1190/1961, Loss: 1.3820
# Epoch 1, Step 1200, Batch 1200/1961, Loss: 1.3835
# Epoch 1, Step 1210, Batch 1210/1961, Loss: 1.3930
# Epoch 1, Step 1220, Batch 1220/1961, Loss: 1.3857
# Epoch 1, Step 1230, Batch 1230/1961, Loss: 1.3565
# Epoch 1, Step 1240, Batch 1240/1961, Loss: 1.3722
# Epoch 1, Step 1250, Batch 1250/1961, Loss: 1.3656
# Epoch 1, Step 1260, Batch 1260/1961, Loss: 1.3747
# Epoch 1, Step 1270, Batch 1270/1961, Loss: 1.3686
# Epoch 1, Step 1280, Batch 1280/1961, Loss: 1.3853
# Epoch 1, Step 1290, Batch 1290/1961, Loss: 1.3612
# Epoch 1, Step 1300, Batch 1300/1961, Loss: 1.3642
# Epoch 1, Step 1310, Batch 1310/1961, Loss: 1.3672
# Epoch 1, Step 1320, Batch 1320/1961, Loss: 1.3612
# Epoch 1, Step 1330, Batch 1330/1961, Loss: 1.3626
# Epoch 1, Step 1340, Batch 1340/1961, Loss: 1.3521
# Epoch 1, Step 1350, Batch 1350/1961, Loss: 1.3459
# Epoch 1, Step 1360, Batch 1360/1961, Loss: 1.3480
# Epoch 1, Step 1370, Batch 1370/1961, Loss: 1.3560
# Epoch 1, Step 1380, Batch 1380/1961, Loss: 1.3624
# Epoch 1, Step 1390, Batch 1390/1961, Loss: 1.3456
# Epoch 1, Step 1400, Batch 1400/1961, Loss: 1.3595
# Epoch 1, Step 1410, Batch 1410/1961, Loss: 1.3506
# Epoch 1, Step 1420, Batch 1420/1961, Loss: 1.3381
# Epoch 1, Step 1430, Batch 1430/1961, Loss: 1.3598
# Epoch 1, Step 1440, Batch 1440/1961, Loss: 1.3471
# Epoch 1, Step 1450, Batch 1450/1961, Loss: 1.3475
# Epoch 1, Step 1460, Batch 1460/1961, Loss: 1.3602
# Epoch 1, Step 1470, Batch 1470/1961, Loss: 1.3416
# Epoch 1, Step 1480, Batch 1480/1961, Loss: 1.3364
# Epoch 1, Step 1490, Batch 1490/1961, Loss: 1.3408
# Epoch 1, Step 1500, Batch 1500/1961, Loss: 1.3381
# Epoch 1, Step 1510, Batch 1510/1961, Loss: 1.3228
# Epoch 1, Step 1520, Batch 1520/1961, Loss: 1.3560
# Epoch 1, Step 1530, Batch 1530/1961, Loss: 1.3529
# Epoch 1, Step 1540, Batch 1540/1961, Loss: 1.3508
# Epoch 1, Step 1550, Batch 1550/1961, Loss: 1.3279
# Epoch 1, Step 1560, Batch 1560/1961, Loss: 1.3285
# Epoch 1, Step 1570, Batch 1570/1961, Loss: 1.3406
# Epoch 1, Step 1580, Batch 1580/1961, Loss: 1.3367
# Epoch 1, Step 1590, Batch 1590/1961, Loss: 1.3364
# Epoch 1, Step 1600, Batch 1600/1961, Loss: 1.3265
# Epoch 1, Step 1610, Batch 1610/1961, Loss: 1.3384
# Epoch 1, Step 1620, Batch 1620/1961, Loss: 1.3282
# Epoch 1, Step 1630, Batch 1630/1961, Loss: 1.3329
# Epoch 1, Step 1640, Batch 1640/1961, Loss: 1.3298
# Epoch 1, Step 1650, Batch 1650/1961, Loss: 1.3498
# Epoch 1, Step 1660, Batch 1660/1961, Loss: 1.3284
# Epoch 1, Step 1670, Batch 1670/1961, Loss: 1.3301
# Epoch 1, Step 1680, Batch 1680/1961, Loss: 1.3293
# Epoch 1, Step 1690, Batch 1690/1961, Loss: 1.3176
# Epoch 1, Step 1700, Batch 1700/1961, Loss: 1.3312
# Epoch 1, Step 1710, Batch 1710/1961, Loss: 1.3489
# Epoch 1, Step 1720, Batch 1720/1961, Loss: 1.3173
# Epoch 1, Step 1730, Batch 1730/1961, Loss: 1.3324
# Epoch 1, Step 1740, Batch 1740/1961, Loss: 1.3222
# Epoch 1, Step 1750, Batch 1750/1961, Loss: 1.3298
# Epoch 1, Step 1760, Batch 1760/1961, Loss: 1.3158
# Epoch 1, Step 1770, Batch 1770/1961, Loss: 1.3251
# Epoch 1, Step 1780, Batch 1780/1961, Loss: 1.2905
# Epoch 1, Step 1790, Batch 1790/1961, Loss: 1.3163
# Epoch 1, Step 1800, Batch 1800/1961, Loss: 1.3075
# Epoch 1, Step 1810, Batch 1810/1961, Loss: 1.3112
# Epoch 1, Step 1820, Batch 1820/1961, Loss: 1.3285
# Epoch 1, Step 1830, Batch 1830/1961, Loss: 1.3131
# Epoch 1, Step 1840, Batch 1840/1961, Loss: 1.3212
# Epoch 1, Step 1850, Batch 1850/1961, Loss: 1.3272
# Epoch 1, Step 1860, Batch 1860/1961, Loss: 1.3141
# Epoch 1, Step 1870, Batch 1870/1961, Loss: 1.3083
# Epoch 1, Step 1880, Batch 1880/1961, Loss: 1.3208
# Epoch 1, Step 1890, Batch 1890/1961, Loss: 1.3207
# Epoch 1, Step 1900, Batch 1900/1961, Loss: 1.3014
# Epoch 1, Step 1910, Batch 1910/1961, Loss: 1.3123
# Epoch 1, Step 1920, Batch 1920/1961, Loss: 1.3098
# Epoch 1, Step 1930, Batch 1930/1961, Loss: 1.3108
# Epoch 1, Step 1940, Batch 1940/1961, Loss: 1.3009
# Epoch 1, Step 1950, Batch 1950/1961, Loss: 1.3088
# Epoch 1, Step 1960, Batch 1960/1961, Loss: 1.3148
# Epoch 1/1, Train Loss: 1.2918, Val Loss: 1.6261, Epoch Time: 132.20s

# %%
# Text generation using validation data
val_sample, _ = next(iter(val_loader))
start_text = ''.join([idx_to_char[idx.item()] for idx in val_sample[0][:SEQUENCE_LENGTH]])
generated_text = generate_text(trained_model, char_to_idx, idx_to_char, start_text, device)
print(f"Generated text (starting with validation data [{start_text}]):")
print("-"*50)
print(generated_text)
# Out:
# Generated text (starting with validation data [
#
# GREMIO:
# Good morrow, neighbour Baptista.
#
# BAPTISTA:
# Good morro]):
# --------------------------------------------------
#
#
# GREMIO:
# Good morrow, neighbour Baptista.
#
# BAPTISTA:
# Good morrow! O loves,
# Weet dishon live on me, and was! I say, 'tis my are.
# To Citizen:'
# You must do be hearts confesping more:
# There beseeds thee bucket son, he's credity?
#
# Post:
# Yea, nobless, thou, direct it, King:
# 'Tis my son so:
# I mustiness that is yond force that won's heaven,
# And give on the warrancy; so poor sainth,
# The for your grace of take baggation of me.
#
# GLOUCETES:
# 'His sentencas, hither brought
# Arm faith upon action of the word and my measom shall be food:
# And will these blood than blases
# Sta

# %% [markdown]
# The generated text demonstrates that the model has learned some structure, but the coherence is still lacking.
#
# It can form character strings that resemble English but doesn’t create meaningful sentences. This is typical for early-stage character-level models, which struggle to capture long-term dependencies.

# %%
# After training a model (e.g., LSTM without RMSNorm), add its losses
add_loss_to_comparison('LSTM', train_losses_df, val_losses_df)

# %%
# Decoder Input/Output Example
sample_input, _ = next(iter(val_loader))
sample_input = sample_input[0].unsqueeze(0).to(device)  # Add batch dimension

trained_model.eval()
with torch.no_grad():
    output, _ = trained_model(sample_input)

print("\nSample Input:")
print(''.join([idx_to_char[idx.item()] for idx in sample_input[0]]))

print("\nModel Output (logits for next character prediction):")
print(output.shape)
print(output[0, 0, :10])  # Print first 10 logits of the first timestep

print("\nPredicted next character:")
predicted_char_idx = torch.argmax(output[0, -1]).item()
print(idx_to_char[predicted_char_idx])
# Out:
# Sample Input:
#
#
# GREMIO:
# Good morrow, neighbour Baptista.
#
# BAPTISTA:
# Good morro
#
# Model Output (logits for next character prediction):
# torch.Size([1, 64, 65])
# tensor([ 4.8621, -0.4401, -3.3080, -3.0007, -2.0786,  1.0671, -1.9589, -0.7228,
#         -1.8191,  0.5482], device='cuda:0')
#
# Predicted next character:
# w

# %%
# After you've added multiple models, plot the comparison
plot_loss_comparisons()

# %% [markdown]
# We now transition to the core LLaMA components.
#
# From this point, we’ll begin building the essential structures of LLaMA, starting with simple single-head attention-based decoders. We will progressively add complexity to the model, block by block, to achieve a full implementation of LLaMA 1.
#
# Here’s an overview of the steps we’ll follow to build the complete model:
#
# 1. **Single-Head Attention Decoder**:
#    - We start with a basic single-head attention mechanism to familiarize ourselves with attention layers.
#    - This will serve as a foundational block for more complex attention architectures.
#
# 2. **Positional Encoding**:
#    - To provide the model with an understanding of token order, we will add learnable positional embeddings, helping the model understand sequence order and relationships.
#
# 3. **Look-Ahead Masking**:
#    - To prevent the model from seeing future tokens during training, we’ll implement look-ahead masking, ensuring proper autoregressive behavior.
#
# 4. **Layer Normalization (LayerNorm)**:
#    - We’ll introduce LayerNorm, which stabilizes the training process by normalizing the outputs of each layer, improving convergence.
#
# 5. **RMSNorm**:
#    - Next, we’ll swap out LayerNorm with RMSNorm, a more efficient normalization technique used in LLaMA for larger model scalability and better computational efficiency.
#
# 6. **Residual Connections**:
#    - Adding residual connections to preserve important information and prevent the degradation of signals as they pass through multiple layers.
#
# 7. **Feed-Forward Networks (FFNs)**:
#    - We’ll introduce traditional feed-forward layers, followed by LLaMA’s more advanced SwiGLU activation-based feed-forward network, which allows for efficient representation mixing.
#
# 8. **Rotary Position Embedding (RoPE)**:
#    - We’ll enhance the model’s ability to capture positional information by replacing the learnable positional embeddings with Rotary Position Embedding (RoPE), improving the model’s handling of longer sequences.
#
# 9. **Multi-Head Attention (MHA)**:
#    - To scale the attention mechanism, we’ll move from single-head to multi-head attention, allowing the model to attend to multiple parts of the sequence simultaneously.
#
# 10. **Stacking Layers**:
#     - Finally, we will scale the architecture by stacking multiple layers, creating a multi-layer transformer with multi-head attention and feed-forward networks, which is the backbone of the LLaMA architecture.
#
# 11. **Final Verification**:
#     - Once all components are in place, we’ll compare our custom implementation with Hugging Face's official LLaMA 1 model, ensuring that our implementation is accurate and produces identical results in a high-precision environment.
#
# ---

# %% [markdown]
# # Simple Single-Head Attention-Based Decoder
#
# In this section, we implement a basic single-head attention mechanism as a step towards LLaMA.
#
# Attention mechanisms allow models to focus on specific parts of the input sequence when generating predictions, improving the ability to capture relationships between distant tokens.

# %%
import torch
import torch.nn.functional as F

# Single-Head Attention (Very Basic)
class SingleHeadAttention(nn.Module):
    def __init__(self, d_model, seq_length):
        super(SingleHeadAttention, self).__init__()
        self.d_model = d_model
        self.seq_length = seq_length

        self.query = nn.Linear(d_model, d_model, bias=False)
        self.key = nn.Linear(d_model, d_model, bias=False)
        self.value = nn.Linear(d_model, d_model, bias=False)
        self.fc_out = nn.Linear(d_model, d_model, bias=False)

    def forward(self, x):
        Q = self.query(x)
        K = self.key(x)
        V = self.value(x)

        # Scaled dot-product attention
        attention_scores = torch.matmul(Q, K.transpose(-2, -1)) / (self.d_model ** 0.5)

        attention_probs = F.softmax(attention_scores, dim=-1)
        attention_output = torch.matmul(attention_probs, V)

        return self.fc_out(attention_output)


# LLaMA Decoder Layer
class LLaMADecoderLayer(nn.Module):
    def __init__(self, embedding_dim, seq_length):
        super(LLaMADecoderLayer, self).__init__()
        self.attention = SingleHeadAttention(embedding_dim, seq_length)

    def forward(self, x):
        attention_output = self.attention(x)
        return attention_output


class LLaMAModel(nn.Module):
    def __init__(self, vocab_size, embedding_dim, seq_length):
        super(LLaMAModel, self).__init__()
        self.embedding = nn.Embedding(vocab_size, embedding_dim)
        self.layer = LLaMADecoderLayer(embedding_dim, seq_length)
        self.fc_out = nn.Linear(embedding_dim, vocab_size, bias=False) # lm_head

    def forward(self, idx, targets=None):
        x = self.embedding(idx)
        x = self.layer(x)
        logits = self.fc_out(x)

        if targets is not None:
            loss = F.cross_entropy(logits.view(-1, logits.size(-1)), targets.view(-1))
            return logits, loss
        return logits, None

# %% [markdown]
# For this initial implementation, we employ a simple approach to text generation using single-head attention.
#
# Although there are more sophisticated generation methods, this basic version will allow us to observe the performance of the model with attention mechanisms in place.

# %%
def generate_text_attention(model, char_to_idx, idx_to_char, start_text, device, max_length=500):
    model.eval()
    current_text = start_text

    with torch.no_grad():
        for _ in range(max_length):
            # Convert the last sequence of characters to indices and feed it to the model
            x = torch.tensor([[char_to_idx[ch] for ch in current_text[-SEQUENCE_LENGTH:]]]).to(device)
            output = model(x)[0]  # No hidden state needed for attention-based models
            probs = torch.softmax(output[0, -1], dim=0)
            next_char_idx = torch.multinomial(probs, 1).item()
            next_char = idx_to_char[next_char_idx]
            current_text += next_char

    return current_text

# %%
def train_and_test(model_desc, start_text):
    # Initialize the model
    model_llama = LLaMAModel(vocab_size, EMBEDDING_DIM, SEQUENCE_LENGTH).to(device)

    # Use the same optimizer and criterion
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model_llama.parameters(), lr=LEARNING_RATE)

    # Train the model
    trained_model, train_losses_df, val_losses_df = train_model(
        model_llama, train_loader, val_loader, criterion, optimizer, device, EPOCHS
    )

    # Generate text
    generated_text = generate_text_attention(trained_model, char_to_idx, idx_to_char, start_text, device)
    print(f"Generated text [{start_text}]:")
    print("-"*50)
    print(generated_text)

    add_loss_to_comparison(model_desc, train_losses_df, val_losses_df)

    # Plot loss comparisons including this model
    plot_loss_comparisons()

# %%
train_and_test("SHA", start_text)
# Out:
# Epoch 1/1
# Epoch 1, Step 10, Batch 10/1961, Loss: 3.1406
# Epoch 1, Step 20, Batch 20/1961, Loss: 2.9080
# Epoch 1, Step 30, Batch 30/1961, Loss: 2.7888
# Epoch 1, Step 40, Batch 40/1961, Loss: 2.7164
# Epoch 1, Step 50, Batch 50/1961, Loss: 2.6772
# Epoch 1, Step 60, Batch 60/1961, Loss: 2.6456
# Epoch 1, Step 70, Batch 70/1961, Loss: 2.6225
# Epoch 1, Step 80, Batch 80/1961, Loss: 2.5720
# Epoch 1, Step 90, Batch 90/1961, Loss: 2.5620
# Epoch 1, Step 100, Batch 100/1961, Loss: 2.5594
# Epoch 1, Step 110, Batch 110/1961, Loss: 2.5456
# Epoch 1, Step 120, Batch 120/1961, Loss: 2.5302
# Epoch 1, Step 130, Batch 130/1961, Loss: 2.5246
# Epoch 1, Step 140, Batch 140/1961, Loss: 2.5237
# Epoch 1, Step 150, Batch 150/1961, Loss: 2.5266
# Epoch 1, Step 160, Batch 160/1961, Loss: 2.5279
# Epoch 1, Step 170, Batch 170/1961, Loss: 2.5013
# Epoch 1, Step 180, Batch 180/1961, Loss: 2.5112
# Epoch 1, Step 190, Batch 190/1961, Loss: 2.4921
# Epoch 1, Step 200, Batch 200/1961, Loss: 2.4723
# Epoch 1, Step 210, Batch 210/1961, Loss: 2.4741
# Epoch 1, Step 220, Batch 220/1961, Loss: 2.4531
# Epoch 1, Step 230, Batch 230/1961, Loss: 2.4502
# Epoch 1, Step 240, Batch 240/1961, Loss: 2.4523
# Epoch 1, Step 250, Batch 250/1961, Loss: 2.4476
# Epoch 1, Step 260, Batch 260/1961, Loss: 2.4390
# Epoch 1, Step 270, Batch 270/1961, Loss: 2.4316
# Epoch 1, Step 280, Batch 280/1961, Loss: 2.3937
# Epoch 1, Step 290, Batch 290/1961, Loss: 2.4114
# Epoch 1, Step 300, Batch 300/1961, Loss: 2.4041
# Epoch 1, Step 310, Batch 310/1961, Loss: 2.3990
# Epoch 1, Step 320, Batch 320/1961, Loss: 2.3696
# Epoch 1, Step 330, Batch 330/1961, Loss: 2.3807
# Epoch 1, Step 340, Batch 340/1961, Loss: 2.3731
# Epoch 1, Step 350, Batch 350/1961, Loss: 2.3662
# Epoch 1, Step 360, Batch 360/1961, Loss: 2.3472
# Epoch 1, Step 370, Batch 370/1961, Loss: 2.3480
# Epoch 1, Step 380, Batch 380/1961, Loss: 2.3558
# Epoch 1, Step 390, Batch 390/1961, Loss: 2.3494
# Epoch 1, Step 400, Batch 400/1961, Loss: 2.3410
# Epoch 1, Step 410, Batch 410/1961, Loss: 2.3423
# Epoch 1, Step 420, Batch 420/1961, Loss: 2.3376
# Epoch 1, Step 430, Batch 430/1961, Loss: 2.3275
# Epoch 1, Step 440, Batch 440/1961, Loss: 2.3211
# Epoch 1, Step 450, Batch 450/1961, Loss: 2.3154
# Epoch 1, Step 460, Batch 460/1961, Loss: 2.3249
# Epoch 1, Step 470, Batch 470/1961, Loss: 2.3037
# Epoch 1, Step 480, Batch 480/1961, Loss: 2.3211
# Epoch 1, Step 490, Batch 490/1961, Loss: 2.3140
# Epoch 1, Step 500, Batch 500/1961, Loss: 2.3100
# Epoch 1, Step 510, Batch 510/1961, Loss: 2.3034
# Epoch 1, Step 520, Batch 520/1961, Loss: 2.3013
# Epoch 1, Step 530, Batch 530/1961, Loss: 2.2974
# Epoch 1, Step 540, Batch 540/1961, Loss: 2.3007
# Epoch 1, Step 550, Batch 550/1961, Loss: 2.2949
# Epoch 1, Step 560, Batch 560/1961, Loss: 2.3022
# Epoch 1, Step 570, Batch 570/1961, Loss: 2.2881
# Epoch 1, Step 580, Batch 580/1961, Loss: 2.2733
# Epoch 1, Step 590, Batch 590/1961, Loss: 2.2827
# Epoch 1, Step 600, Batch 600/1961, Loss: 2.2814
# Epoch 1, Step 610, Batch 610/1961, Loss: 2.2857
# Epoch 1, Step 620, Batch 620/1961, Loss: 2.2755
# Epoch 1, Step 630, Batch 630/1961, Loss: 2.2722
# Epoch 1, Step 640, Batch 640/1961, Loss: 2.2855
# Epoch 1, Step 650, Batch 650/1961, Loss: 2.2831
# Epoch 1, Step 660, Batch 660/1961, Loss: 2.2758
# Epoch 1, Step 670, Batch 670/1961, Loss: 2.2778
# Epoch 1, Step 680, Batch 680/1961, Loss: 2.2641
# Epoch 1, Step 690, Batch 690/1961, Loss: 2.2740
# Epoch 1, Step 700, Batch 700/1961, Loss: 2.2759
# Epoch 1, Step 710, Batch 710/1961, Loss: 2.2718
# Epoch 1, Step 720, Batch 720/1961, Loss: 2.2787
# Epoch 1, Step 730, Batch 730/1961, Loss: 2.2702
# Epoch 1, Step 740, Batch 740/1961, Loss: 2.2756
# Epoch 1, Step 750, Batch 750/1961, Loss: 2.2773
# Epoch 1, Step 760, Batch 760/1961, Loss: 2.2692
# Epoch 1, Step 770, Batch 770/1961, Loss: 2.2777
# Epoch 1, Step 780, Batch 780/1961, Loss: 2.2723
# Epoch 1, Step 790, Batch 790/1961, Loss: 2.2673
# Epoch 1, Step 800, Batch 800/1961, Loss: 2.2670
# Epoch 1, Step 810, Batch 810/1961, Loss: 2.2737
# Epoch 1, Step 820, Batch 820/1961, Loss: 2.2746
# Epoch 1, Step 830, Batch 830/1961, Loss: 2.2739
# Epoch 1, Step 840, Batch 840/1961, Loss: 2.2711
# Epoch 1, Step 850, Batch 850/1961, Loss: 2.2676
# Epoch 1, Step 860, Batch 860/1961, Loss: 2.2797
# Epoch 1, Step 870, Batch 870/1961, Loss: 2.2732
# Epoch 1, Step 880, Batch 880/1961, Loss: 2.2688
# Epoch 1, Step 890, Batch 890/1961, Loss: 2.2624
# Epoch 1, Step 900, Batch 900/1961, Loss: 2.2645
# Epoch 1, Step 910, Batch 910/1961, Loss: 2.2555
# Epoch 1, Step 920, Batch 920/1961, Loss: 2.2550
# Epoch 1, Step 930, Batch 930/1961, Loss: 2.2630
# Epoch 1, Step 940, Batch 940/1961, Loss: 2.2623
# Epoch 1, Step 950, Batch 950/1961, Loss: 2.2536
# Epoch 1, Step 960, Batch 960/1961, Loss: 2.2519
# Epoch 1, Step 970, Batch 970/1961, Loss: 2.2428
# Epoch 1, Step 980, Batch 980/1961, Loss: 2.2543
# Epoch 1, Step 990, Batch 990/1961, Loss: 2.2716
# Epoch 1, Step 1000, Batch 1000/1961, Loss: 2.2571
# Epoch 1, Step 1010, Batch 1010/1961, Loss: 2.2548
# Epoch 1, Step 1020, Batch 1020/1961, Loss: 2.2616
# Epoch 1, Step 1030, Batch 1030/1961, Loss: 2.2678
# Epoch 1, Step 1040, Batch 1040/1961, Loss: 2.2551
# Epoch 1, Step 1050, Batch 1050/1961, Loss: 2.2572
# Epoch 1, Step 1060, Batch 1060/1961, Loss: 2.2527
# Epoch 1, Step 1070, Batch 1070/1961, Loss: 2.2566
# Epoch 1, Step 1080, Batch 1080/1961, Loss: 2.2485
# Epoch 1, Step 1090, Batch 1090/1961, Loss: 2.2670
# Epoch 1, Step 1100, Batch 1100/1961, Loss: 2.2647
# Epoch 1, Step 1110, Batch 1110/1961, Loss: 2.2613
# Epoch 1, Step 1120, Batch 1120/1961, Loss: 2.2674
# Epoch 1, Step 1130, Batch 1130/1961, Loss: 2.2529
# Epoch 1, Step 1140, Batch 1140/1961, Loss: 2.2495
# Epoch 1, Step 1150, Batch 1150/1961, Loss: 2.2519
# Epoch 1, Step 1160, Batch 1160/1961, Loss: 2.2646
# Epoch 1, Step 1170, Batch 1170/1961, Loss: 2.2437
# Epoch 1, Step 1180, Batch 1180/1961, Loss: 2.2539
# Epoch 1, Step 1190, Batch 1190/1961, Loss: 2.2659
# Epoch 1, Step 1200, Batch 1200/1961, Loss: 2.2523
# Epoch 1, Step 1210, Batch 1210/1961, Loss: 2.2609
# Epoch 1, Step 1220, Batch 1220/1961, Loss: 2.2486
# Epoch 1, Step 1230, Batch 1230/1961, Loss: 2.2577
# Epoch 1, Step 1240, Batch 1240/1961, Loss: 2.2527
# Epoch 1, Step 1250, Batch 1250/1961, Loss: 2.2477
# Epoch 1, Step 1260, Batch 1260/1961, Loss: 2.2613
# Epoch 1, Step 1270, Batch 1270/1961, Loss: 2.2476
# Epoch 1, Step 1280, Batch 1280/1961, Loss: 2.2476
# Epoch 1, Step 1290, Batch 1290/1961, Loss: 2.2606
# Epoch 1, Step 1300, Batch 1300/1961, Loss: 2.2492
# Epoch 1, Step 1310, Batch 1310/1961, Loss: 2.2562
# Epoch 1, Step 1320, Batch 1320/1961, Loss: 2.2483
# Epoch 1, Step 1330, Batch 1330/1961, Loss: 2.2602
# Epoch 1, Step 1340, Batch 1340/1961, Loss: 2.2424
# Epoch 1, Step 1350, Batch 1350/1961, Loss: 2.2481
# Epoch 1, Step 1360, Batch 1360/1961, Loss: 2.2643
# Epoch 1, Step 1370, Batch 1370/1961, Loss: 2.2527
# Epoch 1, Step 1380, Batch 1380/1961, Loss: 2.2565
# Epoch 1, Step 1390, Batch 1390/1961, Loss: 2.2692
# Epoch 1, Step 1400, Batch 1400/1961, Loss: 2.2454
# Epoch 1, Step 1410, Batch 1410/1961, Loss: 2.2579
# Epoch 1, Step 1420, Batch 1420/1961, Loss: 2.2515
# Epoch 1, Step 1430, Batch 1430/1961, Loss: 2.2567
# Epoch 1, Step 1440, Batch 1440/1961, Loss: 2.2532
# Epoch 1, Step 1450, Batch 1450/1961, Loss: 2.2333
# Epoch 1, Step 1460, Batch 1460/1961, Loss: 2.2569
# Epoch 1, Step 1470, Batch 1470/1961, Loss: 2.2548
# Epoch 1, Step 1480, Batch 1480/1961, Loss: 2.2512
# Epoch 1, Step 1490, Batch 1490/1961, Loss: 2.2593
# Epoch 1, Step 1500, Batch 1500/1961, Loss: 2.2500
# Epoch 1, Step 1510, Batch 1510/1961, Loss: 2.2478
# Epoch 1, Step 1520, Batch 1520/1961, Loss: 2.2600
# Epoch 1, Step 1530, Batch 1530/1961, Loss: 2.2487
# Epoch 1, Step 1540, Batch 1540/1961, Loss: 2.2630
# Epoch 1, Step 1550, Batch 1550/1961, Loss: 2.2482
# Epoch 1, Step 1560, Batch 1560/1961, Loss: 2.2494
# Epoch 1, Step 1570, Batch 1570/1961, Loss: 2.2470
# Epoch 1, Step 1580, Batch 1580/1961, Loss: 2.2492
# Epoch 1, Step 1590, Batch 1590/1961, Loss: 2.2394
# Epoch 1, Step 1600, Batch 1600/1961, Loss: 2.2551
# Epoch 1, Step 1610, Batch 1610/1961, Loss: 2.2496
# Epoch 1, Step 1620, Batch 1620/1961, Loss: 2.2626
# Epoch 1, Step 1630, Batch 1630/1961, Loss: 2.2493
# Epoch 1, Step 1640, Batch 1640/1961, Loss: 2.2529
# Epoch 1, Step 1650, Batch 1650/1961, Loss: 2.2543
# Epoch 1, Step 1660, Batch 1660/1961, Loss: 2.2610
# Epoch 1, Step 1670, Batch 1670/1961, Loss: 2.2545
# Epoch 1, Step 1680, Batch 1680/1961, Loss: 2.2465
# Epoch 1, Step 1690, Batch 1690/1961, Loss: 2.2622
# Epoch 1, Step 1700, Batch 1700/1961, Loss: 2.2564
# Epoch 1, Step 1710, Batch 1710/1961, Loss: 2.2489
# Epoch 1, Step 1720, Batch 1720/1961, Loss: 2.2338
# Epoch 1, Step 1730, Batch 1730/1961, Loss: 2.2706
# Epoch 1, Step 1740, Batch 1740/1961, Loss: 2.2459
# Epoch 1, Step 1750, Batch 1750/1961, Loss: 2.2400
# Epoch 1, Step 1760, Batch 1760/1961, Loss: 2.2487
# Epoch 1, Step 1770, Batch 1770/1961, Loss: 2.2461
# Epoch 1, Step 1780, Batch 1780/1961, Loss: 2.2461
# Epoch 1, Step 1790, Batch 1790/1961, Loss: 2.2483
# Epoch 1, Step 1800, Batch 1800/1961, Loss: 2.2545
# Epoch 1, Step 1810, Batch 1810/1961, Loss: 2.2429
# Epoch 1, Step 1820, Batch 1820/1961, Loss: 2.2356
# Epoch 1, Step 1830, Batch 1830/1961, Loss: 2.2322
# Epoch 1, Step 1840, Batch 1840/1961, Loss: 2.2369
# Epoch 1, Step 1850, Batch 1850/1961, Loss: 2.2503
# Epoch 1, Step 1860, Batch 1860/1961, Loss: 2.2434
# Epoch 1, Step 1870, Batch 1870/1961, Loss: 2.2324
# Epoch 1, Step 1880, Batch 1880/1961, Loss: 2.2353
# Epoch 1, Step 1890, Batch 1890/1961, Loss: 2.2331
# Epoch 1, Step 1900, Batch 1900/1961, Loss: 2.2454
# Epoch 1, Step 1910, Batch 1910/1961, Loss: 2.2500
# Epoch 1, Step 1920, Batch 1920/1961, Loss: 2.2305
# Epoch 1, Step 1930, Batch 1930/1961, Loss: 2.2457
# Epoch 1, Step 1940, Batch 1940/1961, Loss: 2.2341
# Epoch 1, Step 1950, Batch 1950/1961, Loss: 2.2429
# Epoch 1, Step 1960, Batch 1960/1961, Loss: 2.2426
# Epoch 1/1, Train Loss: 2.2300, Val Loss: 2.3003, Epoch Time: 96.99s
# Generated text [
#
# GREMIO:
# Good morrow, neighbour Baptista.
#
# BAPTISTA:
# Good morro]:
# --------------------------------------------------
#
#
# GREMIO:
# Good morrow, neighbour Baptista.
#
# BAPTISTA:
# Good morrotr:
# BRoobrostooertstotoe BRorome ...

# %% [markdown]
# The performance of this simple attention model lags behind the LSTM model. There are several reasons for this:
# - Lack of positional encoding, which hinders the model’s ability to understand the sequence order.
# - Single-head attention may not capture sufficient complexity in relationships between tokens.
# - Basic architecture without residual connections or normalization can limit model performance.

# %% [markdown]
# ## SHA + Positional Encoding
#
# Unlike LSTM models, attention-based models do not inherently understand the order of tokens. To address this, we introduce positional encoding, which provides the model with information about the sequence order. In this case, we use a learnable positional embedding, similar to how BERT models incorporate positional information.

# %%
import torch
import torch.nn.functional as F

class SingleHeadAttention(nn.Module):
    def __init__(self, d_model, seq_length):
        super(SingleHeadAttention, self).__init__()
        self.d_model = d_model
        self.seq_length = seq_length

        self.query = nn.Linear(d_model, d_model, bias=False)
        self.key = nn.Linear(d_model, d_model, bias=False)
        self.value = nn.Linear(d_model, d_model, bias=False)
        self.fc_out = nn.Linear(d_model, d_model, bias=False)

    def forward(self, x):
        Q = self.query(x)
        K = self.key(x)
        V = self.value(x)

        # Scaled dot-product attention
        attention_scores = torch.matmul(Q, K.transpose(-2, -1)) / (self.d_model ** 0.5)

        attention_probs = F.softmax(attention_scores, dim=-1)
        attention_output = torch.matmul(attention_probs, V)

        return self.fc_out(attention_output)


# LLaMA Decoder Layer
class LLaMADecoderLayer(nn.Module):
    def __init__(self, embedding_dim, seq_length):
        super(LLaMADecoderLayer, self).__init__()
        self.attention = SingleHeadAttention(embedding_dim, seq_length)

    def forward(self, x):
        attention_output = self.attention(x)
        return attention_output

class LLaMAModel(nn.Module):
    def __init__(self, vocab_size, embedding_dim, seq_length):
        super(LLaMAModel, self).__init__()
        self.embedding = nn.Embedding(vocab_size, embedding_dim)
        self.layer = LLaMADecoderLayer(embedding_dim, seq_length)
        self.fc_out = nn.Linear(embedding_dim, vocab_size, bias=False) # lm_head

        # Learnable Positional Embedding
        self.positional_embedding = nn.Embedding(seq_length, embedding_dim)


    def forward(self, idx, targets=None):
        x = self.embedding(idx)

        # Add positional embeddings to input embeddings
        seq_positions = torch.arange(0, x.size(1), device=x.device).unsqueeze(0)  # Create position indices
        x = x + self.positional_embedding(seq_positions)

        x = self.layer(x)
        logits = self.fc_out(x)

        if targets is not None:
            loss = F.cross_entropy(logits.view(-1, logits.size(-1)), targets.view(-1))
            return logits, loss
        return logits, None

# %%
train_and_test("SHA + POS", start_text)
# Out:
# Epoch 1/1
# Epoch 1, Step 10, Batch 10/1961, Loss: 3.2066
# Epoch 1, Step 20, Batch 20/1961, Loss: 2.9279
# Epoch 1, Step 30, Batch 30/1961, Loss: 2.7616
# Epoch 1, Step 40, Batch 40/1961, Loss: 2.6902
# Epoch 1, Step 50, Batch 50/1961, Loss: 2.3965
# Epoch 1, Step 60, Batch 60/1961, Loss: 0.7449
# Epoch 1, Step 70, Batch 70/1961, Loss: 0.1397
# Epoch 1, Step 80, Batch 80/1961, Loss: 0.0768
# Epoch 1, Step 90, Batch 90/1961, Loss: 0.0620
# Epoch 1, Step 100, Batch 100/1961, Loss: 0.0583
# Epoch 1, Step 110, Batch 110/1961, Loss: 0.0527
# Epoch 1, Step 120, Batch 120/1961, Loss: 0.0501
# Epoch 1, Step 130, Batch 130/1961, Loss: 0.0508
# Epoch 1, Step 140, Batch 140/1961, Loss: 0.0499
# Epoch 1, Step 150, Batch 150/1961, Loss: 0.0506
# Epoch 1, Step 160, Batch 160/1961, Loss: 0.0466
# Epoch 1, Step 170, Batch 170/1961, Loss: 0.0474
# Epoch 1, Step 180, Batch 180/1961, Loss: 0.0466
# Epoch 1, Step 190, Batch 190/1961, Loss: 0.0490
# Epoch 1, Step 200, Batch 200/1961, Loss: 0.0473
# Epoch 1, Step 210, Batch 210/1961, Loss: 0.0479
# Epoch 1, Step 220, Batch 220/1961, Loss: 0.0461
# Epoch 1, Step 230, Batch 230/1961, Loss: 0.0448
# Epoch 1, Step 240, Batch 240/1961, Loss: 0.0448
# Epoch 1, Step 250, Batch 250/1961, Loss: 0.0451

# Generated text [
#
# GREMIO:
# Good morrow, neighbour Baptista.
#
# BAPTISTA:
# Good morro]:
# --------------------------------------------------
#
#
# GREMIO:
# Good morrow, neighbour Baptista.
#
# BAPTISTA:
# Good morro ofre: tito fothera non, teange
# Tirnes foid y.
#
# JnLelt.
#
# Rcen, Whand Is ts than! Awh Hive sadce sheret;
# A thas csamipth abe st ntiveceto ond.
#
# PORKINAD:
# Bar, that thy blous!
#
# Thy this I I nowourgod at sut din tel'd otlifing rat,
# I't whecranid saty shoum?
# No wosutr yu
# Gatre hads imn, I notoest yous ses
# Modave,
# Go omford thaken pprowlo or fre, theren on yt vy, kin ubredd art minned fxeclurowry.
#
# MEWyo ble, and
# Bucat Ed: whalf Cory to us then.
#
# POLURIAD:
# Wherter;
# FoOr aismatre you, mat ord'steirepa

# %% [markdown]
# With look-ahead masking, we obtain more *realistic* performance curves. This method ensures the model no longer has access to future tokens, providing a more challenging, yet authentic, learning task. We now begin to observe the expected loss behavior.

# %% [markdown]
# ## SHA + POS + Masking + Norm(LayerNorm)
#
# Next, we introduce normalization layers into the model. Layer normalization (LayerNorm) stabilizes the training process by normalizing the output of each layer, preventing issues such as exploding or vanishing gradients. We apply LayerNorm before and after the attention mechanism and the feed-forward layer.

# %%
import torch
import torch.nn.functional as F

class SingleHeadAttention(nn.Module):
    def __init__(self, d_model, seq_length):
        super(SingleHeadAttention, self).__init__()
        self.d_model = d_model
        self.seq_length = seq_length

        self.query = nn.Linear(d_model, d_model, bias=False)
        self.key = nn.Linear(d_model, d_model, bias=False)
        self.value = nn.Linear(d_model, d_model, bias=False)
        self.fc_out = nn.Linear(d_model, d_model, bias=False)

    def forward(self, x, mask=None):
        Q = self.query(x)
        K = self.key(x)
        V = self.value(x)

        # Scaled dot-product attention
        attention_scores = torch.matmul(Q, K.transpose(-2, -1)) / (self.d_model ** 0.5)

        # look-ahead masking!
        if mask is not None:
            attention_scores = attention_scores.masked_fill(mask == 0, float('-inf'))

        attention_probs = F.softmax(attention_scores, dim=-1)
        attention_output = torch.matmul(attention_probs, V)

        return self.fc_out(attention_output)


# LLaMA Decoder Layer
class LLaMADecoderLayer(nn.Module):
    def __init__(self, embedding_dim, seq_length):
        super(LLaMADecoderLayer, self).__init__()
        self.attention = SingleHeadAttention(embedding_dim, seq_length)
        self.layernorm1 = nn.LayerNorm(embedding_dim) # pre-norm
        self.layernorm2 = nn.LayerNorm(embedding_dim) # post-norm

    def forward(self, x, mask):
        # Pre-Norm
        normed_x = self.layernorm1(x)

        # Attention
        attention_output = self.attention(normed_x, mask)

        # Post-Norm
        normed_x = self.layernorm2(attention_output)

        return x

class LLaMAModel(nn.Module):
    def __init__(self, vocab_size, embedding_dim, seq_length):
        super(LLaMAModel, self).__init__()
        self.embedding = nn.Embedding(vocab_size, embedding_dim)
        self.layer = LLaMADecoderLayer(embedding_dim, seq_length)
        self.fc_out = nn.Linear(embedding_dim, vocab_size, bias=False) # lm_head

        # final norm after top-layer
        self.layernorm3 = nn.LayerNorm(embedding_dim) # final-norm

        # Learnable Positional Embedding
        self.positional_embedding = nn.Embedding(seq_length, embedding_dim)

    def forward(self, idx, targets=None):
        x = self.embedding(idx)

        # Add positional embeddings to input embeddings
        seq_positions = torch.arange(0, x.size(1), device=x.device).unsqueeze(0)  # Create position indices
        x = x + self.positional_embedding(seq_positions)

        # Look-Ahead Masking
        seq_length = x.size(1)
        mask = torch.tril(torch.ones(seq_length, seq_length)).to(x.device)

        x = self.layer(x, mask)

        # Normalization
        x = self.layernorm3(x)

        logits = self.fc_out(x)

        if targets is not None:
            loss = F.cross_entropy(logits.view(-1, logits.size(-1)), targets.view(-1))
            return logits, loss
        return logits, None

# %%
train_and_test("SHA + POS + Masking + Norm(LayerNorm)", start_text)
# Out:
# Epoch 1/1
# Epoch 1, Step 10, Batch 10/1961, Loss: 3.7614
# Epoch 1, Step 20, Batch 20/1961, Loss: 3.3246
# Epoch 1, Step 30, Batch 30/1961, Loss: 3.0636
# Epoch 1, Step 40, Batch 40/1961, Loss: 2.8858
# Epoch 1, Step 50, Batch 50/1961, Loss: 2.7644
# Epoch 1, Step 60, Batch 60/1961, Loss: 2.7187
# Epoch 1, Step 70, Batch 70/1961, Loss: 2.6624
# Epoch 1, Step 80, Batch 80/1961, Loss: 2.6293
# Epoch 1, Step 90, Batch 90/1961, Loss: 2.5873
# Epoch 1, Step 100, Batch 100/1961, Loss: 2.5696
# Epoch 1, Step 110, Batch 110/1961, Loss: 2.5419
# Epoch 1, Step 120, Batch 120/1961, Loss: 2.5341
# Epoch 1, Step 130, Batch 130/1961, Loss: 2.5189
# Epoch 1, Step 140, Batch 140/1961, Loss: 2.5290
# Epoch 1, Step 150, Batch 150/1961, Loss: 2.5186
# Epoch 1, Step 160, Batch 160/1961, Loss: 2.4996
# Epoch 1, Step 170, Batch 170/1961, Loss: 2.4988
# Epoch 1, Step 180, Batch 180/1961, Loss: 2.5005
# Epoch 1, Step 190, Batch 190/1961, Loss: 2.4966
# Epoch 1, Step 200, Batch 200/1961, Loss: 2.4879
# Epoch 1, Step 210, Batch 210/1961, Loss: 2.4876
# Epoch 1, Step 220, Batch 220/1961, Loss: 2.4966
# Epoch 1, Step 230, Batch 230/1961, Loss: 2.4814
# Epoch 1, Step 240, Batch 240/1961, Loss: 2.4707
# Epoch 1, Step 250, Batch 250/1961, Loss: 2.4806
# Epoch 1, Step 260, Batch 260/1961, Loss: 2.4702
# Epoch 1, Step 270, Batch 270/1961, Loss: 2.4722
# Epoch 1, Step 280, Batch 280/1961, Loss: 2.4687
# Epoch 1, Step 290, Batch 290/1961, Loss: 2.4800
# Epoch 1, Step 300, Batch 300/1961, Loss: 2.4803
# Epoch 1, Step 310, Batch 310/1961, Loss: 2.4693
# Epoch 1, Step 320, Batch 320/1961, Loss: 2.4707
# Epoch 1, Step 330, Batch 330/1961, Loss: 2.4642
# Epoch 1, Step 340, Batch 340/1961, Loss: 2.4677
# Epoch 1, Step 350, Batch 350/1961, Loss: 2.4673
# Epoch 1, Step 360, Batch 360/1961, Loss: 2.4638
# Epoch 1, Step 370, Batch 370/1961, Loss: 2.4654
# Epoch 1, Step 380, Batch 380/1961, Loss: 2.4606
# Epoch 1, Step 390, Batch 390/1961, Loss: 2.4740
# Epoch 1, Step 400, Batch 400/1961, Loss: 2.4633
# Epoch 1, Step 410, Batch 410/1961, Loss: 2.4679
# Epoch 1, Step 420, Batch 420/1961, Loss: 2.4658
# Epoch 1, Step 430, Batch 430/1961, Loss: 2.4610
# Epoch 1, Step 440, Batch 440/1961, Loss: 2.4627
# Epoch 1, Step 450, Batch 450/1961, Loss: 2.4593
# Epoch 1, Step 460, Batch 460/1961, Loss: 2.4647
# Epoch 1, Step 470, Batch 470/1961, Loss: 2.4588
# Epoch 1, Step 480, Batch 480/1961, Loss: 2.4705
# Epoch 1, Step 490, Batch 490/1961, Loss: 2.4633
# Epoch 1, Step 500, Batch 500/1961, Loss: 2.4550
# Epoch 1, Step 510, Batch 510/1961, Loss: 2.4672
# Epoch 1, Step 520, Batch 520/1961, Loss: 2.4631
# Epoch 1, Step 530, Batch 530/1961, Loss: 2.4706
# Epoch 1, Step 540, Batch 540/1961, Loss: 2.4575
# Epoch 1, Step 550, Batch 550/1961, Loss: 2.4563
# Epoch 1, Step 560, Batch 560/1961, Loss: 2.4684
# Epoch 1, Step 570, Batch 570/1961, Loss: 2.4533
# Epoch 1, Step 580, Batch 580/1961, Loss: 2.4656
# Epoch 1, Step 590, Batch 590/1961, Loss: 2.4559
# Epoch 1, Step 600, Batch 600/1961, Loss: 2.4531
# Epoch 1, Step 610, Batch 610/1961, Loss: 2.4522
# Epoch 1, Step 620, Batch 620/1961, Loss: 2.4574
# Epoch 1, Step 630, Batch 630/1961, Loss: 2.4529
# Epoch 1, Step 640, Batch 640/1961, Loss: 2.4631
# Epoch 1, Step 650, Batch 650/1961, Loss: 2.4590
# Epoch 1, Step 660, Batch 660/1961, Loss: 2.4712
# Epoch 1, Step 670, Batch 670/1961, Loss: 2.4507
# Epoch 1, Step 680, Batch 680/1961, Loss: 2.4542
# Epoch 1, Step 690, Batch 690/1961, Loss: 2.4612
# Epoch 1, Step 700, Batch 700/1961, Loss: 2.4649
# Epoch 1, Step 710, Batch 710/1961, Loss: 2.4546
# Epoch 1, Step 720, Batch 720/1961, Loss: 2.4704
# Epoch 1, Step 730, Batch 730/1961, Loss: 2.4517
# Epoch 1, Step 740, Batch 740/1961, Loss: 2.4408
# Epoch 1, Step 750, Batch 750/1961, Loss: 2.4559
# Epoch 1, Step 760, Batch 760/1961, Loss: 2.4560
# Epoch 1, Step 770, Batch 770/1961, Loss: 2.4586
# Epoch 1, Step 780, Batch 780/1961, Loss: 2.4602
# Epoch 1, Step 790, Batch 790/1961, Loss: 2.4563
# Epoch 1, Step 800, Batch 800/1961, Loss: 2.4509
# Epoch 1, Step 810, Batch 810/1961, Loss: 2.4641
# Epoch 1, Step 820, Batch 820/1961, Loss: 2.4581
# Epoch 1, Step 830, Batch 830/1961, Loss: 2.4527
# Epoch 1, Step 840, Batch 840/1961, Loss: 2.4500
# Epoch 1, Step 850, Batch 850/1961, Loss: 2.4638
# Epoch 1, Step 860, Batch 860/1961, Loss: 2.4583
# Epoch 1, Step 870, Batch 870/1961, Loss: 2.4504
# Epoch 1, Step 880, Batch 880/1961, Loss: 2.4517
# Epoch 1, Step 890, Batch 890/1961, Loss: 2.4685
# Epoch 1, Step 900, Batch 900/1961, Loss: 2.4592
# Epoch 1, Step 910, Batch 910/1961, Loss: 2.4652
# Epoch 1, Step 920, Batch 920/1961, Loss: 2.4522
# Epoch 1, Step 930, Batch 930/1961, Loss: 2.4659
# Epoch 1, Step 940, Batch 940/1961, Loss: 2.4577
# Epoch 1, Step 950, Batch 950/1961, Loss: 2.4590
# Epoch 1, Step 960, Batch 960/1961, Loss: 2.4522
# Epoch 1, Step 970, Batch 970/1961, Loss: 2.4569
# Epoch 1, Step 980, Batch 980/1961, Loss: 2.4582
# Epoch 1, Step 990, Batch 990/1961, Loss: 2.4550
# Epoch 1, Step 1000, Batch 1000/1961, Loss: 2.4598
# Epoch 1, Step 1010, Batch 1010/1961, Loss: 2.4613
# Epoch 1, Step 1020, Batch 1020/1961, Loss: 2.4609
# Epoch 1, Step 1030, Batch 1030/1961, Loss: 2.4524
# Epoch 1, Step 1040, Batch 1040/1961, Loss: 2.4632
# Epoch 1, Step 1050, Batch 1050/1961, Loss: 2.4557
# Epoch 1, Step 1060, Batch 1060/1961, Loss: 2.4499
# Epoch 1, Step 1070, Batch 1070/1961, Loss: 2.4665
# Epoch 1, Step 1080, Batch 1080/1961, Loss: 2.4612
# Epoch 1, Step 1090, Batch 1090/1961, Loss: 2.4509
# Epoch 1, Step 1100, Batch 1100/1961, Loss: 2.4663
# Epoch 1, Step 1110, Batch 1110/1961, Loss: 2.4621
# Epoch 1, Step 1120, Batch 1120/1961, Loss: 2.4526
# Epoch 1, Step 1130, Batch 1130/1961, Loss: 2.4562
# Epoch 1, Step 1140, Batch 1140/1961, Loss: 2.4600
# Epoch 1, Step 1150, Batch 1150/1961, Loss: 2.4435
# Epoch 1, Step 1160, Batch 1160/1961, Loss: 2.4620
# Epoch 1, Step 1170, Batch 1170/1961, Loss: 2.4649
# Epoch 1, Step 1180, Batch 1180/1961, Loss: 2.4503
# Epoch 1, Step 1190, Batch 1190/1961, Loss: 2.4526
# Epoch 1, Step 1200, Batch 1200/1961, Loss: 2.4641
# Epoch 1, Step 1210, Batch 1210/1961, Loss: 2.4634
# Epoch 1, Step 1220, Batch 1220/1961, Loss: 2.4610
# Epoch 1, Step 1230, Batch 1230/1961, Loss: 2.4533
# Epoch 1, Step 1240, Batch 1240/1961, Loss: 2.4615
# Epoch 1, Step 1250, Batch 1250/1961, Loss: 2.4573
# Epoch 1, Step 1260, Batch 1260/1961, Loss: 2.4637
# Epoch 1, Step 1270, Batch 1270/1961, Loss: 2.4636
# Epoch 1, Step 1280, Batch 1280/1961, Loss: 2.4617
# Epoch 1, Step 1290, Batch 1290/1961, Loss: 2.4592
# Epoch 1, Step 1300, Batch 1300/1961, Loss: 2.4515
# Epoch 1, Step 1310, Batch 1310/1961, Loss: 2.4581
# Epoch 1, Step 1320, Batch 1320/1961, Loss: 2.4575
# Epoch 1, Step 1330, Batch 1330/1961, Loss: 2.4580
# Epoch 1, Step 1340, Batch 1340/1961, Loss: 2.4637
# Epoch 1, Step 1350, Batch 1350/1961, Loss: 2.4646
# Epoch 1, Step 1360, Batch 1360/1961, Loss: 2.4592
# Epoch 1, Step 1370, Batch 1370/1961, Loss: 2.4515
# Epoch 1, Step 1380, Batch 1380/1961, Loss: 2.4609
# Epoch 1, Step 1390, Batch 1390/1961, Loss: 2.4654
# Epoch 1, Step 1400, Batch 1400/1961, Loss: 2.4520
# Epoch 1, Step 1410, Batch 1410/1961, Loss: 2.4629
# Epoch 1, Step 1420, Batch 1420/1961, Loss: 2.4606
# Epoch 1, Step 1430, Batch 1430/1961, Loss: 2.4520
# Epoch 1, Step 1440, Batch 1440/1961, Loss: 2.4590
# Epoch 1, Step 1450, Batch 1450/1961, Loss: 2.4605
# Epoch 1, Step 1460, Batch 1460/1961, Loss: 2.4511
# Epoch 1, Step 1470, Batch 1470/1961, Loss: 2.4494
# Epoch 1, Step 1480, Batch 1480/1961, Loss: 2.4475
# Epoch 1, Step 1490, Batch 1490/1961, Loss: 2.4632
# Epoch 1, Step 1500, Batch 1500/1961, Loss: 2.4576
# Epoch 1, Step 1510, Batch 1510/1961, Loss: 2.4699
# Epoch 1, Step 1520, Batch 1520/1961, Loss: 2.4625
# Epoch 1, Step 1530, Batch 1530/1961, Loss: 2.4612
# Epoch 1, Step 1540, Batch 1540/1961, Loss: 2.4520
# Epoch 1, Step 1550, Batch 1550/1961, Loss: 2.4523
# Epoch 1, Step 1560, Batch 1560/1961, Loss: 2
# Epoch 1, Step 1640, Batch 1640/1961, Loss: 2.0407
# Epoch 1, Step 1650, Batch 1650/1961, Loss: 2.0391
# Epoch 1, Step 1660, Batch 1660/1961, Loss: 2.0498
# Epoch 1, Step 1670, Batch 1670/1961, Loss: 2.0265
# Epoch 1, Step 1680, Batch 1680/1961, Loss: 2.0438
# Epoch 1, Step 1690, Batch 1690/1961, Loss: 2.0400
# Epoch 1, Step 1700, Batch 1700/1961, Loss: 2.0362
# Epoch 1, Step 1710, Batch 1710/1961, Loss: 2.0370
# Epoch 1, Step 1720, Batch 1720/1961, Loss: 2.0338
# Epoch 1, Step 1730, Batch 1730/1961, Loss: 2.0422
# Epoch 1, Step 1740, Batch 1740/1961, Loss: 2.0366
# Epoch 1, Step 1750, Batch 1750/1961, Loss: 2.0429
# Epoch 1, Step 1760, Batch 1760/1961, Loss: 2.0577
# Epoch 1, Step 1770, Batch 1770/1961, Loss: 2.0369
# Epoch 1, Step 1780, Batch 1780/1961, Loss: 2.0341
# Epoch 1, Step 1790, Batch 1790/1961, Loss: 2.0347
# Epoch 1, Step 1800, Batch 1800/1961, Loss: 2.0269
# Epoch 1, Step 1810, Batch 1810/1961, Loss: 2.0189
# Epoch 1, Step 1820, Batch 1820/1961, Loss: 2.0349
# Epoch 1, Step 1830, Batch 1830/1961, Loss: 2.0249
# Epoch 1, Step 1840, Batch 1840/1961, Loss: 2.0450
# Epoch 1, Step 1850, Batch 1850/1961, Loss: 2.0367
# Epoch 1, Step 1860, Batch 1860/1961, Loss: 2.0401
# Epoch 1, Step 1870, Batch 1870/1961, Loss: 2.0213
# Epoch 1, Step 1880, Batch 1880/1961, Loss: 2.0293
# Epoch 1, Step 1890, Batch 1890/1961, Loss: 2.0383
# Epoch 1, Step 1900, Batch 1900/1961, Loss: 2.0118
# Epoch 1, Step 1910, Batch 1910/1961, Loss: 2.0359
# Epoch 1, Step 1920, Batch 1920/1961, Loss: 2.0459
# Epoch 1, Step 1930, Batch 1930/1961, Loss: 2.0410
# Epoch 1, Step 1940, Batch 1940/1961, Loss: 2.0138
# Epoch 1, Step 1950, Batch 1950/1961, Loss: 2.0408
# Epoch 1, Step 1960, Batch 1960/1961, Loss: 2.0325
# Epoch 1/1, Train Loss: 2.0378, Val Loss: 2.2744, Epoch Time: 124.98s
# Generated text [
#
# GREMIO:
# Good morrow, neighbour Baptista.
#
# BAPTISTA:
# Good morro]:
# --------------------------------------------------
#
#
# GREMIO:
# Good morrow, neighbour Baptista.
#
# BAPTISTA:
# Good morrom muthe his refed upe gove nobeaprin
# Hermy
# Hasp tought he hourdast sin not,
# I kidly Bery mos fer't.
#
# ROKES:
# Hagef food lera the fesus thins Comerit pon'd
# Whathe drule, be waicendred.  thonown ithe forembet beir ought.
#
# GLOUCHES Moded, seet of you cat I waid And gave und's histit camifo mo a will.
#
# ANGERONCE:
# Conger:
# The wid' mon? Whe cund my younde.
#
# Nor
# As bell for
# Thave to thenity,
# Your thene;
# And nos ingoombe toove thas there hancer, an, blactles min, whom genherswe; witherp, 'I wes dreen ind

# %% [markdown]
# Residual connections help prevent the degradation of information as it passes through multiple layers.
#
# By adding the input directly to the output of certain layers (e.g., attention and feed-forward layers), we ensure that important information isn't lost during the transformation process.

# %% [markdown]
# ## SHA + POS + Masking + RMSNorm + Residual + FeedForward(Original)

# %% [markdown]
# In the original transformer architecture, the feed-forward network consisted of a simple projection up to a higher dimensional space, followed by a projection back down. Typically, the up-projection dimension is four times the input dimension. This basic feed-forward architecture provides powerful feature mixing.

# %%
import torch
import torch.nn.functional as F

class SingleHeadAttention(nn.Module):
    def __init__(self, d_model, seq_length):
        super(SingleHeadAttention, self).__init__()
        self.d_model = d_model
        self.seq_length = seq_length

        self.query = nn.Linear(d_model, d_model, bias=False)
        self.key = nn.Linear(d_model, d_model, bias=False)
        self.value = nn.Linear(d_model, d_model, bias=False)
        self.fc_out = nn.Linear(d_model, d_model, bias=False)

    def forward(self, x, mask=None):
        Q = self.query(x)
        K = self.key(x)
        V = self.value(x)

        # Scaled dot-product attention
        attention_scores = torch.matmul(Q, K.transpose(-2, -1)) / (self.d_model ** 0.5)

        # look-ahead masking!
        if mask is not None:
            attention_scores = attention_scores.masked_fill(mask == 0, float('-inf'))

        attention_probs = F.softmax(attention_scores, dim=-1)
        attention_output = torch.matmul(attention_probs, V)

        return self.fc_out(attention_output)


# Custom RMSNorm to match LLaMA 1 official implementation
class RMSNorm(nn.Module):
    def __init__(self, d_model, eps=1e-6):
        super(RMSNorm, self).__init__()
        self.weight = nn.Parameter(torch.ones(d_model))
        self.eps = eps

    def _norm(self, x):
        # Compute variance and apply reciprocal square root for RMS normalization
        return x * torch.rsqrt(x.pow(2).mean(-1, keepdim=True) + self.eps)

    def forward(self, x):
        # Convert to float32 for precision, then back to original dtype
        output = self._norm(x.float()).type_as(x)
        return output * self.weight

# Original Feed-Forward Network
class FeedForward(nn.Module):
    def __init__(self, d_model):
        super(FeedForward, self).__init__()
        up_hidden_dim = d_model * 4
        self.up_proj = nn.Linear(d_model, up_hidden_dim, bias=False)
        self.down_proj = nn.Linear(up_hidden_dim, d_model, bias=False)
        self.act_fn = F.relu

    def forward(self, x):
        return self.down_proj(self.act_fn(self.up_proj(x)))

# LLaMA Decoder Layer
class LLaMADecoderLayer(nn.Module):
    def __init__(self, embedding_dim, seq_length):
        super(LLaMADecoderLayer, self).__init__()
        self.attention = SingleHeadAttention(embedding_dim, seq_length)
        self.rmsnorm1 = RMSNorm(embedding_dim) # pre-norm
        self.rmsnorm2 = RMSNorm(embedding_dim) # post-norm
        self.feed_forward = FeedForward(embedding_dim)

    def forward(self, x, mask):
        # Pre-Norm
        normed_x = self.rmsnorm1(x)

        # Attention
        attention_output = self.attention(normed_x, mask)

        # Residual connection
        x = x + attention_output

        # Post-Norm
        normed_x = self.rmsnorm2(x)

        feed_forward_output = self.feed_forward(normed_x)

        # Residual Connection
        return x + feed_forward_output

class LLaMAModel(nn.Module):
    def __init__(self, vocab_size, embedding_dim, seq_length):
        super(LLaMAModel, self).__init__()
        self.embedding = nn.Embedding(vocab_size, embedding_dim)
        self.layer = LLaMADecoderLayer(embedding_dim, seq_length)
        self.fc_out = nn.Linear(embedding_dim, vocab_size, bias=False) # lm_head

        self.rmsnorm_f = RMSNorm(embedding_dim) # final_norm

        # Learnable Positional Embedding
        self.positional_embedding = nn.Embedding(seq_length, embedding_dim)

    def forward(self, idx, targets=None):
        x = self.embedding(idx)

        # Add positional embeddings to input embeddings
        seq_positions = torch.arange(0, x.size(1), device=x.device).unsqueeze(0)  # Create position indices
        x = x + self.positional_embedding(seq_positions)

        # Look-Ahead Masking
        seq_length = x.size(1)
        mask = torch.tril(torch.ones(seq_length, seq_length)).to(x.device)

        x = self.layer(x, mask)

        # final norm
        x = self.rmsnorm_f(x)

        logits = self.fc_out(x)

        if targets is not None:
            loss = F.cross_entropy(logits.view(-1, logits.size(-1)), targets.view(-1))
            return logits, loss
        return logits, None

# %%
train_and_test("SHA + POS + Masking + RMSNorm + Residual + FF(Original) ", start_text)
# Out:
# Epoch 1/1
# Epoch 1, Step 10, Batch 10/1961, Loss: 3.0082
# Epoch 1, Step 20, Batch 20/1961, Loss: 2.7458
# Epoch 1, Step 30, Batch 30/1961, Loss: 2.5974
# Epoch 1, Step 40, Batch 40/1961, Loss: 2.5306
# Epoch 1, Step 50, Batch 50/1961, Loss: 2.4856
# Epoch 1, Step 60, Batch 60/1961, Loss: 2.4070
# Epoch 1, Step 70, Batch 70/1961, Loss: 2.3157
# Epoch 1, Step 80, Batch 80/1961, Loss: 2.2594
# Epoch 1, Step 90, Batch 90/1961, Loss: 2.2295
# Epoch 1, Step 100, Batch 100/1961, Loss: 2.1854
# Epoch 1, Step 110, Batch 110/1961, Loss: 2.1659
# Epoch 1, Step 120, Batch 120/1961, Loss: 2.1295
# Epoch 1, Step 130, Batch 130/1961, Loss: 2.1017
# Epoch 1, Step 140, Batch 140/1961, Loss: 2.0718
# Epoch 1, Step 150, Batch 150/1961, Loss: 2.0499
# Epoch 1, Step 160, Batch 160/1961, Loss: 2.0452
# Epoch 1, Step 170, Batch 170/1961, Loss: 2.0105
# Epoch 1, Step 180, Batch 180/1961, Loss: 2.0176
# Epoch 1, Step 190, Batch 190/1961, Loss: 1.9866
# Epoch 1, Step 200, Batch 200/1961, Loss: 1.9779
# Epoch 1, Step 210, Batch 210/1961, Loss: 1.9720
# Epoch 1, Step 220, Batch 220/1961, Loss: 1.9430
# Epoch 1, Step 230, Batch 230/1961, Loss: 1.9609
# Epoch 1, Step 240, Batch 240/1961, Loss: 1.9092
# Epoch 1, Step 250, Batch 250/1961, Loss: 1.8984
# Epoch 1, Step 260, Batch 260/1961, Loss: 1.8990
# Epoch 1, Step 270, Batch 270/1961, Loss: 1.8875
# Epoch 1, Step 280, Batch 280/1961, Loss: 1.8898
# Epoch 1, Step 290, Batch 290/1961, Loss: 1.8689
# Epoch 1, Step 300, Batch 300/1961, Loss: 1.8672
# Epoch 1, Step 310, Batch 310/1961, Loss: 1.8751
# Epoch 1, Step 320, Batch 320/1961, Loss: 1.8396
# Epoch 1, Step 330, Batch 330/1961, Loss: 1.8474
# Epoch 1, Step 340, Batch 340/1961, Loss: 1.8155
# Epoch 1, Step 350, Batch 350/1961, Loss: 1.8181
# Epoch 1, Step 360, Batch 360/1961, Loss: 1.8008
# Epoch 1, Step 370, Batch 370/1961, Loss: 1.8104
# Epoch 1, Step 380, Batch 380/1961, Loss: 1.7815
# Epoch 1, Step 390, Batch 390/1961, Loss: 1.7665
# Epoch 1, Step 400, Batch 400/1961, Loss: 1.7855
# Epoch 1, Step 410, Batch 410/1961, Loss: 1.7644
# Epoch 1, Step 420, Batch 420/1961, Loss: 1.7598
# Epoch 1, Step 430, Batch 430/1961, Loss: 1.7471
# Epoch 1, Step 440, Batch 440/1961, Loss: 1.7561
# Epoch 1, Step 450, Batch 450/1961, Loss: 1.7460
# Epoch 1, Step 460, Batch 460/1961, Loss: 1.7469
# Epoch 1, Step 470, Batch 470/1961, Loss: 1.7198
# Epoch 1, Step 480, Batch 480/1961, Loss: 1.7220
# Epoch 1, Step 490, Batch 490/1961, Loss: 1.7204
# Epoch 1, Step 500, Batch 500/1961, Loss: 1.6989
# Epoch 1, Step 510, Batch 510/1961, Loss: 1.6937
# Epoch 1, Step 520, Batch 520/1961, Loss: 1.6982
# Epoch 1, Step 530, Batch 530/1961, Loss: 1.6846
# Epoch 1, Step 540, Batch 540/1961, Loss: 1.6766
# Epoch 1, Step 550, Batch 550/1961, Loss: 1.6508
# Epoch 1, Step 560, Batch 560/1961, Loss: 1.6671
# Epoch 1, Step 570, Batch 570/1961, Loss: 1.6735
# Epoch 1, Step 580, Batch 580/1961, Loss: 1.6813
# Epoch 1, Step 590, Batch 590/1961, Loss: 1.6607
# Epoch 1, Step 600, Batch 600/1961, Loss: 1.6537
# Epoch 1, Step 610, Batch 610/1961, Loss: 1.6440
# Epoch 1, Step 620, Batch 620/1961, Loss: 1.6523
# Epoch 1, Step 630, Batch 630/1961, Loss: 1.6440
# Epoch 1, Step 640, Batch 640/1961, Loss: 1.6383
# Epoch 1, Step 650, Batch 650/1961, Loss: 1.6288
# Epoch 1, Step 660, Batch 660/1961, Loss: 1.6392
# Epoch 1, Step 670, Batch 670/1961, Loss: 1.6347
# Epoch 1, Step 680, Batch 680/1961, Loss: 1.6299
# Epoch 1, Step 690, Batch 690/1961, Loss: 1.6428
# Epoch 1, Step 700, Batch 700/1961, Loss: 1.6194
# Epoch 1, Step 710, Batch 710/1961, Loss: 1.6248
# Epoch 1, Step 720, Batch 720/1961, Loss: 1.6231
# Epoch 1, Step 730, Batch 730/1961, Loss: 1.6251
# Epoch 1, Step 740, Batch 740/1961, Loss: 1.6273
# Epoch 1, Step 750, Batch 750/1961, Loss: 1.6168
# Epoch 1, Step 760, Batch 760/1961, Loss: 1.6009
# Epoch 1, Step 770, Batch 770/1961, Loss: 1.5998
# Epoch 1, Step 780, Batch 780/1961, Loss: 1.5814
# Epoch 1, Step 790, Batch 790/1961, Loss: 1.6079
# Epoch 1, Step 800, Batch 800/1961, Loss: 1.5786
# Epoch 1, Step 810, Batch 810/1961, Loss: 1.5866
# Epoch 1, Step 820, Batch 820/1961, Loss: 1.5943
# Epoch 1, Step 830, Batch 830/1961, Loss: 1.5845
# Epoch 1, Step 840, Batch 840/1961, Loss: 1.6011
# Epoch 1, Step 850, Batch 850/1961, Loss: 1.5902
# Epoch 1, Step 860, Batch 860/1961, Loss: 1.6111
# Epoch 1, Step 870, Batch 870/1961, Loss: 1.5859
# Epoch 1, Step 880, Batch 880/1961, Loss: 1.5865
# Epoch 1, Step 890, Batch 890/1961, Loss: 1.5818
# Epoch 1, Step 900, Batch 900/1961, Loss: 1.5780
# Epoch 1, Step 910, Batch 910/1961, Loss: 1.5734
# Epoch 1, Step 920, Batch 920/1961, Loss: 1.5687
# Epoch 1, Step 930, Batch 930/1961, Loss: 1.5725
# Epoch 1, Step 940, Batch 940/1961, Loss: 1.5690
# Epoch 1, Step 950, Batch 950/1961, Loss: 1.5562
# Epoch 1, Step 960, Batch 960/1961, Loss: 1.5664
# Epoch 1, Step 970, Batch 970/1961, Loss: 1.5698
# Epoch 1, Step 980, Batch 980/1961, Loss: 1.5606
# Epoch 1, Step 990, Batch 990/1961, Loss: 1.5619
# Epoch 1, Step 1000, Batch 1000/1961, Loss: 1.5586
# Epoch 1, Step 1010, Batch 1010/1961, Loss: 1.5682
# Epoch 1, Step 1020, Batch 1020/1961, Loss: 1.5529
# Epoch 1, Step 1030, Batch 1030/1961, Loss: 1.5455
# Epoch 1, Step 1040, Batch 1040/1961, Loss: 1.5700
# Epoch 1, Step 1050, Batch 1050/1961, Loss: 1.5594
# Epoch 1, Step 1060, Batch 1060/1961, Loss: 1.5286
# Epoch 1, Step 1070, Batch 1070/1961, Loss: 1.5526
# Epoch 1, Step 1080, Batch 1080/1961, Loss: 1.5670
# Epoch 1, Step 1090, Batch 1090/1961, Loss: 1.5547
# Epoch 1, Step 1100, Batch 1100/1961, Loss: 1.5640
# Epoch 1, Step 1110, Batch 1110/1961, Loss: 1.5329
# Epoch 1, Step 1120, Batch 1120/1961, Loss: 1.5476
# Epoch 1, Step 1130, Batch 1130/1961, Loss: 1.5368
# Epoch 1, Step 1140, Batch 1140/1961, Loss: 1.5499
# Epoch 1, Step 1150, Batch 1150/1961, Loss: 1.5391
# Epoch 1, Step 1160, Batch 1160/1961, Loss: 1.5064
# Epoch 1, Step 1170, Batch 1170/1961, Loss: 1.5318
# Epoch 1, Step 1180, Batch 1180/1961, Loss: 1.5390
# Epoch 1, Step 1190, Batch 1190/1961, Loss: 1.5467
# Epoch 1, Step 1200, Batch 1200/1961, Loss: 1.5206
# Epoch 1, Step 1210, Batch 1210/1961, Loss: 1.5211
# Epoch 1, Step 1220, Batch 1220/1961, Loss: 1.5051
# Epoch 1, Step 1230, Batch 1230/1961, Loss: 1.5103
# Epoch 1, Step 1240, Batch 1240/1961, Loss: 1.5224
# Epoch 1, Step 1250, Batch 1250/1961, Loss: 1.5161
# Epoch 1, Step 1260, Batch 1260/1961, Loss: 1.5157
# Epoch 1, Step 1270, Batch 1270/1961, Loss: 1.5288
# Epoch 1, Step 1280, Batch 1280/1961, Loss: 1.5245
# Epoch 1, Step 1290, Batch 1290/1961, Loss: 1.5205
# Epoch 1, Step 1300, Batch 1300/1961, Loss: 1.5101
# Epoch 1, Step 1310, Batch 1310/1961, Loss: 1.5065
# Epoch 1, Step 1320, Batch 1320/1961, Loss: 1.5342
# Epoch 1, Step 1330, Batch 1330/1961, Loss: 1.5025
# Epoch 1, Step 1340, Batch 1340/1961, Loss: 1.5089
# Epoch 1, Step 1350, Batch 1350/1961, Loss: 1.4967
# Epoch 1, Step 1360, Batch 1360/1961, Loss: 1.4987
# Epoch 1, Step 1370, Batch 1370/1961, Loss: 1.5026
# Epoch 1, Step 1380, Batch 1380/1961, Loss: 1.5005
# Epoch 1, Step 1390, Batch 1390/1961, Loss: 1.5009
# Epoch 1, Step 1400, Batch 1400/1961, Loss: 1.5187
# Epoch 1, Step 1410, Batch 1410/1961, Loss: 1.5095
# Epoch 1, Step 1420, Batch 1420/1961, Loss: 1.5201
# Epoch 1, Step 1430, Batch 1430/1961, Loss: 1.5047
# Epoch 1, Step 1440, Batch 1440/1961, Loss: 1.4907
# Epoch 1, Step 1450, Batch 1450/1961, Loss: 1.4903
# Epoch 1, Step 1460, Batch 1460/1961, Loss: 1.4985
# Epoch 1, Step 1470, Batch 1470/1961, Loss: 1.5079
# Epoch 1, Step 1480, Batch 1480/1961, Loss: 1.5119
# Epoch 1, Step 1490, Batch 1490/1961, Loss: 1.5066
# Epoch 1, Step 1500, Batch 1500/1961, Loss: 1.4867
# Epoch 1, Step 1510, Batch 1510/1961, Loss: 1.4970
# Epoch 1, Step 1520, Batch 1520/1961, Loss: 1.4955
# Epoch 1, Step 1530, Batch 1530/1961, Loss: 1.5071
# Epoch 1, Step 1540, Batch 1540/1961, Loss: 1.4972
# Epoch 1, Step 1550, Batch 1550/1961, Loss: 1.5134
# Epoch 1, Step 1560, Batch 1560/1961, Loss: 1.5052
# Epoch 1, Step 1570, Batch 1570/1961, Loss: 1.4946
# Epoch 1, Step 1580, Batch 1580/1961, Loss: 1.4939
# Epoch 1, Step 1590, Batch 1590/1961, Loss: 1.4857
# Epoch 1, Step 1600, Batch 1600/1961, Loss: 1.4904
# Epoch 1, Step 1610, Batch 1610/1961, Loss: 1.4982
# Epoch 1, Step 1620, Batch 1620/1961, Loss: 1.4966
# Epoch 1, Step 1630, Batch 1630/1961, Loss: 1.4765
# Epoch 1, Step 1640, Batch 1640/1961, Loss: 1.5000
# Epoch 1, Step 1650, Batch 1650/1961, Loss: 1.5008
# Epoch 1, Step 1660, Batch 1660/1961, Loss: 1.4875
# Epoch 1, Step 1670, Batch 1670/1961, Loss: 1.4969
# Epoch 1, Step 1680, Batch 1680/1961, Loss: 1.4879
# Epoch 1, Step 1690, Batch 1690/1961, Loss: 1.4871
# Epoch 1, Step 1700, Batch 1700/1961, Loss: 1.5012
# Epoch 1, Step 1710, Batch 1710/1961, Loss: 1.4665
# Epoch 1, Step 1720, Batch 1720/1961, Loss: 1.4919
# Epoch 1, Step 1730, Batch 1730/1961, Loss: 1.4572
# Epoch 1, Step 1740, Batch 1740/1961, Loss: 1.4836
# Epoch 1, Step 1750, Batch 1750/1961, Loss: 1.4763
# Epoch 1, Step 1760, Batch 1760/1961, Loss: 1.4999
# Epoch 1, Step 1770, Batch 1770/1961, Loss: 1.4781
# Epoch 1, Step 1780, Batch 1780/1961, Loss: 1.4675
# Epoch 1, Step 1790, Batch 1790/1961, Loss: 1.4775
# Epoch 1, Step 1800, Batch 1800/1961, Loss: 1.4879
# Epoch 1, Step 1810, Batch 1810/1961, Loss: 1.4713
# Epoch 1, Step 1820, Batch 1820/1961, Loss: 1.4897
# Epoch 1, Step 1830, Batch 1830/1961, Loss: 1.4677
# Epoch 1, Step 1840, Batch 1840/1961, Loss: 1.4943
# Epoch 1, Step 1850, Batch 1850/1961, Loss: 1.4670
# Epoch 1, Step 1860, Batch 1860/1961, Loss: 1.4527
# Epoch 1, Step 1870, Batch 1870/1961, Loss: 1.4618
# Epoch 1, Step 1880, Batch 1880/1961, Loss: 1.4714
# Epoch 1, Step 1890, Batch 1890/1961, Loss: 1.4599
# Epoch 1, Step 1900, Batch 1900/1961, Loss: 1.4822
# Epoch 1, Step 1910, Batch 1910/1961, Loss: 1.4683
# Epoch 1, Step 1920, Batch 1920/1961, Loss: 1.4616
# Epoch 1, Step 1930, Batch 1930/1961, Loss: 1.4660
# Epoch 1, Step 1940, Batch 1940/1961, Loss: 1.4681
# Epoch 1, Step 1950, Batch 1950/1961, Loss: 1.4754
# Epoch 1, Step 1960, Batch 1960/1961, Loss: 1.4680
# Epoch 1/1, Train Loss: 1.4680, Val Loss: 1.9295, Epoch Time: 169.08s
# Generated text [
#
# GREMIO:
# Good morrow, neighbour Baptista.
#
# BAPTISTA:
# Good morro]:
# --------------------------------------------------
#
#
# GREMIO:
# Good morrow, neighbour Baptista.
#
# BAPTISTA:
# Good morrow she, is follant advock'd both a kinclums a
# trefer, pity to that are fismer, and I'ead,
# All where most shappy.
#
# LARTIUS:
# I saw are you full: would him of this non wipt to be poor follow thyself
# Requer, I speak, have art me be to me that wailt welcome to beliest thee with Cominius;
# For Isabe so nexted with thinks; so Mintual to well follow nor a prepare qua.
#
# RICHARD III:
# Then, when as thy for he, now, poor the did my royal will, mask base my intence,
# O I should vay, acreason of heavy both Servi

# %% [markdown]
# Introducing the feed-forward network brings the performance closer to that of the LSTM model. The network now has a mechanism for better mixing information across dimensions, resulting in improved predictions.

# %% [markdown]
# ## SHA + POS + Masking + RMSNorm + Residual + FeedForward(Implicit Gating)
#
# LLaMA uses a more advanced feed-forward mechanism called SwiGLU, which incorporates implicit gating and SiLU activations. This design is more efficient in handling non-linearities and enhances model expressiveness. We will now switch to this feed-forward method to observe its impact.

# %%
import torch
import torch.nn.functional as F

class SingleHeadAttention(nn.Module):
    def __init__(self, d_model, seq_length):
        super(SingleHeadAttention, self).__init__()
        self.d_model = d_model
        self.seq_length = seq_length

        self.query = nn.Linear(d_model, d_model, bias=False)
        self.key = nn.Linear(d_model, d_model, bias=False)
        self.value = nn.Linear(d_model, d_model, bias=False)
        self.fc_out = nn.Linear(d_model, d_model, bias=False)

    def forward(self, x, mask=None):
        Q = self.query(x)
        K = self.key(x)
        V = self.value(x)

        # Scaled dot-product attention
        attention_scores = torch.matmul(Q, K.transpose(-2, -1)) / (self.d_model ** 0.5)

        # look-ahead masking!
        if mask is not None:
            attention_scores = attention_scores.masked_fill(mask == 0, float('-inf'))

        attention_probs = F.softmax(attention_scores, dim=-1)
        attention_output = torch.matmul(attention_probs, V)

        return self.fc_out(attention_output)


# Custom RMSNorm to match LLaMA 1 official implementation
class RMSNorm(nn.Module):
    def __init__(self, d_model, eps=1e-6):
        super(RMSNorm, self).__init__()
        self.weight = nn.Parameter(torch.ones(d_model))
        self.eps = eps

    def _norm(self, x):
        # Compute variance and apply reciprocal square root for RMS normalization
        return x * torch.rsqrt(x.pow(2).mean(-1, keepdim=True) + self.eps)

    def forward(self, x):
        # Convert to float32 for precision, then back to original dtype
        output = self._norm(x.float()).type_as(x)
        return output * self.weight

# Feed-Forward Network with implicit gating
import math
class FeedForward(nn.Module):
    def __init__(self, d_model, multiple_of):
        super(FeedForward, self).__init__()
        up_hidden_dim = multiple_of * math.ceil((d_model * 4 * 2 / 3) / multiple_of)
        ###### self.gate_proj, self.up_proj, self.down_proj 정의 ######
        self.gate_proj =
        self.up_proj =
        self.down_proj =
        self.act_fn = F.silu  # SiLU activation

    def forward(self, x):
        ### feedforward 작성 ###
        return

# LLaMA Decoder Layer
class LLaMADecoderLayer(nn.Module):
    def __init__(self, embedding_dim, multiple_of, seq_length):
        super(LLaMADecoderLayer, self).__init__()
        self.attention = SingleHeadAttention(embedding_dim, seq_length)
        self.rmsnorm1 = RMSNorm(embedding_dim) # pre-norm
        self.rmsnorm2 = RMSNorm(embedding_dim) # post-norm

        self.feed_forward = FeedForward(embedding_dim, multiple_of)


    def forward(self, x, mask):
        # Pre-Norm
        normed_x = self.rmsnorm1(x)

        # Attention
        attention_output = self.attention(normed_x, mask)

        # Residual connection
        x = x + attention_output

        # Post-Norm
        normed_x = self.rmsnorm2(x)

        feed_forward_output = self.feed_forward(normed_x)

        # Residual Connection
        return x + feed_forward_output


class LLaMAModel(nn.Module):
    def __init__(self, vocab_size, embedding_dim, seq_length, multiple_of):
        super(LLaMAModel, self).__init__()
        self.embedding = nn.Embedding(vocab_size, embedding_dim)
        self.layer = LLaMADecoderLayer(embedding_dim, multiple_of, seq_length)
        self.fc_out = nn.Linear(embedding_dim, vocab_size, bias=False) # lm_head

        self.rmsnorm_f = RMSNorm(embedding_dim) # final_norm

        # Learnable Positional Embedding
        self.positional_embedding = nn.Embedding(seq_length, embedding_dim)


    def forward(self, idx, targets=None):
        x = self.embedding(idx)

        # Add positional embeddings to input embeddings
        seq_positions = torch.arange(0, x.size(1), device=x.device).unsqueeze(0)  # Create position indices
        x = x + self.positional_embedding(seq_positions)

        # Look-Ahead Masking
        seq_length = x.size(1)
        mask = torch.tril(torch.ones(seq_length, seq_length)).to(x.device)

        x = self.layer(x, mask)

        # final norm
        x = self.rmsnorm_f(x)

        logits = self.fc_out(x)

        if targets is not None:
            loss = F.cross_entropy(logits.view(-1, logits.size(-1)), targets.view(-1))
            return logits, loss
        return logits, None

# %%
def train_and_test(model_desc, start_text, multiple_of):
    # Initialize the model
    model_llama = LLaMAModel(vocab_size, EMBEDDING_DIM, SEQUENCE_LENGTH, multiple_of).to(device)

    # Use the same optimizer and criterion
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model_llama.parameters(), lr=LEARNING_RATE)

    # Train the model
    trained_model, train_losses_df, val_losses_df = train_model(
        model_llama, train_loader, val_loader, criterion, optimizer, device, EPOCHS
    )

    # Generate text
    generated_text = generate_text_attention(trained_model, char_to_idx, idx_to_char, start_text, device)
    print(f"Generated text [{start_text}]:")
    print("-"*50)
    print(generated_text)

    add_loss_to_comparison(model_desc, train_losses_df, val_losses_df)

    # Plot loss comparisons including this model
    plot_loss_comparisons()

# %% [markdown]
# In the LLaMA 1 implementation, the up-projection dimension is not simply calculated as 4 times the hidden dimension, as seen in the original transformers. Instead, LLaMA uses a more efficient approach where the up-projection dimension is a multiple of a specific value, often 256, to optimize for GPU performance.
#
# The formula for calculating the up-projection dimension is as follows:
#
# $$
# up\_hidden\_dim = multiple\_of \times \left\lceil \frac{hidden\_dim \times 4 \times \frac{2}{3}}{multiple\_of} \right\rceil
# $$
#
# For example, if the hidden dimension is 4096 and the `multiple_of` value is 256, the calculation is:
#
# $$
# up\_hidden\_dim = 256 \times \left\lceil \frac{4096 \times 4 \times \frac{2}{3}}{256} \right\rceil
# $$
#
# This results in:
#
# $$
# up\_hidden\_dim = 256 \times \left\lceil \frac{10922.6667}{256} \right\rceil = 256 \times 43 = 11008
# $$
#
# #### Why use `multiple_of = 256`?
#
# - **GPU Efficiency**:
#   - Modern hardware like GPUs and TPUs are optimized for matrix operations when the tensor dimensions are multiples of powers of 2, such as 32, 64, 128, or 256.
#   - Rounding dimensions to multiples of 256 ensures memory alignment and maximizes parallel processing efficiency, reducing wasted memory bandwidth and improving throughput during matrix computations.
#
# In this example, instead of using LLaMA 1's typical value of 256 for `multiple_of`, we use a smaller value, such as 8, for demonstration purposes. This allows us to explore the architecture with limited computational resources while maintaining the structure of the model.

# %%
multiple_of = 8   # roughly dim * 1/16
train_and_test("SHA + POS + Masking + RMSNorm + Residual + FF(SwiGLU)", start_text, multiple_of)
# Out:
# Epoch 1/1
# Epoch 1, Step 10, Batch 10/1961, Loss: 3.1406
# Epoch 1, Step 20, Batch 20/1961, Loss: 2.7777
# Epoch 1, Step 30, Batch 30/1961, Loss: 2.6457
# Epoch 1, Step 40, Batch 40/1961, Loss: 2.5477
# Epoch 1, Step 50, Batch 50/1961, Loss: 2.5016
# Epoch 1, Step 60, Batch 60/1961, Loss: 2.4585
# Epoch 1, Step 70, Batch 70/1961, Loss: 2.4089
# Epoch 1, Step 80, Batch 80/1961, Loss: 2.3042
# Epoch 1, Step 90, Batch 90/1961, Loss: 2.2676
# Epoch 1, Step 100, Batch 100/1961, Loss: 2.2207
# Epoch 1, Step 110, Batch 110/1961, Loss: 2.2016
# Epoch 1, Step 120, Batch 120/1961, Loss: 2.1564
# Epoch 1, Step 130, Batch 130/1961, Loss: 2.1367
# Epoch 1, Step 140, Batch 140/1961, Loss: 2.1119
# Epoch 1, Step 150, Batch 150/1961, Loss: 2.0580
# Epoch 1, Step 160, Batch 160/1961, Loss: 2.0466
# Epoch 1, Step 170, Batch 170/1961, Loss: 2.0081
# Epoch 1, Step 180, Batch 180/1961, Loss: 2.0001
# Epoch 1, Step 190, Batch 190/1961, Loss: 1.9820
# Epoch 1, Step 200, Batch 200/1961, Loss: 1.9666
# Epoch 1, Step 210, Batch 210/1961, Loss: 1.9573
# Epoch 1, Step 220, Batch 220/1961, Loss: 1.9370
# Epoch 1, Step 230, Batch 230/1961, Loss: 1.9249
# Epoch 1, Step 240, Batch 240/1961, Loss: 1.9000
# Epoch 1, Step 250, Batch 250/1961, Loss: 1.8945
# Epoch 1, Step 260, Batch 260/1961, Loss: 1.8886
# Epoch 1, Step 270, Batch 270/1961, Loss: 1.8694
# Epoch 1, Step 280, Batch 280/1961, Loss: 1.8663
# Epoch 1, Step 290, Batch 290/1961, Loss: 1.8363
# Epoch 1, Step 300, Batch 300/1961, Loss: 1.8285
# Epoch 1, Step 310, Batch 310/1961, Loss: 1.8097
# Epoch 1, Step 320, Batch 320/1961, Loss: 1.8101
# Epoch 1, Step 330, Batch 330/1961, Loss: 1.7805
# Epoch 1, Step 340, Batch 340/1961, Loss: 1.7882
# Epoch 1, Step 350, Batch 350/1961, Loss: 1.7759
# Epoch 1, Step 360, Batch 360/1961, Loss: 1.7708
# Epoch 1, Step 370, Batch 370/1961, Loss: 1.7588
# Epoch 1, Step 380, Batch 380/1961, Loss: 1.7614
# Epoch 1, Step 390, Batch 390/1961, Loss: 1.7475
# Epoch 1, Step 400, Batch 400/1961, Loss: 1.7300
# Epoch 1, Step 410, Batch 410/1961, Loss: 1.7396
# Epoch 1, Step 420, Batch 420/1961, Loss: 1.7278
# Epoch 1, Step 430, Batch 430/1961, Loss: 1.7286
# Epoch 1, Step 440, Batch 440/1961, Loss: 1.7032
# Epoch 1, Step 450, Batch 450/1961, Loss: 1.7006
# Epoch 1, Step 460, Batch 460/1961, Loss: 1.6918
# Epoch 1, Step 470, Batch 470/1961, Loss: 1.6838
# Epoch 1, Step 480, Batch 480/1961, Loss: 1.6744
# Epoch 1, Step 490, Batch 490/1961, Loss: 1.6848
# Epoch 1, Step 500, Batch 500/1961, Loss: 1.6687
# Epoch 1, Step 510, Batch 510/1961, Loss: 1.6824
# Epoch 1, Step 520, Batch 520/1961, Loss: 1.6431
# Epoch 1, Step 530, Batch 530/1961, Loss: 1.6633
# Epoch 1, Step 540, Batch 540/1961, Loss: 1.6523
# Epoch 1, Step 550, Batch 550/1961, Loss: 1.6569
# Epoch 1, Step 560, Batch 560/1961, Loss: 1.6331
# Epoch 1, Step 570, Batch 570/1961, Loss: 1.6493
# Epoch 1, Step 580, Batch 580/1961, Loss: 1.6448
# Epoch 1, Step 590, Batch 590/1961, Loss: 1.6359
# Epoch 1, Step 600, Batch 600/1961, Loss: 1.6411
# Epoch 1, Step 610, Batch 610/1961, Loss: 1.6111
# Epoch 1, Step 620, Batch 620/1961, Loss: 1.6148
# Epoch 1, Step 630, Batch 630/1961, Loss: 1.6047
# Epoch 1, Step 640, Batch 640/1961, Loss: 1.5899
# Epoch 1, Step 650, Batch 650/1961, Loss: 1.6098
# Epoch 1, Step 660, Batch 660/1961, Loss: 1.5992
# Epoch 1, Step 670, Batch 670/1961, Loss: 1.5749
# Epoch 1, Step 680, Batch 680/1961, Loss: 1.6002
# Epoch 1, Step 690, Batch 690/1961, Loss: 1.5998
# Epoch 1, Step 700, Batch 700/1961, Loss: 1.5838
# Epoch 1, Step 710, Batch 710/1961, Loss: 1.5773
# Epoch 1, Step 720, Batch 720/1961, Loss: 1.5926
# Epoch 1, Step 730, Batch 730/1961, Loss: 1.5795
# Epoch 1, Step 740, Batch 740/1961, Loss: 1.5936
# Epoch 1, Step 750, Batch 750/1961, Loss: 1.5651
# Epoch 1, Step 760, Batch 760/1961, Loss: 1.5581
# Epoch 1, Step 770, Batch 770/1961, Loss: 1.5772
# Epoch 1, Step 780, Batch 780/1961, Loss: 1.5691
# Epoch 1, Step 790, Batch 790/1961, Loss: 1.5379
# Epoch 1, Step 800, Batch 800/1961, Loss: 1.5581
# Epoch 1, Step 810, Batch 810/1961, Loss: 1.5535
# Epoch 1, Step 820, Batch 820/1961, Loss: 1.5574
# Epoch 1, Step 830, Batch 830/1961, Loss: 1.5674
# Epoch 1, Step 840, Batch 840/1961, Loss: 1.5262
# Epoch 1, Step 850, Batch 850/1961, Loss: 1.5469
# Epoch 1, Step 860, Batch 860/1961, Loss: 1.5470
# Epoch 1, Step 870, Batch 870/1961, Loss: 1.5506
# Epoch 1, Step 880, Batch 880/1961, Loss: 1.5502
# Epoch 1, Step 890, Batch 890/1961, Loss: 1.5481
# Epoch 1, Step 900, Batch 900/1961, Loss: 1.5452
# Epoch 1, Step 910, Batch 910/1961, Loss: 1.5310
# Epoch 1, Step 920, Batch 920/1961, Loss: 1.5136
# Epoch 1, Step 930, Batch 930/1961, Loss: 1.5172
# Epoch 1, Step 940, Batch 940/1961, Loss: 1.5106
# Epoch 1, Step 950, Batch 950/1961, Loss: 1.5399
# Epoch 1, Step 960, Batch 960/1961, Loss: 1.5311
# Epoch 1, Step 970, Batch 970/1961, Loss: 1.5213
# Epoch 1, Step 980, Batch 980/1961, Loss: 1.5279
# Epoch 1, Step 990, Batch 990/1961, Loss: 1.5192
# Epoch 1, Step 1000, Batch 1000/1961, Loss: 1.5228
# Epoch 1, Step 1010, Batch 1010/1961, Loss: 1.5078
# Epoch 1, Step 1020, Batch 1020/1961, Loss: 1.5130
# Epoch 1, Step 1030, Batch 1030/1961, Loss: 1.5086
# Epoch 1, Step 1040, Batch 1040/1961, Loss: 1.5044
# Epoch 1, Step 1050, Batch 1050/1961, Loss: 1.5144
# Epoch 1, Step 1060, Batch 1060/1961, Loss: 1.5020
# Epoch 1, Step 1070, Batch 1070/1961, Loss: 1.5069
# Epoch 1, Step 1080, Batch 1080/1961, Loss: 1.5198
# Epoch 1, Step 1090, Batch 1090/1961, Loss: 1.5087
# Epoch 1, Step 1100, Batch 1100/1961, Loss: 1.5021
# Epoch 1, Step 1110, Batch 1110/1961, Loss: 1.5164
# Epoch 1, Step 1120, Batch 1120/1961, Loss: 1.4998
# Epoch 1, Step 1130, Batch 1130/1961, Loss: 1.4907
# Epoch 1, Step 1140, Batch 1140/1961, Loss: 1.5110
# Epoch 1, Step 1150, Batch 1150/1961, Loss: 1.4880
# Epoch 1, Step 1160, Batch 1160/1961, Loss: 1.5083
# Epoch 1, Step 1170, Batch 1170/1961, Loss: 1.5060
# Epoch 1, Step 1180, Batch 1180/1961, Loss: 1.4913
# Epoch 1, Step 1190, Batch 1190/1961, Loss: 1.4831
# Epoch 1, Step 1200, Batch 1200/1961, Loss: 1.4784
# Epoch 1, Step 1210, Batch 1210/1961, Loss: 1.5069
# Epoch 1, Step 1220, Batch 1220/1961, Loss: 1.4931
# Epoch 1, Step 1230, Batch 1230/1961, Loss: 1.4683
# Epoch 1, Step 1240, Batch 1240/1961, Loss: 1.4888
# Epoch 1, Step 1250, Batch 1250/1961, Loss: 1.4810
# Epoch 1, Step 1260, Batch 1260/1961, Loss: 1.4907
# Epoch 1, Step 1270, Batch 1270/1961, Loss: 1.4782
# Epoch 1, Step 1280, Batch 1280/1961, Loss: 1.4959
# Epoch 1, Step 1290, Batch 1290/1961, Loss: 1.4830
# Epoch 1, Step 1300, Batch 1300/1961, Loss: 1.4801
# Epoch 1, Step 1310, Batch 1310/1961, Loss: 1.4798
# Epoch 1, Step 1320, Batch 1320/1961, Loss: 1.4923
# Epoch 1, Step 1330, Batch 1330/1961, Loss: 1.4838
# Epoch 1, Step 1340, Batch 1340/1961, Loss: 1.4788
# Epoch 1, Step 1350, Batch 1350/1961, Loss: 1.4831
# Epoch 1, Step 1360, Batch 1360/1961, Loss: 1.4669
# Epoch 1, Step 1370, Batch 1370/1961, Loss: 1.4616
# Epoch 1, Step 1380, Batch 1380/1961, Loss: 1.4797
# Epoch 1, Step 1390, Batch 1390/1961, Loss: 1.4765
# Epoch 1, Step 1400, Batch 1400/1961, Loss: 1.4652
# Epoch 1, Step 1410, Batch 1410/1961, Loss: 1.4684
# Epoch 1, Step 1420, Batch 1420/1961, Loss: 1.4741
# Epoch 1, Step 1430, Batch 1430/1961, Loss: 1.4561
# Epoch 1, Step 1440, Batch 1440/1961, Loss: 1.4719
# Epoch 1, Step 1450, Batch 1450/1961, Loss: 1.4698
# Epoch 1, Step 1460, Batch 1460/1961, Loss: 1.4642
# Epoch 1, Step 1470, Batch 1470/1961, Loss: 1.4588
# Epoch 1, Step 1480, Batch 1480/1961, Loss: 1.4736
# Epoch 1, Step 1490, Batch 1490/1961, Loss: 1.4641
# Epoch 1, Step 1500, Batch 1500/1961, Loss: 1.4514
# Epoch 1, Step 1510, Batch 1510/1961, Loss: 1.4390
# Epoch 1, Step 1520, Batch 1520/1961, Loss: 1.4721
# Epoch 1, Step 1530, Batch 1530/1961, Loss: 1.4488
# Epoch 1, Step 1540, Batch 1540/1961, Loss: 1.4465
# Epoch 1, Step 1550, Batch 1550/1961, Loss: 1.4615
# Epoch 1, Step 1560, Batch 1560/1961, Loss: 1.4527
# Epoch 1, Step 1570, Batch 1570/1961, Loss: 1.4592
# Epoch 1, Step 1580, Batch 1580/1961, Loss: 1.4622
# Epoch 1, Step 1590, Batch 1590/1961, Loss: 1.4344
# Epoch 1, Step 1600, Batch 1600/1961, Loss: 1.4474
# Epoch 1, Step 1610, Batch 1610/1961, Loss: 1.4652
# Epoch 1, Step 1620, Batch 1620/1961, Loss: 1.4524
# Epoch 1, Step 1630, Batch 1630/1961, Loss: 1.4561
# Epoch 1, Step 1640, Batch 1640/1961, Loss: 1.4514
# Epoch 1, Step 1650, Batch 1650/1961, Loss: 1.4568
# Epoch 1, Step 1660, Batch 1660/1961, Loss: 1.4484
# Epoch 1, Step 1670, Batch 1670/1961, Loss: 1.4413
# Epoch 1, Step 1680, Batch 1680/1961, Loss: 1.4468
# Epoch 1, Step 1690, Batch 1690/1961, Loss: 1.4450
# Epoch 1, Step 1700, Batch 1700/1961, Loss: 1.4264
# Epoch 1, Step 1710, Batch 1710/1961, Loss: 1.4430
# Epoch 1, Step 1720, Batch 1720/1961, Loss: 1.4374
# Epoch 1, Step 1730, Batch 1730/1961, Loss: 1.4295
# Epoch 1, Step 1740, Batch 1740/1961, Loss: 1.4378
# Epoch 1, Step 1750, Batch 1750/1961, Loss: 1.4473
# Epoch 1, Step 1760, Batch 1760/1961, Loss: 1.4461
# Epoch 1, Step 1770, Batch 1770/1961, Loss: 1.4351
# Epoch 1, Step 1780, Batch 1780/1961, Loss: 1.4435
# Epoch 1, Step 1790, Batch 1790/1961, Loss: 1.4499
# Epoch 1, Step 1800, Batch 1800/1961, Loss: 1.4407
# Epoch 1, Step 1810, Batch 1810/1961, Loss: 1.4352
# Epoch 1, Step 1820, Batch 1820/1961, Loss: 1.4282
# Epoch 1, Step 1830, Batch 1830/1961, Loss: 1.4223
# Epoch 1, Step 1840, Batch 1840/1961, Loss: 1.4287
# Epoch 1, Step 1850, Batch 1850/1961, Loss: 1.4544
# Epoch 1, Step 1860, Batch 1860/1961, Loss: 1.4400
# Epoch 1, Step 1870, Batch 1870/1961, Loss: 1.4282
# Epoch 1, Step 1880, Batch 1880/1961, Loss: 1.4317
# Epoch 1, Step 1890, Batch 1890/1961, Loss: 1.4286
# Epoch 1, Step 1900, Batch 1900/1961, Loss: 1.4351
# Epoch 1, Step 1910, Batch 1910/1961, Loss: 1.4361
# Epoch 1, Step 1920, Batch 1920/1961, Loss: 1.4306
# Epoch 1, Step 1930, Batch 1930/1961, Loss: 1.4432
# Epoch 1, Step 1940, Batch 1940/1961, Loss: 1.4356
# Epoch 1, Step 1950, Batch 1950/1961, Loss: 1.4191
# Epoch 1, Step 1960, Batch 1960/1961, Loss: 1.4482
# Epoch 1/1, Train Loss: 1.4003, Val Loss: 1.9093, Epoch Time: 180.63s
# Generated text [
#
# GREMIO:
# Good morrow, neighbour Baptista.
#
# BAPTISTA:
# Good morro]:
# --------------------------------------------------
#
#
# GREMIO:
# Good morrow, neighbour Baptista.
#
# BAPTISTA:
# Good morrow thy men and of thyself
# Or my bastard;
# host stangue scorn! how? thou to grows!
#
# AUbol! O, to you signio, no: you fantage;
# Your, and give I would not thine?
#
# BENVOLIO:
# Tull-sweet common my loyal pace.
#
# Clown:
# He is Behomised he lady here, Claudy, so began:
# Unless but, neverwick.
#
# Can reckly thou dost to see thunder business dead hearts
# Upon of their breather; at'ent I'll and I cannot on guess,
# Definity, and not perproach in
# thoughter Watchman, scourage, that are
# You may by note.
#
# KING RICHARD II

# %% [markdown]
# With SwiGLU, we achieve performance similar to simpler models. However, its true strength becomes apparent in larger models and datasets. As model scale increases, SwiGLU outperforms simpler feed-forward mechanisms. Next, we'll swap out the learnable positional encoding for RoPE.

# %% [markdown]
# ## SHA + POS(ROPE) + Masking + RMSNorm + Residual + FeedForward(Implicit Gating)
#
# Rotary Position Embedding (RoPE) is an advanced method for injecting positional information into the model. It provides a more efficient and scalable way to handle positional information compared to learnable embeddings, especially for longer sequences. RoPE also improves the model's ability to generalize across different sequence lengths.

# %%
import torch
import torch.nn.functional as F

# RoPE: Rotary Position Embedding function
def apply_rotary_pos_emb(q, k, sin, cos):
    ###### 여기 채우기 #####
    q_rot =
    k_rot =
    return q_rot, k_rot

def rotate_half(x):
    x1, x2 = x.chunk(2, dim=-1)
    return torch.cat((-x2, x1), dim=-1)

# in case of single-head head_dim = dim
def build_rope_cache(seq_len, head_dim, device):
    inv_freq = 1.0 / (10000 ** (torch.arange(0, head_dim, 2).float().to(device) / head_dim))
    t = torch.arange(seq_len, device=device).float()
    freqs = torch.einsum('i,j->ij', t, inv_freq)
    emb = torch.cat((freqs, freqs), dim=-1)
    sin, cos = emb.sin(), emb.cos()
    return sin, cos

# Single-Head Attention (Very Basic)
class SingleHeadAttention(nn.Module):
    def __init__(self, d_model, seq_length):
        super(SingleHeadAttention, self).__init__()
        self.d_model = d_model
        self.seq_length = seq_length

        self.query = nn.Linear(d_model, d_model, bias=False)
        self.key = nn.Linear(d_model, d_model, bias=False)
        self.value = nn.Linear(d_model, d_model, bias=False)
        self.fc_out = nn.Linear(d_model, d_model, bias=False)

        # Build RoPE cache
        self.sin, self.cos = build_rope_cache(seq_length, d_model, torch.device('cpu'))

    def forward(self, x, mask=None):
        Q = self.query(x)
        K = self.key(x)
        V = self.value(x)

        # Apply RoPE to Q and K
        batch_size, seq_length, _ = x.size()
        sin, cos = self.sin[:seq_length, :].to(x.device), self.cos[:seq_length, :].to(x.device)
        Q_rot, K_rot = apply_rotary_pos_emb(Q, K, sin, cos)

        # Scaled dot-product attention
        attention_scores = torch.matmul(Q_rot, K_rot.transpose(-2, -1)) / (self.d_model ** 0.5)

        # look-ahead masking!
        if mask is not None:
            attention_scores = attention_scores.masked_fill(mask == 0, float('-inf'))

        attention_probs = F.softmax(attention_scores, dim=-1)
        attention_output = torch.matmul(attention_probs, V)

        return self.fc_out(attention_output)


# Custom RMSNorm to match LLaMA 1 official implementation
class RMSNorm(nn.Module):
    def __init__(self, d_model, eps=1e-6):
        super(RMSNorm, self).__init__()
        self.weight = nn.Parameter(torch.ones(d_model))
        self.eps = eps

    def _norm(self, x):
        # Compute variance and apply reciprocal square root for RMS normalization
        return x * torch.rsqrt(x.pow(2).mean(-1, keepdim=True) + self.eps)

    def forward(self, x):
        # Convert to float32 for precision, then back to original dtype
        output = self._norm(x.float()).type_as(x)
        return output * self.weight

# Feed-Forward Network with implicit gating
import math
class FeedForward(nn.Module):
    def __init__(self, d_model, multiple_of):
        super(FeedForward, self).__init__()
        up_hidden_dim = multiple_of * math.ceil((d_model * 4 * 2 / 3) / multiple_of)
        ###### self.gate_proj, self.up_proj, self.down_proj 정의 ######
        self.gate_proj =
        self.up_proj =
        self.down_proj =
        self.act_fn = F.silu  # SiLU activation

    def forward(self, x):
        ### feedforward 작성 ###
        return

# LLaMA Decoder Layer
class LLaMADecoderLayer(nn.Module):
    def __init__(self, embedding_dim, multiple_of, seq_length):
        super(LLaMADecoderLayer, self).__init__()
        self.attention = SingleHeadAttention(embedding_dim, seq_length)
        self.rmsnorm1 = RMSNorm(embedding_dim) # pre-norm
        self.rmsnorm2 = RMSNorm(embedding_dim) # post-norm

        self.feed_forward = FeedForward(embedding_dim, multiple_of)


    def forward(self, x, mask):
        # Pre-Norm
        normed_x = self.rmsnorm1(x)

        # Attention
        attention_output = self.attention(normed_x, mask)

        # Residual connection
        x = x + attention_output

        # Post-Norm
        normed_x = self.rmsnorm2(x)

        feed_forward_output = self.feed_forward(normed_x)

        # Residual Connection
        return x + feed_forward_output


class LLaMAModel(nn.Module):
    def __init__(self, vocab_size, embedding_dim, seq_length, multiple_of):
        super(LLaMAModel, self).__init__()
        self.embedding = nn.Embedding(vocab_size, embedding_dim)
        self.layer = LLaMADecoderLayer(embedding_dim, multiple_of, seq_length)
        self.fc_out = nn.Linear(embedding_dim, vocab_size, bias=False) # lm_head

        self.rmsnorm_f = RMSNorm(embedding_dim) # final_norm

    def forward(self, idx, targets=None):
        x = self.embedding(idx)

        # Look-Ahead Masking
        seq_length = x.size(1)
        mask = torch.tril(torch.ones(seq_length, seq_length)).to(x.device)

        x = self.layer(x, mask)

        # final norm
        x = self.rmsnorm_f(x)

        logits = self.fc_out(x)

        if targets is not None:
            loss = F.cross_entropy(logits.view(-1, logits.size(-1)), targets.view(-1))
            return logits, loss
        return logits, None

# %%
multiple_of = 8   # roughly dim * 1/16
train_and_test("SHA + POS(RoPE) + Masking + Residual + RMSNorm + FF(SwiGLU)", start_text, multiple_of)
# Out:
# Epoch 1/1
# Epoch 1, Step 10, Batch 10/1961, Loss: 2.9582
# Epoch 1, Step 20, Batch 20/1961, Loss: 2.7565
# Epoch 1, Step 30, Batch 30/1961, Loss: 2.6125
# Epoch 1, Step 40, Batch 40/1961, Loss: 2.5291
# Epoch 1, Step 50, Batch 50/1961, Loss: 2.4758
# Epoch 1, Step 60, Batch 60/1961, Loss: 2.4172
# Epoch 1, Step 70, Batch 70/1961, Loss: 2.3632
# Epoch 1, Step 80, Batch 80/1961, Loss: 2.3560
# Epoch 1, Step 90, Batch 90/1961, Loss: 2.3096
# Epoch 1, Step 100, Batch 100/1961, Loss: 2.2930
# Epoch 1, Step 110, Batch 110/1961, Loss: 2.2833
# Epoch 1, Step 120, Batch 120/1961, Loss: 2.2635
# Epoch 1, Step 130, Batch 130/1961, Loss: 2.2552
# Epoch 1, Step 140, Batch 140/1961, Loss: 2.2379
# Epoch 1, Step 150, Batch 150/1961, Loss: 2.2402
# Epoch 1, Step 160, Batch 160/1961, Loss: 2.2051
# Epoch 1, Step 170, Batch 170/1961, Loss: 2.1966
# Epoch 1, Step 180, Batch 180/1961, Loss: 2.1981
# Epoch 1, Step 190, Batch 190/1961, Loss: 2.1775
# Epoch 1, Step 200, Batch 200/1961, Loss: 2.1716
# Epoch 1, Step 210, Batch 210/1961, Loss: 2.1657
# Epoch 1, Step 220, Batch 220/1961, Loss: 2.1576
# Epoch 1, Step 230, Batch 230/1961, Loss: 2.1585
# Epoch 1, Step 240, Batch 240/1961, Loss: 2.1294
# Epoch 1, Step 250, Batch 250/1961, Loss: 2.1182
# Epoch 1, Step 260, Batch 260/1961, Loss: 2.1009
# Epoch 1, Step 270, Batch 270/1961, Loss: 2.1000
# Epoch 1, Step 280, Batch 280/1961, Loss: 2.0937
# Epoch 1, Step 290, Batch 290/1961, Loss: 2.0770
# Epoch 1, Step 300, Batch 300/1961, Loss: 2.0739
# Epoch 1, Step 310, Batch 310/1961, Loss: 2.0467
# Epoch 1, Step 320, Batch 320/1961, Loss: 2.0575
# Epoch 1, Step 330, Batch 330/1961, Loss: 2.0248
# Epoch 1, Step 340, Batch 340/1961, Loss: 2.0393
# Epoch 1, Step 350, Batch 350/1961, Loss: 2.0270
# Epoch 1, Step 360, Batch 360/1961, Loss: 2.0145
# Epoch 1, Step 370, Batch 370/1961, Loss: 2.0096
# Epoch 1, Step 380, Batch 380/1961, Loss: 2.0120
# Epoch 1, Step 390, Batch 390/1961, Loss: 1.9926
# Epoch 1, Step 400, Batch 400/1961, Loss: 1.9804
# Epoch 1, Step 410, Batch 410/1961, Loss: 1.9904
# Epoch 1, Step 420, Batch 420/1961, Loss: 1.9723
# Epoch 1, Step 430, Batch 430/1961, Loss: 1.9745
# Epoch 1, Step 440, Batch 440/1961, Loss: 1.9571
# Epoch 1, Step 450, Batch 450/1961, Loss: 1.9486
# Epoch 1, Step 460, Batch 460/1961, Loss: 1.9354
# Epoch 1, Step 470, Batch 470/1961, Loss: 1.9074
# Epoch 1, Step 480, Batch 480/1961, Loss: 1.8979
# Epoch 1, Step 490, Batch 490/1961, Loss: 1.8874
# Epoch 1, Step 500, Batch 500/1961, Loss: 1.9022
# Epoch 1, Step 510, Batch 510/1961, Loss: 1.8792
# Epoch 1, Step 520, Batch 520/1961, Loss: 1.8736
# Epoch 1, Step 530, Batch 530/1961, Loss: 1.8801
# Epoch 1, Step 540, Batch 540/1961, Loss: 1.8820
# Epoch 1, Step 550, Batch 550/1961, Loss: 1.8479
# Epoch 1, Step 560, Batch 560/1961, Loss: 1.8317
# Epoch 1, Step 570, Batch 570/1961, Loss: 1.8298
# Epoch 1, Step 580, Batch 580/1961, Loss: 1.8266
# Epoch 1, Step 590, Batch 590/1961, Loss: 1.8268
# Epoch 1, Step 600, Batch 600/1961, Loss: 1.8154
# Epoch 1, Step 610, Batch 610/1961, Loss: 1.8057
# Epoch 1, Step 620, Batch 620/1961, Loss: 1.8217
# Epoch 1, Step 630, Batch 630/1961, Loss: 1.8028
# Epoch 1, Step 640, Batch 640/1961, Loss: 1.7830
# Epoch 1, Step 650, Batch 650/1961, Loss: 1.8029
# Epoch 1, Step 660, Batch 660/1961, Loss: 1.7639
# Epoch 1, Step 670, Batch 670/1961, Loss: 1.7914
# Epoch 1, Step 680, Batch 680/1961, Loss: 1.7573
# Epoch 1, Step 690, Batch 690/1961, Loss: 1.7564
# Epoch 1, Step 700, Batch 700/1961, Loss: 1.7474
# Epoch 1, Step 710, Batch 710/1961, Loss: 1.7504
# Epoch 1, Step 720, Batch 720/1961, Loss: 1.7457
# Epoch 1, Step 730, Batch 730/1961, Loss: 1.7428
# Epoch 1, Step 740, Batch 740/1961, Loss: 1.7230
# Epoch 1, Step 750, Batch 750/1961, Loss: 1.7123
# Epoch 1, Step 760, Batch 760/1961, Loss: 1.7216
# Epoch 1, Step 770, Batch 770/1961, Loss: 1.7150
# Epoch 1, Step 780, Batch 780/1961, Loss: 1.7018
# Epoch 1, Step 790, Batch 790/1961, Loss: 1.7341
# Epoch 1, Step 800, Batch 800/1961, Loss: 1.7334
# Epoch 1, Step 810, Batch 810/1961, Loss: 1.7125
# Epoch 1, Step 820, Batch 820/1961, Loss: 1.7019
# Epoch 1, Step 830, Batch 830/1961, Loss: 1.6978
# Epoch 1, Step 840, Batch 840/1961, Loss: 1.6847
# Epoch 1, Step 850, Batch 850/1961, Loss: 1.6695
# Epoch 1, Step 860, Batch 860/1961, Loss: 1.6866
# Epoch 1, Step 870, Batch 870/1961, Loss: 1.6706
# Epoch 1, Step 880, Batch 880/1961, Loss: 1.6530
# Epoch 1, Step 890, Batch 890/1961, Loss: 1.6501
# Epoch 1, Step 900, Batch 900/1961, Loss: 1.6268
# Epoch 1, Step 910, Batch 910/1961, Loss: 1.6093
# Epoch 1, Step 920, Batch 920/1961, Loss: 1.6131
# Epoch 1, Step 930, Batch 930/1961, Loss: 1.6042
# Epoch 1, Step 940, Batch 940/1961, Loss: 1.6017
# Epoch 1, Step 950, Batch 950/1961, Loss: 1.6043
# Epoch 1, Step 960, Batch 960/1961, Loss: 1.6129
# Epoch 1, Step 970, Batch 970/1961, Loss: 1.6028
# Epoch 1, Step 980, Batch 980/1961, Loss: 1.5945
# Epoch 1, Step 990, Batch 990/1961, Loss: 1.5873
# Epoch 1, Step 1000, Batch 1000/1961, Loss: 1.5841
# Epoch 1, Step 1010, Batch 1010/1961, Loss: 1.5735
# Epoch 1, Step 1020, Batch 1020/1961, Loss: 1.5661
# Epoch 1, Step 1030, Batch 1030/1961, Loss: 1.5650
# Epoch 1, Step 1040, Batch 1040/1961, Loss: 1.5685
# Epoch 1, Step 1050, Batch 1050/1961, Loss: 1.5786
# Epoch 1, Step 1060, Batch 1060/1961, Loss: 1.5612
# Epoch 1, Step 1070, Batch 1070/1961, Loss: 1.5486
# Epoch 1, Step 1080, Batch 1080/1961, Loss: 1.5585
# Epoch 1, Step 1090, Batch 1090/1961, Loss: 1.5741
# Epoch 1, Step 1100, Batch 1100/1961, Loss: 1.5653
# Epoch 1, Step 1110, Batch 1110/1961, Loss: 1.5575
# Epoch 1, Step 1120, Batch 1120/1961, Loss: 1.5444
# Epoch 1, Step 1130, Batch 1130/1961, Loss: 1.5583
# Epoch 1, Step 1140, Batch 1140/1961, Loss: 1.5606
# Epoch 1, Step 1150, Batch 1150/1961, Loss: 1.5613
# Epoch 1, Step 1160, Batch 1160/1961, Loss: 1.5288
# Epoch 1, Step 1170, Batch 1170/1961, Loss: 1.5511
# Epoch 1, Step 1180, Batch 1180/1961, Loss: 1.5547
# Epoch 1, Step 1190, Batch 1190/1961, Loss: 1.5416
# Epoch 1, Step 1200, Batch 1200/1961, Loss: 1.5420
# Epoch 1, Step 1210, Batch 1210/1961, Loss: 1.5484
# Epoch 1, Step 1220, Batch 1220/1961, Loss: 1.5398
# Epoch 1, Step 1230, Batch 1230/1961, Loss: 1.5356
# Epoch 1, Step 1240, Batch 1240/1961, Loss: 1.5425
# Epoch 1, Step 1250, Batch 1250/1961, Loss: 1.5413
# Epoch 1, Step 1260, Batch 1260/1961, Loss: 1.5279
# Epoch 1, Step 1270, Batch 1270/1961, Loss: 1.5279
# Epoch 1, Step 1280, Batch 1280/1961, Loss: 1.5221
# Epoch 1, Step 1290, Batch 1290/1961, Loss: 1.5140
# Epoch 1, Step 1300, Batch 1300/1961, Loss: 1.5341
# Epoch 1, Step 1310, Batch 1310/1961, Loss: 1.5259
# Epoch 1, Step 1320, Batch 1320/1961, Loss: 1.5263
# Epoch 1, Step 1330, Batch 1330/1961, Loss: 1.5007
# Epoch 1, Step 1340, Batch 1340/1961, Loss: 1.5142
# Epoch 1, Step 1350, Batch 1350/1961, Loss: 1.5003
# Epoch 1, Step 1360, Batch 1360/1961, Loss: 1.5217
# Epoch 1, Step 1370, Batch 1370/1961, Loss: 1.5165
# Epoch 1, Step 1380, Batch 1380/1961, Loss: 1.5091
# Epoch 1, Step 1390, Batch 1390/1961, Loss: 1.5248
# Epoch 1, Step 1400, Batch 1400/1961, Loss: 1.5053
# Epoch 1, Step 1410, Batch 1410/1961, Loss: 1.4972
# Epoch 1, Step 1420, Batch 1420/1961, Loss: 1.5156
# Epoch 1, Step 1430, Batch 1430/1961, Loss: 1.5042
# Epoch 1, Step 1440, Batch 1440/1961, Loss: 1.4843
# Epoch 1, Step 1450, Batch 1450/1961, Loss: 1.5074
# Epoch 1, Step 1460, Batch 1460/1961, Loss: 1.5118
# Epoch 1, Step 1470, Batch 1470/1961, Loss: 1.5007
# Epoch 1, Step 1480, Batch 1480/1961, Loss: 1.5022
# Epoch 1, Step 1490, Batch 1490/1961, Loss: 1.4984
# Epoch 1, Step 1500, Batch 1500/1961, Loss: 1.4927
# Epoch 1, Step 1510, Batch 1510/1961, Loss: 1.4956
# Epoch 1, Step 1520, Batch 1520/1961, Loss: 1.5075
# Epoch 1, Step 1530, Batch 1530/1961, Loss: 1.4897
# Epoch 1, Step 1540, Batch 1540/1961, Loss: 1.4910
# Epoch 1, Step 1550, Batch 1550/1961, Loss: 1.4777
# Epoch 1, Step 1560, Batch 1560/1961, Loss: 1.4944
# Epoch 1, Step 1570, Batch 1570/1961, Loss: 1.4974
# Epoch 1, Step 1580, Batch 1580/1961, Loss: 1.4651
# Epoch 1, Step 1590, Batch 1590/1961, Loss: 1.4658
# Epoch 1, Step 1600, Batch 1600/1961, Loss: 1.4778
# Epoch 1, Step 1610, Batch 1610/1961, Loss: 1.4807
# Epoch 1, Step 1620, Batch 1620/1961, Loss: 1.4793
# Epoch 1, Step 1630, Batch 1630/1961, Loss: 1.4814
# Epoch 1, Step 1640, Batch 1640/1961, Loss: 1.4856
# Epoch 1, Step 1650, Batch 1650/1961, Loss: 1.4739
# Epoch 1, Step 1660, Batch 1660/1961, Loss: 1.4599
# Epoch 1, Step 1670, Batch 1670/1961, Loss: 1.4726
# Epoch 1, Step 1680, Batch 1680/1961, Loss: 1.4636
# Epoch 1, Step 1690, Batch 1690/1961, Loss: 1.4709
# Epoch 1, Step 1700, Batch 1700/1961, Loss: 1.4965
# Epoch 1, Step 1710, Batch 1710/1961, Loss: 1.4810
# Epoch 1, Step 1720, Batch 1720/1961, Loss: 1.4814
# Epoch 1, Step 1730, Batch 1730/1961, Loss: 1.4876
# Epoch 1, Step 1740, Batch 1740/1961, Loss: 1.4818
# Epoch 1, Step 1750, Batch 1750/1961, Loss: 1.4712
# Epoch 1, Step 1760, Batch 1760/1961, Loss: 1.4598
# Epoch 1, Step 1770, Batch 1770/1961, Loss: 1.4682
# Epoch 1, Step 1780, Batch 1780/1961, Loss: 1.4855
# Epoch 1, Step 1790, Batch 1790/1961, Loss: 1.4709
# Epoch 1, Step 1800, Batch 1800/1961, Loss: 1.4821
# Epoch 1, Step 1810, Batch 1810/1961, Loss: 1.4667
# Epoch 1, Step 1820, Batch 1820/1961, Loss: 1.4739
# Epoch 1, Step 1830, Batch 1830/1961, Loss: 1.4844
# Epoch 1, Step 1840, Batch 1840/1961, Loss: 1.4755
# Epoch 1, Step 1850, Batch 1850/1961, Loss: 1.4735
# Epoch 1, Step 1860, Batch 1860/1961, Loss: 1.4578
# Epoch 1, Step 1870, Batch 1870/1961, Loss: 1.4478
# Epoch 1, Step 1880, Batch 1880/1961, Loss: 1.4618
# Epoch 1, Step 1890, Batch 1890/1961, Loss: 1.4703
# Epoch 1, Step 1900, Batch 1900/1961, Loss: 1.4652
# Epoch 1, Step 1910, Batch 1910/1961, Loss: 1.4645
# Epoch 1, Step 1920, Batch 1920/1961, Loss: 1.4733
# Epoch 1, Step 1930, Batch 1930/1961, Loss: 1.4592
# Epoch 1, Step 1940, Batch 1940/1961, Loss: 1.4663
# Epoch 1, Step 1950, Batch 1950/1961, Loss: 1.4717
# Epoch 1, Step 1960, Batch 1960/1961, Loss: 1.4612
# Epoch 1/1, Train Loss: 1.4423, Val Loss: 1.7904, Epoch Time: 190.83s
# Generated text [
#
# GREMIO:
# Good morrow, neighbour Baptista.
#
# BAPTISTA:
# Good morro]:
# --------------------------------------------------
#
#
# GREMIO:
# Good morrow, neighbour Baptista.
#
# BAPTISTA:
# Good morrow he he perheop, by it? despas in the
# And now-forth agolditious but of Warwick,
# Edrt: thou shalt at you are the dere pays forback poor the not, what enought cus are counsent to Margaret abatle.
#
# GLOUCESTER:
# He hath daughter summer whites are-regat most
# commend the pany her. Ladowing,
# Leaves had fall'd you heaven, but me not with for fast a kton presagre stonest and his driator,
# She shall be a go soldia, madam. Anough
# By that, mawake ain myself ill evil; and know parable hast shall the mabherefin

# %% [markdown]
# Introducing RoPE shows a noticeable improvement in performance, with the model now generating more coherent text. The loss curve aligns more closely with our expectations, reaching a point where it starts to rival LSTM performance. This confirms that RoPE is well-suited for transformer-based models.

# %% [markdown]
# We now conclude our single-head attention series and move on to multi-head attention, which significantly boosts performance.
#
# Multi-head attention allows the model to focus on different parts of the input sequence simultaneously, providing a richer representation of the data and improving learning efficiency.

# %% [markdown]
# ## Multihead Attention

# %%
import torch
import torch.nn.functional as F
import torch.nn as nn
import math

# RoPE: Rotary Position Embedding function
def apply_rotary_pos_emb(q, k, sin, cos):
    ###### 여기 채우기 #####
    q_rot =
    k_rot =
    return q_rot, k_rot

def rotate_half(x):
    x1, x2 = x.chunk(2, dim=-1)
    return torch.cat((-x2, x1), dim=-1)

def build_rope_cache(seq_len, head_dim, device):
    inv_freq = 1.0 / (10000 ** (torch.arange(0, head_dim, 2).float().to(device) / head_dim))
    t = torch.arange(seq_len, device=device).float()
    freqs = torch.einsum('i,j->ij', t, inv_freq)
    emb = torch.cat((freqs, freqs), dim=-1)
    sin, cos = emb.sin(), emb.cos()
    return sin, cos

# Custom RMSNorm to match LLaMA 1 official implementation
class RMSNorm(nn.Module):
    def __init__(self, d_model, eps=1e-6):
        super(RMSNorm, self).__init__()
        self.weight = nn.Parameter(torch.ones(d_model))
        self.eps = eps

    def _norm(self, x):
        # Compute variance and apply reciprocal square root for RMS normalization
        return x * torch.rsqrt(x.pow(2).mean(-1, keepdim=True) + self.eps)

    def forward(self, x):
        # Convert to float32 for precision, then back to original dtype
        output = self._norm(x.float()).type_as(x)
        return output * self.weight

# Feed-Forward Network with implicit gating
class FeedForward(nn.Module):
    def __init__(self, d_model, multiple_of):
        super(FeedForward, self).__init__()
        up_hidden_dim = multiple_of * math.ceil((d_model * 4 * 2 / 3) / multiple_of)
        ###### self.gate_proj, self.up_proj, self.down_proj 정의 ######
        self.gate_proj =
        self.up_proj =
        self.down_proj =
        self.act_fn = F.silu  # SiLU activation

    def forward(self, x):
        ### feedforward 작성 ###
        return

# Multi-Head Attention with Causal Masking and RoPE
class MultiHeadAttention(nn.Module):
    def __init__(self, d_model, num_heads, seq_length):
        super(MultiHeadAttention, self).__init__()
        self.num_heads = num_heads
        self.d_model = d_model
        self.head_dim = d_model // num_heads
        self.seq_length = seq_length

        self.query = nn.Linear(d_model, d_model, bias=False)
        self.key = nn.Linear(d_model, d_model, bias=False)
        self.value = nn.Linear(d_model, d_model, bias=False)
        self.fc_out = nn.Linear(d_model, d_model, bias=False)

        # Build RoPE cache
        self.sin, self.cos = build_rope_cache(seq_length, self.head_dim, torch.device('cpu'))

    def forward(self, x, mask=None):

        ########## 여기 작성 ###########


        return x

# LLaMA Decoder Layer with Multi-Head Attention and RoPE
class LLaMADecoderLayer(nn.Module):
    def __init__(self, embedding_dim, multiple_of, num_heads, seq_length):
        super(LLaMADecoderLayer, self).__init__()
        self.rmsnorm1 = RMSNorm(embedding_dim)
        self.attention = MultiHeadAttention(embedding_dim, num_heads, seq_length)
        self.rmsnorm2 = RMSNorm(embedding_dim)
        self.feed_forward = FeedForward(embedding_dim, multiple_of)

    def forward(self, x, mask):
        normed_x = self.rmsnorm1(x)
        attention_output = self.attention(normed_x, mask)
        x = x + attention_output  # Residual connection
        normed_x = self.rmsnorm2(x)
        feed_forward_output = self.feed_forward(normed_x)
        return x + feed_forward_output  # Residual connection

class LLaMAModel(nn.Module):
    def __init__(self, vocab_size, embedding_dim, seq_length, num_heads, multiple_of):
        super(LLaMAModel, self).__init__()
        self.embedding = nn.Embedding(vocab_size, embedding_dim)
        self.layer = LLaMADecoderLayer(embedding_dim, multiple_of, num_heads, seq_length)
        self.rmsnorm_f = RMSNorm(embedding_dim)
        self.fc_out = nn.Linear(embedding_dim, vocab_size, bias=False)

    def forward(self, idx, targets=None):
        x = self.embedding(idx)
        seq_length = x.size(1)
        mask = torch.tril(torch.ones(seq_length, seq_length)).to(x.device)

        x = self.layer(x, mask)

        x = self.rmsnorm_f(x)
        logits = self.fc_out(x)

        if targets is not None:
            loss = F.cross_entropy(logits.view(-1, logits.size(-1)), targets.view(-1))
            return logits, loss
        return logits, None

# %%
def train_and_test(model_desc, start_text, multiple_of, num_heads):
    # Initialize the model
    model_llama = LLaMAModel(vocab_size, EMBEDDING_DIM, SEQUENCE_LENGTH, num_heads, multiple_of).to(device)

    # Use the same optimizer and criterion
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model_llama.parameters(), lr=LEARNING_RATE)

    # Train the model
    trained_model, train_losses_df, val_losses_df = train_model(
        model_llama, train_loader, val_loader, criterion, optimizer, device, EPOCHS
    )

    # Generate text
    generated_text = generate_text_attention(trained_model, char_to_idx, idx_to_char, start_text, device)
    print(f"Generated text [{start_text}]:")
    print("-"*50)
    print(generated_text)

    add_loss_to_comparison(model_desc, train_losses_df, val_losses_df)

    # Plot loss comparisons including this model
    plot_loss_comparisons()

# %%
multiple_of = 8   # roughly dim * 1/16
num_heads = 8
train_and_test("MHA + POS(RoPE) + Masking + Residual + RMSNorm + FF(SwiGLU)", start_text, multiple_of, num_heads)
# Out:
# Epoch 1/1
# Epoch 1, Step 10, Batch 10/1961, Loss: 2.7847
# Epoch 1, Step 20, Batch 20/1961, Loss: 2.5780
# Epoch 1, Step 30, Batch 30/1961, Loss: 2.4492
# Epoch 1, Step 40, Batch 40/1961, Loss: 2.3728
# Epoch 1, Step 50, Batch 50/1961, Loss: 2.2984
# Epoch 1, Step 60, Batch 60/1961, Loss: 2.2529
# Epoch 1, Step 70, Batch 70/1961, Loss: 2.1880
# Epoch 1, Step 80, Batch 80/1961, Loss: 2.1410
# Epoch 1, Step 90, Batch 90/1961, Loss: 2.1090
# Epoch 1, Step 100, Batch 100/1961, Loss: 2.0521
# Epoch 1, Step 110, Batch 110/1961, Loss: 2.0155
# Epoch 1, Step 120, Batch 120/1961, Loss: 1.9765
# Epoch 1, Step 130, Batch 130/1961, Loss: 1.9349
# Epoch 1, Step 140, Batch 140/1961, Loss: 1.9277
# Epoch 1, Step 150, Batch 150/1961, Loss: 1.8798
# Epoch 1, Step 160, Batch 160/1961, Loss: 1.8586
# Epoch 1, Step 170, Batch 170/1961, Loss: 1.8343
# Epoch 1, Step 180, Batch 180/1961, Loss: 1.7946
# Epoch 1, Step 190, Batch 190/1961, Loss: 1.7728
# Epoch 1, Step 200, Batch 200/1961, Loss: 1.7804
# Epoch 1, Step 210, Batch 210/1961, Loss: 1.7485
# Epoch 1, Step 220, Batch 220/1961, Loss: 1.7276
# Epoch 1, Step 230, Batch 230/1961, Loss: 1.7104
# Epoch 1, Step 240, Batch 240/1961, Loss: 1.7105
# Epoch 1, Step 250, Batch 250/1961, Loss: 1.6645
# Epoch 1, Step 260, Batch 260/1961, Loss: 1.6639
# Epoch 1, Step 270, Batch 270/1961, Loss: 1.6492
# Epoch 1, Step 280, Batch 280/1961, Loss: 1.6410
# Epoch 1, Step 290, Batch 290/1961, Loss: 1.6499
# Epoch 1, Step 300, Batch 300/1961, Loss: 1.6313
# Epoch 1, Step 310, Batch 310/1961, Loss: 1.6167
# Epoch 1, Step 320, Batch 320/1961, Loss: 1.5974
# Epoch 1, Step 330, Batch 330/1961, Loss: 1.5825
# Epoch 1, Step 340, Batch 340/1961, Loss: 1.5710
# Epoch 1, Step 350, Batch 350/1961, Loss: 1.5694
# Epoch 1, Step 360, Batch 360/1961, Loss: 1.5563
# Epoch 1, Step 370, Batch 370/1961, Loss: 1.5655
# Epoch 1, Step 380, Batch 380/1961, Loss: 1.5610
# Epoch 1, Step 390, Batch 390/1961, Loss: 1.5523
# Epoch 1, Step 400, Batch 400/1961, Loss: 1.5368
# Epoch 1, Step 410, Batch 410/1961, Loss: 1.5349
# Epoch 1, Step 420, Batch 420/1961, Loss: 1.5233
# Epoch 1, Step 430, Batch 430/1961, Loss: 1.5186
# Epoch 1, Step 440, Batch 440/1961, Loss: 1.5220
# Epoch 1, Step 450, Batch 450/1961, Loss: 1.5280
# Epoch 1, Step 460, Batch 460/1961, Loss: 1.5047
# Epoch 1, Step 470, Batch 470/1961, Loss: 1.5115
# Epoch 1, Step 480, Batch 480/1961, Loss: 1.4882
# Epoch 1, Step 490, Batch 490/1961, Loss: 1.4841
# Epoch 1, Step 500, Batch 500/1961, Loss: 1.4759
# Epoch 1, Step 510, Batch 510/1961, Loss: 1.4791
# Epoch 1, Step 520, Batch 520/1961, Loss: 1.4995
# Epoch 1, Step 530, Batch 530/1961, Loss: 1.4554
# Epoch 1, Step 540, Batch 540/1961, Loss: 1.4782
# Epoch 1, Step 550, Batch 550/1961, Loss: 1.4909
# Epoch 1, Step 560, Batch 560/1961, Loss: 1.4639
# Epoch 1, Step 570, Batch 570/1961, Loss: 1.4689
# Epoch 1, Step 580, Batch 580/1961, Loss: 1.4624
# Epoch 1, Step 590, Batch 590/1961, Loss: 1.4566
# Epoch 1, Step 600, Batch 600/1961, Loss: 1.4680
# Epoch 1, Step 610, Batch 610/1961, Loss: 1.4686
# Epoch 1, Step 620, Batch 620/1961, Loss: 1.4551
# Epoch 1, Step 630, Batch 630/1961, Loss: 1.4532
# Epoch 1, Step 640, Batch 640/1961, Loss: 1.4658
# Epoch 1, Step 650, Batch 650/1961, Loss: 1.4550
# Epoch 1, Step 660, Batch 660/1961, Loss: 1.4502
# Epoch 1, Step 670, Batch 670/1961, Loss: 1.4472
# Epoch 1, Step 680, Batch 680/1961, Loss: 1.4456
# Epoch 1, Step 690, Batch 690/1961, Loss: 1.4335
# Epoch 1, Step 700, Batch 700/1961, Loss: 1.4171
# Epoch 1, Step 710, Batch 710/1961, Loss: 1.4281
# Epoch 1, Step 720, Batch 720/1961, Loss: 1.4331
# Epoch 1, Step 730, Batch 730/1961, Loss: 1.4195
# Epoch 1, Step 740, Batch 740/1961, Loss: 1.4218
# Epoch 1, Step 750, Batch 750/1961, Loss: 1.4299
# Epoch 1, Step 760, Batch 760/1961, Loss: 1.4263
# Epoch 1, Step 770, Batch 770/1961, Loss: 1.4271
# Epoch 1, Step 780, Batch 780/1961, Loss: 1.4028
# Epoch 1, Step 790, Batch 790/1961, Loss: 1.4113
# Epoch 1, Step 800, Batch 800/1961, Loss: 1.4043
# Epoch 1, Step 810, Batch 810/1961, Loss: 1.4044
# Epoch 1, Step 820, Batch 820/1961, Loss: 1.4134
# Epoch 1, Step 830, Batch 830/1961, Loss: 1.4065
# Epoch 1, Step 840, Batch 840/1961, Loss: 1.3842
# Epoch 1, Step 850, Batch 850/1961, Loss: 1.3931
# Epoch 1, Step 860, Batch 860/1961, Loss: 1.4045
# Epoch 1, Step 870, Batch 870/1961, Loss: 1.3863
# Epoch 1, Step 880, Batch 880/1961, Loss: 1.3892
# Epoch 1, Step 890, Batch 890/1961, Loss: 1.3839
# Epoch 1, Step 900, Batch 900/1961, Loss: 1.4046
# Epoch 1, Step 910, Batch 910/1961, Loss: 1.3931
# Epoch 1, Step 920, Batch 920/1961, Loss: 1.3884
# Epoch 1, Step 930, Batch 930/1961, Loss: 1.3848
# Epoch 1, Step 940, Batch 940/1961, Loss: 1.3861
# Epoch 1, Step 950, Batch 950/1961, Loss: 1.3923
# Epoch 1, Step 960, Batch 960/1961, Loss: 1.3920
# Epoch 1, Step 970, Batch 970/1961, Loss: 1.3806
# Epoch 1, Step 980, Batch 980/1961, Loss: 1.3737
# Epoch 1, Step 990, Batch 990/1961, Loss: 1.3965
# Epoch 1, Step 1000, Batch 1000/1961, Loss: 1.3782
# Epoch 1, Step 1010, Batch 1010/1961, Loss: 1.3941
# Epoch 1, Step 1020, Batch 1020/1961, Loss: 1.3741
# Epoch 1, Step 1030, Batch 1030/1961, Loss: 1.3701
# Epoch 1, Step 1040, Batch 1040/1961, Loss: 1.3830
# Epoch 1, Step 1050, Batch 1050/1961, Loss: 1.3640
# Epoch 1, Step 1060, Batch 1060/1961, Loss: 1.3763
# Epoch 1, Step 1070, Batch 1070/1961, Loss: 1.3656
# Epoch 1, Step 1080, Batch 1080/1961, Loss: 1.3619
# Epoch 1, Step 1090, Batch 1090/1961, Loss: 1.3665
# Epoch 1, Step 1100, Batch 1100/1961, Loss: 1.3647
# Epoch 1, Step 1110, Batch 1110/1961, Loss: 1.3561
# Epoch 1, Step 1120, Batch 1120/1961, Loss: 1.3610
# Epoch 1, Step 1130, Batch 1130/1961, Loss: 1.3701
# Epoch 1, Step 1140, Batch 1140/1961, Loss: 1.3518
# Epoch 1, Step 1150, Batch 1150/1961, Loss: 1.3641
# Epoch 1, Step 1160, Batch 1160/1961, Loss: 1.3552
# Epoch 1, Step 1170, Batch 1170/1961, Loss: 1.3437
# Epoch 1, Step 1180, Batch 1180/1961, Loss: 1.3504
# Epoch 1, Step 1190, Batch 1190/1961, Loss: 1.3496
# Epoch 1, Step 1200, Batch 1200/1961, Loss: 1.3534
# Epoch 1, Step 1210, Batch 1210/1961, Loss: 1.3492
# Epoch 1, Step 1220, Batch 1220/1961, Loss: 1.3571
# Epoch 1, Step 1230, Batch 1230/1961, Loss: 1.3504
# Epoch 1, Step 1240, Batch 1240/1961, Loss: 1.3604
# Epoch 1, Step 1250, Batch 1250/1961, Loss: 1.3365
# Epoch 1, Step 1260, Batch 1260/1961, Loss: 1.3371
# Epoch 1, Step 1270, Batch 1270/1961, Loss: 1.3499
# Epoch 1, Step 1280, Batch 1280/1961, Loss: 1.3526
# Epoch 1, Step 1290, Batch 1290/1961, Loss: 1.3502
# Epoch 1, Step 1300, Batch 1300/1961, Loss: 1.3423
# Epoch 1, Step 1310, Batch 1310/1961, Loss: 1.3341
# Epoch 1, Step 1320, Batch 1320/1961, Loss: 1.3308
# Epoch 1, Step 1330, Batch 1330/1961, Loss: 1.3331
# Epoch 1, Step 1340, Batch 1340/1961, Loss: 1.3266
# Epoch 1, Step 1350, Batch 1350/1961, Loss: 1.3436
# Epoch 1, Step 1360, Batch 1360/1961, Loss: 1.3388
# Epoch 1, Step 1370, Batch 1370/1961, Loss: 1.3347
# Epoch 1, Step 1380, Batch 1380/1961, Loss: 1.3296
# Epoch 1, Step 1390, Batch 1390/1961, Loss: 1.3512
# Epoch 1, Step 1400, Batch 1400/1961, Loss: 1.3310
# Epoch 1, Step 1410, Batch 1410/1961, Loss: 1.3150
# Epoch 1, Step 1420, Batch 1420/1961, Loss: 1.3299
# Epoch 1, Step 1430, Batch 1430/1961, Loss: 1.3347
# Epoch 1, Step 1440, Batch 1440/1961, Loss: 1.3142
# Epoch 1, Step 1450, Batch 1450/1961, Loss: 1.3316
# Epoch 1, Step 1460, Batch 1460/1961, Loss: 1.3409
# Epoch 1, Step 1470, Batch 1470/1961, Loss: 1.3387
# Epoch 1, Step 1480, Batch 1480/1961, Loss: 1.3169
# Epoch 1, Step 1490, Batch 1490/1961, Loss: 1.3283
# Epoch 1, Step 1500, Batch 1500/1961, Loss: 1.3289
# Epoch 1, Step 1510, Batch 1510/1961, Loss: 1.3317
# Epoch 1, Step 1520, Batch 1520/1961, Loss: 1.3184
# Epoch 1, Step 1530, Batch 1530/1961, Loss: 1.3256
# Epoch 1, Step 1540, Batch 1540/1961, Loss: 1.3202
# Epoch 1, Step 1550, Batch 1550/1961, Loss: 1.3145
# Epoch 1, Step 1560, Batch 1560/1961, Loss: 1.3158
# Epoch 1, Step 1570, Batch 1570/1961, Loss: 1.3105
# Epoch 1, Step 1580, Batch 1580/1961, Loss: 1.3066
# Epoch 1, Step 1590, Batch 1590/1961, Loss: 1.3286
# Epoch 1, Step 1600, Batch 1600/1961, Loss: 1.3242
# Epoch 1, Step 1610, Batch 1610/1961, Loss: 1.3084
# Epoch 1, Step 1620, Batch 1620/1961, Loss: 1.3250
# Epoch 1, Step 1630, Batch 1630/1961, Loss: 1.3038
# Epoch 1, Step 1640, Batch 1640/1961, Loss: 1.3265
# Epoch 1, Step 1650, Batch 1650/1961, Loss: 1.3118
# Epoch 1, Step 1660, Batch 1660/1961, Loss: 1.3228
# Epoch 1, Step 1670, Batch 1670/1961, Loss: 1.3040
# Epoch 1, Step 1680, Batch 1680/1961, Loss: 1.3170
# Epoch 1, Step 1690, Batch 1690/1961, Loss: 1.3122
# Epoch 1, Step 1700, Batch 1700/1961, Loss: 1.3209
# Epoch 1, Step 1710, Batch 1710/1961, Loss: 1.3191
# Epoch 1, Step 1720, Batch 1720/1961, Loss: 1.3159
# Epoch 1, Step 1730, Batch 1730/1961, Loss: 1.3145
# Epoch 1, Step 1740, Batch 1740/1961, Loss: 1.2977
# Epoch 1, Step 1750, Batch 1750/1961, Loss: 1.3076
# Epoch 1, Step 1760, Batch 1760/1961, Loss: 1.2947
# Epoch 1, Step 1770, Batch 1770/1961, Loss: 1.3143
# Epoch 1, Step 1780, Batch 1780/1961, Loss: 1.2998
# Epoch 1, Step 1790, Batch 1790/1961, Loss: 1.3109
# Epoch 1, Step 1800, Batch 1800/1961, Loss: 1.3160
# Epoch 1, Step 1810, Batch 1810/1961, Loss: 1.3235
# Epoch 1, Step 1820, Batch 1820/1961, Loss: 1.3112
# Epoch 1, Step 1830, Batch 1830/1961, Loss: 1.2988
# Epoch 1, Step 1840, Batch 1840/1961, Loss: 1.3032
# Epoch 1, Step 1850, Batch 1850/1961, Loss: 1.3030
# Epoch 1, Step 1860, Batch 1860/1961, Loss: 1.2983
# Epoch 1, Step 1870, Batch 1870/1961, Loss: 1.2889
# Epoch 1, Step 1880, Batch 1880/1961, Loss: 1.2936
# Epoch 1, Step 1890, Batch 1890/1961, Loss: 1.2995
# Epoch 1, Step 1900, Batch 1900/1961, Loss: 1.2859
# Epoch 1, Step 1910, Batch 1910/1961, Loss: 1.2969
# Epoch 1, Step 1920, Batch 1920/1961, Loss: 1.3016
# Epoch 1, Step 1930, Batch 1930/1961, Loss: 1.2867
# Epoch 1, Step 1940, Batch 1940/1961, Loss: 1.2920
# Epoch 1, Step 1950, Batch 1950/1961, Loss: 1.2954
# Epoch 1, Step 1960, Batch 1960/1961, Loss: 1.2899
# Epoch 1/1, Train Loss: 1.2947, Val Loss: 1.8291, Epoch Time: 207.84s
# Generated text [
#
# GREMIO:
# Good morrow, neighbour Baptista.
#
# BAPTISTA:
# Good morro]:
# --------------------------------------------------
#
#
# GREMIO:
# Good morrow, neighbour Baptista.
#
# BAPTISTA:
# Good morrow, stands eye
# The violate a gosseStly: and she eyes
# Your center, daughter, is becomes blows,
# There on is the lie. There is you? you all the elder men
# this in the should infidels the pick at once,
# Nor met, becure through of thou shepherd I
# The highe I leart's the matter?
#
# VOLUMNIA:
# Upon my this.
#
# MARCIUS:
# Evep me fellow; no monstrel-book tongue but were,
# When he worst winterpretaion tears? Let may had not have other was speak.
#
# Second Servant:
#
# Return is false things of thing, to married:
# I shoul

# %% [markdown]
# As expected, multi-head attention dramatically improves the performance. The loss curve becomes much smoother, and the generated text is much more fluent and coherent. Multi-head attention allows the model to better capture complex relationships within the sequence.

# %% [markdown]
# # Multi-Layer
#
# Real-world transformers often have dozens of layers, with models like GPT-3 and LLaMA featuring as many as 32 layers or more. The true power of transformers comes from stacking multiple layers, which helps capture deeper patterns and relationships within the data. In this step, we extend our model to a multi-layer architecture.
#
# And one more change will be added. Previously, since there was only a single layer, the RoPE cache was placed inside the MHA. However, in the case of multiple layers, the RoPE cache is now created only once at the beginning and reused across all layers.

# %%
import torch
import torch.nn.functional as F
import torch.nn as nn
import math

# RoPE: Rotary Position Embedding function
def apply_rotary_pos_emb(q, k, sin, cos):
    ###### 여기 채우기 #####
    q_rot =
    k_rot =
    return q_rot, k_rot

def rotate_half(x):
    x1, x2 = x.chunk(2, dim=-1)
    return torch.cat((-x2, x1), dim=-1)


# Building the RoPE cache once, to be shared across layers
class RoPECache:
    def __init__(self, seq_len, head_dim, device):
        self.sin, self.cos = self.build_rope_cache(seq_len, head_dim, device)

    @staticmethod
    def build_rope_cache(seq_len, head_dim, device):
        inv_freq = 1.0 / (10000 ** (torch.arange(0, head_dim, 2).float().to(device) / head_dim))
        t = torch.arange(seq_len, device=device).float()
        freqs = torch.einsum('i,j->ij', t, inv_freq)
        emb = torch.cat((freqs, freqs), dim=-1)
        sin, cos = emb.sin(), emb.cos()
        return sin, cos

# Custom RMSNorm to match LLaMA 1 official implementation
class RMSNorm(nn.Module):
    def __init__(self, d_model, eps=1e-6):
        super(RMSNorm, self).__init__()
        self.weight = nn.Parameter(torch.ones(d_model))
        self.eps = eps

    def _norm(self, x):
        # Compute variance and apply reciprocal square root for RMS normalization
        return x * torch.rsqrt(x.pow(2).mean(-1, keepdim=True) + self.eps)

    def forward(self, x):
        # Convert to float32 for precision, then back to original dtype
        output = self._norm(x.float()).type_as(x)
        return output * self.weight

# Feed-Forward Network with implicit gating
class FeedForward(nn.Module):
    def __init__(self, d_model, multiple_of):
        super(FeedForward, self).__init__()
        up_hidden_dim = multiple_of * math.ceil((d_model * 4 * 2 / 3) / multiple_of)
        ###### self.gate_proj, self.up_proj, self.down_proj 정의 ######
        self.gate_proj =
        self.up_proj =
        self.down_proj =
        self.act_fn = F.silu  # SiLU activation

    def forward(self, x):
        ### feedforward 작성 ###
        return

# Multi-Head Attention with Causal Masking and RoPE
class MultiHeadAttention(nn.Module):
    def __init__(self, d_model, num_heads, seq_length, rope_cache):
        super(MultiHeadAttention, self).__init__()
        self.num_heads = num_heads
        self.d_model = d_model
        self.head_dim = d_model // num_heads
        self.seq_length = seq_length

        self.query = nn.Linear(d_model, d_model, bias=False)
        self.key = nn.Linear(d_model, d_model, bias=False)
        self.value = nn.Linear(d_model, d_model, bias=False)
        self.fc_out = nn.Linear(d_model, d_model, bias=False)

        # Use the shared RoPE cache
        self.rope_cache = rope_cache

    def forward(self, x, mask=None):

        ########## 여기 작성 ###########

        return x

# LLaMA Decoder Layer with Multi-Head Attention and RoPE
class LLaMADecoderLayer(nn.Module):
    def __init__(self, embedding_dim, multiple_of, num_heads, seq_length, rms_norm_eps, rope_cache):
        super(LLaMADecoderLayer, self).__init__()
        self.rmsnorm1 = RMSNorm(embedding_dim, rms_norm_eps)
        self.attention = MultiHeadAttention(embedding_dim, num_heads, seq_length, rope_cache)
        self.rmsnorm2 = RMSNorm(embedding_dim, rms_norm_eps)
        self.feed_forward = FeedForward(embedding_dim, multiple_of)

    def forward(self, x, mask):
        normed_x = self.rmsnorm1(x)
        attention_output = self.attention(normed_x, mask)
        x = x + attention_output  # Residual connection
        normed_x = self.rmsnorm2(x)
        feed_forward_output = self.feed_forward(normed_x)
        return x + feed_forward_output  # Residual connection

# LLaMA Model with RoPE and Multi-Layer
class LLaMAModel(nn.Module):
    def __init__(self, vocab_size, embedding_dim, seq_length, num_heads, num_layers, multiple_of, rms_norm_eps=1e-6):
        super(LLaMAModel, self).__init__()
        self.embedding = nn.Embedding(vocab_size, embedding_dim)

        # Initialize the shared RoPE cache once
        rope_cache = RoPECache(seq_length, embedding_dim // num_heads, torch.device('cpu'))

        self.layers = nn.ModuleList([LLaMADecoderLayer(embedding_dim, multiple_of, num_heads, seq_length, rms_norm_eps, rope_cache) for _ in range(num_layers)])
        self.rmsnorm_f = RMSNorm(embedding_dim, rms_norm_eps)
        self.fc_out = nn.Linear(embedding_dim, vocab_size, bias=False)

    def forward(self, idx, targets=None):
        x = self.embedding(idx)
        seq_length = x.size(1)
        mask = torch.tril(torch.ones(seq_length, seq_length)).to(x.device)

        for layer in self.layers:
            x = layer(x, mask)

        x = self.rmsnorm_f(x)
        logits = self.fc_out(x)

        if targets is not None:
            loss = F.cross_entropy(logits.view(-1, logits.size(-1)), targets.view(-1))
            return logits, loss
        return logits, None

# %%
def train_and_test(model_desc, start_text, multiple_of, num_heads, num_layers):
    # Initialize the model
    model_llama = LLaMAModel(vocab_size, EMBEDDING_DIM, SEQUENCE_LENGTH, num_heads, num_layers, multiple_of).to(device)

    # Use the same optimizer and criterion
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model_llama.parameters(), lr=LEARNING_RATE)

    # Train the model
    trained_model, train_losses_df, val_losses_df = train_model(
        model_llama, train_loader, val_loader, criterion, optimizer, device, EPOCHS
    )

    # Generate text
    generated_text = generate_text_attention(trained_model, char_to_idx, idx_to_char, start_text, device)
    print(f"Generated text [{start_text}]:")
    print("-"*50)
    print(generated_text)

    add_loss_to_comparison(model_desc, train_losses_df, val_losses_df)

    # Plot loss comparisons including this model
    plot_loss_comparisons()

# %%
multiple_of = 8   # roughly dim * 1/16
num_heads = 8
num_layers = 6

train_and_test("MultiLayer + MHA + POS(RoPE) + Masking + Residual + RMSNorm + FF(SwiGLU)", start_text, multiple_of, num_heads, num_layers)
# Out:
# Epoch 1/1
# Epoch 1, Step 10, Batch 10/1961, Loss: 2.5861
# Epoch 1, Step 20, Batch 20/1961, Loss: 2.4412
# Epoch 1, Step 30, Batch 30/1961, Loss: 2.3138
# Epoch 1, Step 40, Batch 40/1961, Loss: 2.1750
# Epoch 1, Step 50, Batch 50/1961, Loss: 2.0690
# Epoch 1, Step 60, Batch 60/1961, Loss: 1.9772
# Epoch 1, Step 70, Batch 70/1961, Loss: 1.9026
# Epoch 1, Step 80, Batch 80/1961, Loss: 1.7968
# Epoch 1, Step 90, Batch 90/1961, Loss: 1.7365
# Epoch 1, Step 100, Batch 100/1961, Loss: 1.6652
# Epoch 1, Step 110, Batch 110/1961, Loss: 1.6440
# Epoch 1, Step 120, Batch 120/1961, Loss: 1.5704
# Epoch 1, Step 130, Batch 130/1961, Loss: 1.5495
# Epoch 1, Step 140, Batch 140/1961, Loss: 1.5051
# Epoch 1, Step 150, Batch 150/1961, Loss: 1.4925
# Epoch 1, Step 160, Batch 160/1961, Loss: 1.4629
# Epoch 1, Step 170, Batch 170/1961, Loss: 1.4509
# Epoch 1, Step 180, Batch 180/1961, Loss: 1.4361
# Epoch 1, Step 190, Batch 190/1961, Loss: 1.4027
# Epoch 1, Step 200, Batch 200/1961, Loss: 1.3842
# Epoch 1, Step 210, Batch 210/1961, Loss: 1.3753
# Epoch 1, Step 220, Batch 220/1961, Loss: 1.3766
# Epoch 1, Step 230, Batch 230/1961, Loss: 1.3656
# Epoch 1, Step 240, Batch 240/1961, Loss: 1.3442
# Epoch 1, Step 250, Batch 250/1961, Loss: 1.3409
# Epoch 1, Step 260, Batch 260/1961, Loss: 1.3371
# Epoch 1, Step 270, Batch 270/1961, Loss: 1.3261
# Epoch 1, Step 280, Batch 280/1961, Loss: 1.3153
# Epoch 1, Step 290, Batch 290/1961, Loss: 1.3203
# Epoch 1, Step 300, Batch 300/1961, Loss: 1.3034
# Epoch 1, Step 310, Batch 310/1961, Loss: 1.2905
# Epoch 1, Step 320, Batch 320/1961, Loss: 1.2743
# Epoch 1, Step 330, Batch 330/1961, Loss: 1.2796
# Epoch 1, Step 340, Batch 340/1961, Loss: 1.2643
# Epoch 1, Step 350, Batch 350/1961, Loss: 1.2685
# Epoch 1, Step 360, Batch 360/1961, Loss: 1.2665
# Epoch 1, Step 370, Batch 370/1961, Loss: 1.2584
# Epoch 1, Step 380, Batch 380/1961, Loss: 1.2471
# Epoch 1, Step 390, Batch 390/1961, Loss: 1.2363
# Epoch 1, Step 400, Batch 400/1961, Loss: 1.2266
# Epoch 1, Step 410, Batch 410/1961, Loss: 1.2046
# Epoch 1, Step 420, Batch 420/1961, Loss: 1.2121
# Epoch 1, Step 430, Batch 430/1961, Loss: 1.2115
# Epoch 1, Step 440, Batch 440/1961, Loss: 1.2030
# Epoch 1, Step 450, Batch 450/1961, Loss: 1.1906
# Epoch 1, Step 460, Batch 460/1961, Loss: 1.2024
# Epoch 1, Step 470, Batch 470/1961, Loss: 1.1803
# Epoch 1, Step 480, Batch 480/1961, Loss: 1.1716
# Epoch 1, Step 490, Batch 490/1961, Loss: 1.1555
# Epoch 1, Step 500, Batch 500/1961, Loss: 1.1748
# Epoch 1, Step 510, Batch 510/1961, Loss: 1.1574
# Epoch 1, Step 520, Batch 520/1961, Loss: 1.1586
# Epoch 1, Step 530, Batch 530/1961, Loss: 1.1287
# Epoch 1, Step 540, Batch 540/1961, Loss: 1.1471
# Epoch 1, Step 550, Batch 550/1961, Loss: 1.1216
# Epoch 1, Step 560, Batch 560/1961, Loss: 1.1240
# Epoch 1, Step 570, Batch 570/1961, Loss: 1.1270
# Epoch 1, Step 580, Batch 580/1961, Loss: 1.1097
# Epoch 1, Step 590, Batch 590/1961, Loss: 1.1030
# Epoch 1, Step 600, Batch 600/1961, Loss: 1.0999
# Epoch 1, Step 610, Batch 610/1961, Loss: 1.0720
# Epoch 1, Step 620, Batch 620/1961, Loss: 1.0917
# Epoch 1, Step 630, Batch 630/1961, Loss: 1.0722
# Epoch 1, Step 640, Batch 640/1961, Loss: 1.0698
# Epoch 1, Step 650, Batch 650/1961, Loss: 1.0626
# Epoch 1, Step 660, Batch 660/1961, Loss: 1.0547
# Epoch 1, Step 670, Batch 670/1961, Loss: 1.0569
# Epoch 1, Step 680, Batch 680/1961, Loss: 1.0414
# Epoch 1, Step 690, Batch 690/1961, Loss: 1.0465
# Epoch 1, Step 700, Batch 700/1961, Loss: 1.0260
# Epoch 1, Step 710, Batch 710/1961, Loss: 1.0088
# Epoch 1, Step 720, Batch 720/1961, Loss: 1.0133
# Epoch 1, Step 730, Batch 730/1961, Loss: 1.0141
# Epoch 1, Step 740, Batch 740/1961, Loss: 0.9882
# Epoch 1, Step 750, Batch 750/1961, Loss: 0.9698
# Epoch 1, Step 760, Batch 760/1961, Loss: 0.9822
# Epoch 1, Step 770, Batch 770/1961, Loss: 0.9734
# Epoch 1, Step 780, Batch 780/1961, Loss: 0.9611
# Epoch 1, Step 790, Batch 790/1961, Loss: 0.9543
# Epoch 1, Step 800, Batch 800/1961, Loss: 0.9418
# Epoch 1, Step 810, Batch 810/1961, Loss: 0.9607
# Epoch 1, Step 820, Batch 820/1961, Loss: 0.9185
# Epoch 1, Step 830, Batch 830/1961, Loss: 0.9297
# Epoch 1, Step 840, Batch 840/1961, Loss: 0.9155
# Epoch 1, Step 850, Batch 850/1961, Loss: 0.9042
# Epoch 1, Step 860, Batch 860/1961, Loss: 0.9049
# Epoch 1, Step 870, Batch 870/1961, Loss: 0.8862
# Epoch 1, Step 880, Batch 880/1961, Loss: 0.8856
# Epoch 1, Step 890, Batch 890/1961, Loss: 0.8719
# Epoch 1, Step 900, Batch 900/1961, Loss: 0.8715
# Epoch 1, Step 910, Batch 910/1961, Loss: 0.8677
# Epoch 1, Step 920, Batch 920/1961, Loss: 0.8422
# Epoch 1, Step 930, Batch 930/1961, Loss: 0.8436
# Epoch 1, Step 940, Batch 940/1961, Loss: 0.8380
# Epoch 1, Step 950, Batch 950/1961, Loss: 0.8313
# Epoch 1, Step 960, Batch 960/1961, Loss: 0.8268
# Epoch 1, Step 970, Batch 970/1961, Loss: 0.8160
# Epoch 1, Step 980, Batch 980/1961, Loss: 0.8099
# Epoch 1, Step 990, Batch 990/1961, Loss: 0.7962
# Epoch 1, Step 1000, Batch 1000/1961, Loss: 0.7954
# Epoch 1, Step 1010, Batch 1010/1961, Loss: 0.7908
# Epoch 1, Step 1020, Batch 1020/1961, Loss: 0.7778
# Epoch 1, Step 1030, Batch 1030/1961, Loss: 0.7622
# Epoch 1, Step 1040, Batch 1040/1961, Loss: 0.7629
# Epoch 1, Step 1050, Batch 1050/1961, Loss: 0.7595
# Epoch 1, Step 1060, Batch 1060/1961, Loss: 0.7457
# Epoch 1, Step 1070, Batch 1070/1961, Loss: 0.7306
# Epoch 1, Step 1080, Batch 1080/1961, Loss: 0.7288
# Epoch 1, Step 1090, Batch 1090/1961, Loss: 0.7300
# Epoch 1, Step 1100, Batch 1100/1961, Loss: 0.7159
# Epoch 1, Step 1110, Batch 1110/1961, Loss: 0.7105
# Epoch 1, Step 1120, Batch 1120/1961, Loss: 0.7072
# Epoch 1, Step 1130, Batch 1130/1961, Loss: 0.6842
# Epoch 1, Step 1140, Batch 1140/1961, Loss: 0.7007
# Epoch 1, Step 1150, Batch 1150/1961, Loss: 0.6944
# Epoch 1, Step 1160, Batch 1160/1961, Loss: 0.6870
# Epoch 1, Step 1170, Batch 1170/1961, Loss: 0.6734
# Epoch 1, Step 1180, Batch 1180/1961, Loss: 0.6716
# Epoch 1, Step 1190, Batch 1190/1961, Loss: 0.6452
# Epoch 1, Step 1200, Batch 1200/1961, Loss: 0.6539
# Epoch 1, Step 1210, Batch 1210/1961, Loss: 0.6392
# Epoch 1, Step 1220, Batch 1220/1961, Loss: 0.6360
# Epoch 1, Step 1230, Batch 1230/1961, Loss: 0.6410
# Epoch 1, Step 1240, Batch 1240/1961, Loss: 0.6289
# Epoch 1, Step 1250, Batch 1250/1961, Loss: 0.6198
# Epoch 1, Step 1260, Batch 1260/1961, Loss: 0.6110
# Epoch 1, Step 1270, Batch 1270/1961, Loss: 0.6075
# Epoch 1, Step 1280, Batch 1280/1961, Loss: 0.6096
# Epoch 1, Step 1290, Batch 1290/1961, Loss: 0.6019
# Epoch 1, Step 1300, Batch 1300/1961, Loss: 0.5977
# Epoch 1, Step 1310, Batch 1310/1961, Loss: 0.5741
# Epoch 1, Step 1320, Batch 1320/1961, Loss: 0.5842
# Epoch 1, Step 1330, Batch 1330/1961, Loss: 0.5758
# Epoch 1, Step 1340, Batch 1340/1961, Loss: 0.5767
# Epoch 1, Step 1350, Batch 1350/1961, Loss: 0.5620
# Epoch 1, Step 1360, Batch 1360/1961, Loss: 0.5556
# Epoch 1, Step 1370, Batch 1370/1961, Loss: 0.5629
# Epoch 1, Step 1380, Batch 1380/1961, Loss: 0.5415
# Epoch 1, Step 1390, Batch 1390/1961, Loss: 0.5376
# Epoch 1, Step 1400, Batch 1400/1961, Loss: 0.5502
# Epoch 1, Step 1410, Batch 1410/1961, Loss: 0.5301
# Epoch 1, Step 1420, Batch 1420/1961, Loss: 0.5347
# Epoch 1, Step 1430, Batch 1430/1961, Loss: 0.5369
# Epoch 1, Step 1440, Batch 1440/1961, Loss: 0.5226
# Epoch 1, Step 1450, Batch 1450/1961, Loss: 0.5235
# Epoch 1, Step 1460, Batch 1460/1961, Loss: 0.5163
# Epoch 1, Step 1470, Batch 1470/1961, Loss: 0.5118
# Epoch 1, Step 1480, Batch 1480/1961, Loss: 0.5072
# Epoch 1, Step 1490, Batch 1490/1961, Loss: 0.5118
# Epoch 1, Step 1500, Batch 1500/1961, Loss: 0.5130
# Epoch 1, Step 1510, Batch 1510/1961, Loss: 0.4942
# Epoch 1, Step 1520, Batch 1520/1961, Loss: 0.5045
# Epoch 1, Step 1530, Batch 1530/1961, Loss: 0.4935
# Epoch 1, Step 1540, Batch 1540/1961, Loss: 0.4818
# Epoch 1, Step 1550, Batch 1550/1961, Loss: 0.4757
# Epoch 1, Step 1560, Batch 1560/1961, Loss: 0.4817
# Epoch 1, Step 1570, Batch 1570/1961, Loss: 0.4779
# Epoch 1, Step 1580, Batch 1580/1961, Loss: 0.4761
# Epoch 1, Step 1590, Batch 1590/1961, Loss: 0.4663
# Epoch 1, Step 1600, Batch 1600/1961, Loss: 0.4497
# Epoch 1, Step 1610, Batch 1610/1961, Loss: 0.4529
# Epoch 1, Step 1620, Batch 1620/1961, Loss: 0.4522
# Epoch 1, Step 1630, Batch 1630/1961, Loss: 0.4556
# Epoch 1, Step 1640, Batch 1640/1961, Loss: 0.4454
# Epoch 1, Step 1650, Batch 1650/1961, Loss: 0.4493
# Epoch 1, Step 1660, Batch 1660/1961, Loss: 0.4429
# Epoch 1, Step 1670, Batch 1670/1961, Loss: 0.4417
# Epoch 1, Step 1680, Batch 1680/1961, Loss: 0.4382
# Epoch 1, Step 1690, Batch 1690/1961, Loss: 0.4395
# Epoch 1, Step 1700, Batch 1700/1961, Loss: 0.4336
# Epoch 1, Step 1710, Batch 1710/1961, Loss: 0.4393
# Epoch 1, Step 1720, Batch 1720/1961, Loss: 0.4261
# Epoch 1, Step 1730, Batch 1730/1961, Loss: 0.4354
# Epoch 1, Step 1740, Batch 1740/1961, Loss: 0.4269
# Epoch 1, Step 1750, Batch 1750/1961, Loss: 0.4278
# Epoch 1, Step 1760, Batch 1760/1961, Loss: 0.4262
# Epoch 1, Step 1770, Batch 1770/1961, Loss: 0.4157
# Epoch 1, Step 1780, Batch 1780/1961, Loss: 0.4210
# Epoch 1, Step 1790, Batch 1790/1961, Loss: 0.4158
# Epoch 1, Step 1800, Batch 1800/1961, Loss: 0.4053
# Epoch 1, Step 1810, Batch 1810/1961, Loss: 0.4070
# Epoch 1, Step 1820, Batch 1820/1961, Loss: 0.4103
# Epoch 1, Step 1830, Batch 1830/1961, Loss: 0.4096
# Epoch 1, Step 1840, Batch 1840/1961, Loss: 0.3999
# Epoch 1, Step 1850, Batch 1850/1961, Loss: 0.4033
# Epoch 1, Step 1860, Batch 1860/1961, Loss: 0.4008
# Epoch 1, Step 1870, Batch 1870/1961, Loss: 0.4040
# Epoch 1, Step 1880, Batch 1880/1961, Loss: 0.3966
# Epoch 1, Step 1890, Batch 1890/1961, Loss: 0.3969
# Epoch 1, Step 1900, Batch 1900/1961, Loss: 0.3909
# Epoch 1, Step 1910, Batch 1910/1961, Loss: 0.3892
# Epoch 1, Step 1920, Batch 1920/1961, Loss: 0.3920
# Epoch 1, Step 1930, Batch 1930/1961, Loss: 0.3951
# Epoch 1, Step 1940, Batch 1940/1961, Loss: 0.4008
# Epoch 1, Step 1950, Batch 1950/1961, Loss: 0.3866
# Epoch 1, Step 1960, Batch 1960/1961, Loss: 0.3861
# Epoch 1/1, Train Loss: 0.3796, Val Loss: 3.4567, Epoch Time: 1009.69s
# Generated text [
#
# GREMIO:
# Good morrow, neighbour Baptista.
#
# BAPTISTA:
# Good morro]:
# --------------------------------------------------
#
#
# GREMIO:
# Good morrow, neighbour Baptista.
#
# BAPTISTA:
# Good morrow, gentlemen, in good time.
#
# You peers, give him head, madam, madam,
# Having both the palace, an she knew shike a sweet Marcius,
# When such a manner is past, and that
# Apolsome villain: you, let me go.
#
# YORK:
# Grandam, your steel not to plead from the gentlewoman.
#
# Apothecary:
# There is my purge his graves?
#
# KING RICHARD II:
# Sir How some joy is the life of Hermione,
# I know, in honour, O, that ever I
# Had squaring too reservation: this osech the heart
# That could conceive it? No, no, no, no,
# The nights

# %% [markdown]
# With multiple layers, we see a significant improvement in the loss curve and generated text quality. The model is now capable of producing grammatically correct sentences with more coherent meaning. This demonstrates the power of deep transformers, which become more effective as the number of layers increases.

# %% [markdown]
# # Conclusion
#
# In this notebook, we successfully implemented a custom version of the LLaMA model, progressively building from simple components to a complete, high-performing architecture. Starting with a baseline LSTM model, we gradually introduced key features of transformers such as attention, positional encoding, normalization, and residual connections. We incorporated advanced techniques like SwiGLU and RoPE, ultimately scaling the model to multiple layers and heads.
