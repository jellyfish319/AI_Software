# %% [markdown]
# ## 3번 셀까지 차례대로 실행해 주신 후 원하시는 코드 실행해주시면 됩니다.
# inference.py: CLI 챗봇,
# test.py: json파일,
# app.py: streamlit 웹페이지 구동

# %% [markdown]
# 만약 gdown이 되시지 않을 경우 다음 링크에서 파일을 다운받아 코랩에 압축해제해주신 후 라이브러리 설치 및 코드 실행 해주시면 되겠습니다.

# %% [markdown]
# https://drive.google.com/file/d/1-gzfSVTAhB0dlsqaElA_o-CuAP_KB-gu/view?usp=sharing

# %%
# !pip install langchain langchain-community langchain-openai chromadb datasets sentence-transformers streamlit fastapi uvicorn python-dotenv accelerate langchain_huggingface langchain_chroma bitsandbytes streamlit
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 5.4 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 76.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.6/84.6 kB 7.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.7/21.7 MB 122.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.0/9.0 MB 152.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.1/59.1 MB 9.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.2/278.2 kB 24.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 89.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 64.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 475.9/475.9 kB 38.3 MB/s eta 0:00:00
# ...

# %%
FILE_ID = '1-gzfSVTAhB0dlsqaElA_o-CuAP_KB-gu'
# !pip install -q gdown

# %%
import gdown
url = f'https://drive.google.com/uc?id={FILE_ID}'
gdown.download(url, quiet=False)

# !unzip -q {"A.zip"}
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1siEMNdrM-kXNpT4Ifm1hLkW0jDlFR3nm
# From (redirected): https://drive.google.com/uc?id=1siEMNdrM-kXNpT4Ifm1hLkW0jDlFR3nm&confirm=t&uuid=f521db01-60fe-49ff-8160-84c8a84f3d88
# To: /content/A.zip
# 100%|██████████| 10.7G/10.7G [02:51<00:00, 62.2MB/s]
# Downloading...
# From (original): https://drive.google.com/uc?id=1siEMNdrM-kXNpT4Ifm1hLkW0jDlFR3nm
# From (redirected): https://drive.google.com/uc?id=1siEMNdrM-kXNpT4Ifm1hLkW0jDlFR3nm&confirm=t&uuid=67ea455d-01a6-4fa0-8850-3603fe30a492
# To: /content/A.zip
# 100%|██████████| 10.7G/10.7G [01:09<00:00, 153MB/s]

# %%
# !python inference.py
# Out:
# 2025-12-15 13:06:29.734098: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1765803990.036929    2402 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1765803990.119947    2402 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1765803990.733966    2402 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
import os

print("=" * 50)
print("Copy the IP Address")
# !curl ipv4.icanhazip.com
print("=" * 50)
print("\n")

print("Launch Streamlit at Background")
# !nohup streamlit run app.py > nohup.out 2>&1 &

import time
time.sleep(5)

print("Click the URL and paste the url at 'Tunnel Password'")
# !npx localtunnel --port 8501

# %%
# !python test.py
